# %% [markdown]
# ## Libraries etc.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import networkx as nx
import subprocess

import os
import rdata
import dill as pickle

from collections import Counter, defaultdict
from datetime import datetime
from matplotlib import pyplot as plt
from itertools import combinations
#
from multiprocessing import Pool
import rdata
import warnings
from scipy.stats import entropy
warnings.filterwarnings("ignore")
#
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# files
pickle_dir = './pickles/'
imputed_data_file = pickle_dir + 'imputed_data.xlsx'
pcaspace_dir = pickle_dir + '/pcaspaces/'
# parameters
jaccard_threshold=0.9
require_ft_present = True
min_n_tokens = 20
sampling_method = 'convenience'

# %% [markdown]
# ## Part 2: analysis

# %%
df = pd.read_excel(imputed_data_file)

# %%
# sampling method
tot_wc = {l["doculect"] : (l['count']) for i,l in pd.read_csv('word_counts.csv').iterrows()}
doreco_metadata = pd.read_csv('doreco_languages_metadata_sep2023.csv')
doreco_metadata
# Out:
#                        Language Glottocode iso-639-3  \
# 0                          Anal   anal1239       anm
# 1             Yali (Apahapsili)   apah1238        na
# 2                       Arapaho   arap1274       arp
# 3             Baïnounk Gubëeher   bain1259       bab
# 4                          Beja   beja1238       bej
# 5                          Bora   bora1263       boa
# 6                       Cabécar   cabe1245       cjp
# 7                    Cashinahua   cash1254       cbs
# 8                        Dolgan   dolg1241       dlg
# 9                        Evenki   even1259       evn
# 10                       Goemai   goem1240       ank
# 11                       Gorwaa   goro1270       gow
# 12                       Hoocąk   hoch1243       win
# 13                        Jahai   jeha1242       jhi
# 14                       Jejuan   jeju1234       jje
# 15                       Kakabe   kaka1265       kke
# 16                        Kamas   kama1351       xas
# 17                Tabaq (Karko)   kark1256       kko
# 18                       Komnzo   komn1238       tci
# 19               Light Warlpiri   ligh1234        na
# 20                Lower Sorbian   lowe1385       dsb
# 21                       Movima   movi1243       mzp
# 22                      Dalabon   ngal1292       ngk
# 23                       Nisvai   nisv1234      none
# 24                         Nǁng   nngg1234       ngh
# 25  Northern Kurdish (Kurmanji)   nort2641       kmr
# 26                Northern Alta   nort2875       aqn
# 27                      Fanbyak   orko1234       fnb
# 28                         Pnar   pnar1238       pbv
# 29                       Daakie   port1286       ptv
# 30                     Resígaro   resi1247       rgr
# 31                        Ruuli   ruul1235       ruc
# 32                         Sadu   sadu1234        na
# 33                Sanzhi Dargwa   sanz1248        na
# 34                     Savosavo   savo1255       svs
# 35         Nafsan (South Efate)   sout2856       erk
# 36   English (Southern England)   sout3282        na
# 37               French (Swiss)   stan1290       fra
# 38                         Sümi   sumi1235       nsm
# 39                         Svan   svan1243       sva
# 40                    Tabasaran   taba1259       tab
# 41                         Teop   teop1238       tio
# 42          Texistepec Popoluca   texi1237       poq
# 43            Mojeño Trinitario   trin1278       trn
# 44             Asimjeeg Datooga   tsim1256        na
# 45                         Urum   urum1249       uum
# 46                       Vera'a   vera1241       vra
# 47                     Warlpiri   warl1254       wbp
# 48                  Yongning Na   yong1270       nru
# 49                 Yucatec Maya   yuca1254       yua
# 50                     Yurakaré   yura1255       yuz
#
#                       Family fam_glottocode           Area  \
# 0               Sino-Tibetan       sino1245        Eurasia
# 16  Gusev, Valentin and Klooster, Tiina and Wagner...     55.07      94.83
# 17  Hellwig, Birgit and Schneider-Blum, Gertrud an...     12.05      29.21
# 18                                  Döhler, Christian     -8.65     141.52
# 19                                O'Shannessy, Carmel    -18.32     130.63
# 20             Bartels, Hauke and Szczepański, Marcin     51.66      13.94
# 21                                   Haude, Katharina    -13.81     -65.63
# 22                                    Ponsonnet, Maïa    -13.98     133.94
# 23                                     Aznar, Jocelyn    -16.41     167.79
# 24  Güldemann, Tom and Ernszt, Martina and Siegmun...    -29.71      19.08
# 25   Haig, Geoff and Vollmer, Maria and Thiele, Hanna     37.00      43.00
# 26                           Garcia-Laguia, Alexandro     15.69     121.45
# 27                                  Franjieh, Michael    -16.21     168.21
# 28                                        Ring, Hiram     24.82      92.26
# 29                                    Krifka, Manfred    -16.31     168.05
# 30                                     Seifart, Frank     -2.48     -71.36
# 31  Witzlack-Makarevich, Alena and Namyalo, Saudah...      1.42      32.42
# 32                         Xu, Xianming and Bai, Bibo     24.30     102.00
# 33            Forker, Diana and Schiborr, Nils Norman     41.98      47.57
# 34                                   Wegener, Claudia     -9.13     159.81
# 35                                   Thieberger, Nick    -17.70     168.38
# 36                              Schiborr, Nils Norman     53.00      -1.00
# 37  Avanzi, Mathieu and Béguelin, Marie-José and C...     48.00       2.00
# 38                                          Teo, Amos     26.00      94.42
# 39                                      Gippert, Jost     42.91      42.59
# 40  Bogomolova, Natalia and Ganenkov, Dmitry and S...     42.02      47.84
# 41                                      Mosel, Ulrike     -5.67     154.97
# 42                                    Wichmann, Søren     17.89     -94.81
# 43                                    Rose, Françoise    -15.33     -65.41
# 44                                   Griscom, Richard     -3.42      35.43
# 45  Skopeteas, Stavros and Moisidi, Violeta and Ts...     42.04      43.99
# 46                                    Schnell, Stefan    -13.89     167.43
# 47                                O'Shannessy, Carmel    -20.10     131.05
# 48                                    Michaud, Alexis     27.80     100.90
# 49                                 Skopeteas, Stavros     18.78     -88.96
# 50      Gipper, Sonja and Ballivián Torrico, Jeremías    -16.75     -65.12
#
#           Archive  ... Audio license                    DOI Gloss  \
# 0            ELAR  ...      CC BY-NC  10.34847/nkl.0dbazp8m  none
# 1             TLA  ...   CC BY-NC-SA  10.34847/nkl.9d91nkq2   all
# 2            ELAR  ...         CC BY  10.34847/nkl.36f5r1b6   all
# 3            ELAR  ...         CC BY  10.34847/nkl.a332abw8  some
# 4     CorpoAfroas  ...      CC BY-NC  10.34847/nkl.edd011t1   all
# 5             TLA  ...         CC BY  10.34847/nkl.6eaf5laq   all
# 6             TLA  ...   CC BY-NC-ND  10.34847/nkl.ebc4ra22   all
# 7             TLA  ...         CC BY  10.34847/nkl.a8f9q2f1  some
# 8            HZSK  ...      CC BY-NC  10.34847/nkl.f09eikq3   all
# 9   Siberian Lang  ...         CC BY  10.34847/nkl.5e0d27cu   all
# 10            TLA  ...  audio linked  10.34847/nkl.b93664ml   all
# 11           ELAR  ...         CC BY  10.34847/nkl.a4b4ijj2   all
# 12            TLA  ...  audio linked  10.34847/nkl.b57f5065   all
# 13     RWAAI: TLA  ...   CC BY-NC-ND  10.34847/nkl.6a71xp0p  some
# 14           ELAR  ...         CC BY  10.34847/nkl.06ebrk38   all
# 15           ELAR  ...         CC BY  10.34847/nkl.d5aeu9t6   all
# 16           INEL  ...         CC BY  10.34847/nkl.cdd8177b   all
# 17           ELAR  ...  audio linked  10.34847/nkl.eea8144j  none
# 18         Zenodo  ...         CC BY  10.34847/nkl.c5e6dudv   all
# 19            TLA  ...   CC BY-NC-ND  10.34847/nkl.7452803q  none
# 20            TLA  ...  audio linked  10.34847/nkl.6c6e4e9k  none
# 21            TLA  ...  audio linked  10.34847/nkl.da42xf67   all
# 22            TLA  ...         CC BY  10.34847/nkl.fae299ug  some
# 23       Ortolang  ...   CC BY-NC-ND  10.34847/nkl.2801565f   all
# 24             na  ...         CC BY  10.34847/nkl.f6c37fi0   all
# 25     Multi-CAST  ...         CC BY  10.34847/nkl.ca10ez5t   all
# 26           ELAR  ...   CC BY-NC-ND  10.34847/nkl.efea0b36   all
# 27           ELAR  ...         CC BY  10.34847/nkl.02084446  some
# 28     NTU; RWAAI  ...      CC BY-NC  10.34847/nkl.5ba1062k   all
# 29             na  ...         CC BY  10.34847/nkl.efeav5l9  some
# 30            TLA  ...         CC BY  10.34847/nkl.ffb96lo8  none
# 31             na  ...         CC BY  10.34847/nkl.fde4pp1u   all
# 32           ELAR  ...         CC BY  10.34847/nkl.3db4u59d  none
# 33            TLA  ...         CC BY  10.34847/nkl.81934177  some
# 34            TLA  ...         CC BY  10.34847/nkl.b74d1b33   all
# 35      Paradisec  ...   CC BY-NC-SA  10.34847/nkl.ba4f760l   all
# 36     Multi-CAST  ...         CC BY  10.34847/nkl.9c271u5g   all
# 37             na  ...   CC BY-NC-SA  10.34847/nkl.3520l685   all
# 38      Paradisec  ...         CC BY  10.34847/nkl.5ad4t01p   all
# 39            TLA  ...         CC BY  10.34847/nkl.9ba054c3  none
# 40     Multi-CAST  ...         CC BY  10.34847/nkl.ad7f97xr   all
# 41            TLA  ...         CC BY  10.34847/nkl.9322sdf2   all
# 42             na  ...         CC BY  10.34847/nkl.c50ck58f   all
# 43             na  ...         CC BY  10.34847/nkl.cbc3b4xr  some
# 44           ELAR  ...         CC BY  10.34847/nkl.f77c7m72  none
# 45            TLA  ...   CC BY-NC-ND  10.34847/nkl.ac166n10   all
# 46            TLA  ...         CC BY  10.34847/nkl.3e2cu8c4   all
# 47            TLA  ...   CC BY-NC-ND  10.34847/nkl.042dv614  none
# 48       Pangloss  ...   CC BY-NC-SA  10.34847/nkl.abe65p95  none
# 49            TLA  ...   CC BY-NC-ND  10.34847/nkl.9cbb3619  none
# 50            LAC  ...  audio linked  10.34847/nkl.7ca412wg  none
#
#    Extended speakers Extended word tokens Extended texts  Core speakers  \
# 0                 12                13015             23             12
# 1                 14                10191             11             10
# 2                  8                10407             21              4
# 3                 10                12425             18              9
# 4                  5                15439             58              5
# 5                 39                29578             38              6
# 6                 15                17961            115             10
# 7                  3                10043              3              3
# 8                 20                18966             25              6
# 9                 23                 8315             36             23
# 10                 6                25304             27              5
# 11                11                19688             14              8
# 12                11                 7338             21             11
# 13                 3                 7330              9              3
# 14                 5                 7272              8              5
# 15                18                46656             23              4
# 16                 2                40298            131              1
# 17                 5                 9265             16              5
# 18                26                33909             49             11
# 19                 6                 8672              8              6
# 20                 4                10246             15              4
# 21                 5                10183             12              5
# 22                 4                 3412             10              4
# 23                 8                11872             12              8
# 24                 7                28005             33              6
# 25                 2                 9658              5              2
# 26                 2                 8544              4              2
# 27                14                19131             39             10
# 28                19                20454             21              6
# 29                10                12038             16             10
# 30                 3                 7985             20              3
# 31                 7                 8718              5              7
# 32                 6                12019             13              6
# 33                 5                 5146              9              5
# 34                 7                12075              7              7
# 35                19                29414             63             12
# 36                 4                35441              8              2
# 37                 8                13339              8              8
# 38                26                12838             35             23
# 39                 9                 9895             28              9
# 40                 2                 5059              5              2
# 41                11                12148             11             11
# 42                 1                 8473              4              1
# 43                21                18336             32              6
# 44                12                 8784             40             12
# 45                32                18802            246             30
# 46                10                17794             11              7
# 47                18                 7171             22             18
# 48                 1                 8877              6              1
# 49                 6                10857             10              6
# 50                16                20206             20             16
#
#     core word tokens  Core texts  Years of recordings in core set
# 0              13015          23                        2015-2016
# 1               7474           8                        2013-2017
# 2               4746          11                             2005
# 3              11477          17                        2009-2014
# 4              15439          58                        2003-2011
# 5               8431           9                        2004-2008
# 6              10614          39                             2011
# 7              10043           3                             2006
# 8               8778           9                        1972-2010
# 9               8315          36                        2006-2016
# 10              9340          11                        1999-2000
# 11             10674           9                        2013-2016
# 12              7338          21                        2003-2012
# 13              7330           9                        2000-2012
# 14              7272           8                             2015
# 15              9525           9                        2013-2015
# 16             10052          26                        1964-1970
# 17              9265          16                        2011-2013
# 18              9892          19                        2010-2015
# 19              8672           8                        2005-2015
# 20             10246          15                        2011-2013
# 21             10183          12                        2002-2014
# 22              3412          10                        2010-2012
# 23             11872          12                        2011-2015
# 24             10283          17                        2004-2009
# 25              9658           5                        2000-2004
# 26              8544           4                             2016
# 27             10170          26                        2015-2017
# 28              8520           8                        2011-2012
# 29             12038          16                        2010-2018
# 30              7985          20                        2004-2009
# 31              8718           5                        2012-2019
# 32             12019          13                        2010-2013
# 33              5146           9                        2011-2013
# 34             12075           7                        2003-2008
# 35             10243          30                        1997-2000
# 36              8998           2                        1975-1985
# 37             13339           8                        2014-2015
# 38              9981          28                             2010
# 39              9895          28                             2012
# 40              5059           5                             2010
# 41             12148          11                        2003-2004
# 42              8473           4                             1993
# 43              7792          10                        2005-2018
# 44              8784          40                        2015-2017
# 45             10035         132                             2015
# 46             12380           8                             2007
# 47              7171          22                        2004-2010
# 48              8877           6                        2006-2012
# 49             10857          10                             2015
# 50             20206          20                             2013
#
# [51 rows x 23 columns]

# %%
area = defaultdict(lambda : [])
for f,c in Counter(doreco_metadata.Family).most_common():
    glottocodes = list(doreco_metadata[doreco_metadata.Family==f].Glottocode)
    found_glottocodes = [g for g in glottocodes if g in df.doculect.unique()]
    area_f = Counter(doreco_metadata[doreco_metadata.Family==f].Area).most_common(1)[0][0]
    #print(f,c,len(found_glottocodes),area_f)
    best_glottocode = max(found_glottocodes, key = tot_wc.get, default=None)
    # sample doculect with most words per genus
    if sampling_method in {'genus', 'genus-area'}:
        if best_glottocode != None: 
            area[area_f].append(best_glottocode)
    elif sampling_method == 'convenience':
        area[area_f].extend(found_glottocodes)
sample = []
for k,v in area.items():
    if sampling_method == 'genus-area' : 
        best_v = sorted(v, key = tot_wc.get)[-3:]
        # if method is genus-are, sample 3 doculects with most words per area
    else : best_v = v
    print(k,len(v),best_v)
    sample += best_v
print('>>>', sampling_method, len(sample), sample)
sampled_docs = set(sample)
# Out:
# Papunesia 9 ['nisv1234', 'nort2875', 'orko1234', 'port1286', 'sout2856', 'teop1238', 'vera1241', 'apah1238', 'komn1238']
# Eurasia 16 ['anal1239', 'sadu1234', 'sumi1235', 'yong1270', 'lowe1385', 'nort2641', 'sout3282', 'dolg1241', 'urum1249', 'jeha1242', 'pnar1238', 'sanz1248', 'taba1259', 'even1259', 'kama1351', 'svan1243']
# Africa 9 ['beja1238', 'goem1240', 'goro1270', 'bain1259', 'ruul1235', 'kaka1265', 'kark1256', 'nngg1234', 'tsim1256']
# South America 7 ['movi1243', 'savo1255', 'yura1255', 'resi1247', 'trin1278', 'bora1263', 'cash1254']
# North America 5 ['arap1274', 'cabe1245', 'hoch1243', 'texi1237', 'yuca1254']
# Australia 1 ['ngal1292']
# >>> convenience 47 ['nisv1234', 'nort2875', 'orko1234', 'port1286', 'sout2856', 'teop1238', 'vera1241', 'apah1238', 'komn1238', 'anal1239', 'sadu1234', 'sumi1235', 'yong1270', 'lowe1385', 'nort2641', 'sout3282', 'dolg1241', 'urum1249', 'jeha1242', 'pnar1238', 'sanz1248', 'taba1259', 'even1259', 'kama1351', 'svan1243', 'beja1238', 'goem1240', 'goro1270', 'bain1259', 'ruul1235', 'kaka1265', 'kark1256', 'nngg1234', 'tsim1256', 'movi1243', 'savo1255', 'yura1255', 'resi1247', 'trin1278', 'bora1263', 'cash1254', 'arap1274', 'cabe1245', 'hoch1243', 'texi1237', 'yuca1254', 'ngal1292']

# %%
df_sub = df[df.doculect.isin(sampled_docs)]
print('n Sampled tokens: %d | n Original Tokens: %d' % (len(df_sub), len(df)))
# Out:
# n Sampled tokens: 146821 | n Original Tokens: 146821

# %%
field_anchors = []
fields = []
for doc in sampled_docs:
    print(doc)
    markers = df_sub[df_sub.doculect == doc].marker.unique()
    for m in markers:
        if require_ft_present: field = np.array((df_sub['imputed_%s' % doc] == m) & (df_sub['ft_present_%s' % doc]))
        else: field = np.array((df_sub['imputed_%s' % doc] == m))
        if sum(field) == 0: print(doc, m); continue
        fields.append(field)
        field_anchors.append((doc,m))
fields = np.array(fields)
print('n Fields: %d' % len(fields))
# Out:
# anal1239
# port1286
# sadu1234
# sout3282
# goem1240
# dolg1241
# beja1238
# nort2641
# arap1274
# komn1238
# movi1243
# savo1255
# kaka1265
# yuca1254
# bain1259
# yura1255
# resi1247
# cabe1245
# sumi1235
# bora1263
# texi1237
# yong1270
# ruul1235
# kama1351
# trin1278
# nisv1234
# nisv1234 nan
# ngal1292
# ngal1292 nan
# even1259
# urum1249
# tsim1256
# taba1259
# hoch1243
# goro1270
# pnar1238
# jeha1242
# jeha1242 nan
# orko1234
# kark1256
# sanz1248
# lowe1385
# nort2875
# sout2856
# vera1241
# cash1254
# teop1238
# svan1243
# apah1238
# nngg1234
# n Fields: 9535

# %%
def jaccard_similarity(si,sj):
    return (len(si & sj) / len(si | sj))

def get_merged_fields(fields, field_anchors, jaccard_threshold):
    sets = [set(np.where(fields[i])[0]) for i in range(fields.shape[0])]
    with Pool(12) as p:
        similarities = p.starmap(jaccard_similarity, map(lambda c : (sets[c[0]],sets[c[1]]), combinations(range(fields.shape[0]),2)))
    similar_field_pairs = {c for c,sim in zip(combinations(range(fields.shape[0]), 2), similarities) if sim >= jaccard_threshold}
    #
    G = nx.Graph()
    G.add_nodes_from(np.arange(len(fields)))
    G.add_edges_from(similar_field_pairs)
    #
    new_fields, new_anchors = [], []
    for c in nx.connected_components(G):
        similarities_c = [jaccard_similarity(sets[i],sets[j]) for i,j in combinations(c, 2)]
        new_field = np.zeros(fields.shape[1]).astype(bool)
        new_field[list(set.union(*[set(np.where(fields[ci])[0]) for ci in c]))] = True
        new_fields.append(new_field)
        new_anchors.append([field_anchors[ci] for ci in c])
        #
        if len(c) > 1: print('n Terms: %d | avg Jaccard sim: %.3f | min Jaccard sim: %.3f | n terms: %d' %
                             (len(c), np.mean(similarities_c), min(similarities_c), sum(new_field)))
    new_fields = np.array(new_fields)
    print('n New Fields: %d | n Old Fields: %d' % (len(new_fields), len(fields)))
    return new_fields, new_anchors

new_fields, new_anchors = get_merged_fields(fields, field_anchors, jaccard_threshold)
# Out:
# n Terms: 12 | avg Jaccard sim: 0.926 | min Jaccard sim: 0.839 | n terms: 820
# n Terms: 17 | avg Jaccard sim: 0.883 | min Jaccard sim: 0.762 | n terms: 3083
# n Terms: 11 | avg Jaccard sim: 0.904 | min Jaccard sim: 0.831 | n terms: 2253
# n Terms: 17 | avg Jaccard sim: 0.922 | min Jaccard sim: 0.858 | n terms: 1021
# n Terms: 13 | avg Jaccard sim: 0.947 | min Jaccard sim: 0.876 | n terms: 864
# n Terms: 7 | avg Jaccard sim: 0.927 | min Jaccard sim: 0.864 | n terms: 201
# n Terms: 5 | avg Jaccard sim: 0.903 | min Jaccard sim: 0.882 | n terms: 425
# n Terms: 11 | avg Jaccard sim: 0.911 | min Jaccard sim: 0.829 | n terms: 541
# n Terms: 4 | avg Jaccard sim: 0.925 | min Jaccard sim: 0.865 | n terms: 513
# n Terms: 23 | avg Jaccard sim: 0.900 | min Jaccard sim: 0.793 | n terms: 1644
# n Terms: 3 | avg Jaccard sim: 0.964 | min Jaccard sim: 0.947 | n terms: 430
# n Terms: 14 | avg Jaccard sim: 0.940 | min Jaccard sim: 0.884 | n terms: 645
# n Terms: 21 | avg Jaccard sim: 0.930 | min Jaccard sim: 0.842 | n terms: 419
# n Terms: 6 | avg Jaccard sim: 0.888 | min Jaccard sim: 0.828 | n terms: 226
# n Terms: 12 | avg Jaccard sim: 0.921 | min Jaccard sim: 0.858 | n terms: 882
# n Terms: 2 | avg Jaccard sim: 0.908 | min Jaccard sim: 0.908 | n terms: 543
# n Terms: 7 | avg Jaccard sim: 0.894 | min Jaccard sim: 0.827 | n terms: 322
# n Terms: 4 | avg Jaccard sim: 0.934 | min Jaccard sim: 0.919 | n terms: 128
# n Terms: 3 | avg Jaccard sim: 0.927 | min Jaccard sim: 0.893 | n terms: 112
# n Terms: 4 | avg Jaccard sim: 0.932 | min Jaccard sim: 0.913 | n terms: 290
# n Terms: 10 | avg Jaccard sim: 0.884 | min Jaccard sim: 0.828 | n terms: 728
# n Terms: 3 | avg Jaccard sim: 0.939 | min Jaccard sim: 0.923 | n terms: 145
# n Terms: 18 | avg Jaccard sim: 0.928 | min Jaccard sim: 0.841 | n terms: 533
# n Terms: 3 | avg Jaccard sim: 0.914 | min Jaccard sim: 0.905 | n terms: 240
# n Terms: 9 | avg Jaccard sim: 0.934 | min Jaccard sim: 0.818 | n terms: 304
# n Terms: 2 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.907 | n terms: 182
# n Terms: 3 | avg Jaccard sim: 0.952 | min Jaccard sim: 0.929 | n terms: 42
# n Terms: 13 | avg Jaccard sim: 0.921 | min Jaccard sim: 0.855 | n terms: 326
# n Terms: 2 | avg Jaccard sim: 0.925 | min Jaccard sim: 0.925 | n terms: 80
# n Terms: 9 | avg Jaccard sim: 0.918 | min Jaccard sim: 0.868 | n terms: 433
# n Terms: 11 | avg Jaccard sim: 0.933 | min Jaccard sim: 0.872 | n terms: 598
# n Terms: 2 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.907 | n terms: 8540
# n Terms: 23 | avg Jaccard sim: 0.940 | min Jaccard sim: 0.841 | n terms: 9598
# n Terms: 14 | avg Jaccard sim: 0.917 | min Jaccard sim: 0.852 | n terms: 5862
# n Terms: 15 | avg Jaccard sim: 0.930 | min Jaccard sim: 0.844 | n terms: 2251
# n Terms: 11 | avg Jaccard sim: 0.896 | min Jaccard sim: 0.842 | n terms: 1701
# n Terms: 21 | avg Jaccard sim: 0.930 | min Jaccard sim: 0.823 | n terms: 1251
# n Terms: 13 | avg Jaccard sim: 0.912 | min Jaccard sim: 0.845 | n terms: 1232
# n Terms: 20 | avg Jaccard sim: 0.929 | min Jaccard sim: 0.881 | n terms: 1068
# n Terms: 15 | avg Jaccard sim: 0.920 | min Jaccard sim: 0.840 | n terms: 1248
# n Terms: 26 | avg Jaccard sim: 0.937 | min Jaccard sim: 0.824 | n terms: 2136
# n Terms: 10 | avg Jaccard sim: 0.920 | min Jaccard sim: 0.836 | n terms: 299
# n Terms: 12 | avg Jaccard sim: 0.908 | min Jaccard sim: 0.836 | n terms: 818
# n Terms: 11 | avg Jaccard sim: 0.925 | min Jaccard sim: 0.871 | n terms: 1418
# n Terms: 18 | avg Jaccard sim: 0.942 | min Jaccard sim: 0.842 | n terms: 564
# n Terms: 8 | avg Jaccard sim: 0.884 | min Jaccard sim: 0.820 | n terms: 192
# n Terms: 7 | avg Jaccard sim: 0.905 | min Jaccard sim: 0.877 | n terms: 170
# n Terms: 12 | avg Jaccard sim: 0.895 | min Jaccard sim: 0.776 | n terms: 692
# n Terms: 25 | avg Jaccard sim: 0.939 | min Jaccard sim: 0.878 | n terms: 1259
# n Terms: 4 | avg Jaccard sim: 0.912 | min Jaccard sim: 0.862 | n terms: 833
# n Terms: 13 | avg Jaccard sim: 0.956 | min Jaccard sim: 0.866 | n terms: 236
# n Terms: 5 | avg Jaccard sim: 0.882 | min Jaccard sim: 0.816 | n terms: 255
# n Terms: 16 | avg Jaccard sim: 0.909 | min Jaccard sim: 0.845 | n terms: 817
# n Terms: 2 | avg Jaccard sim: 0.904 | min Jaccard sim: 0.904 | n terms: 342
# n Terms: 3 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.889 | n terms: 163
# n Terms: 13 | avg Jaccard sim: 0.920 | min Jaccard sim: 0.848 | n terms: 454
# n Terms: 14 | avg Jaccard sim: 0.901 | min Jaccard sim: 0.828 | n terms: 584
# n Terms: 11 | avg Jaccard sim: 0.927 | min Jaccard sim: 0.858 | n terms: 497
# n Terms: 3 | avg Jaccard sim: 0.915 | min Jaccard sim: 0.882 | n terms: 144
# n Terms: 4 | avg Jaccard sim: 0.935 | min Jaccard sim: 0.920 | n terms: 177
# n Terms: 5 | avg Jaccard sim: 0.974 | min Jaccard sim: 0.956 | n terms: 229
# n Terms: 3 | avg Jaccard sim: 0.928 | min Jaccard sim: 0.913 | n terms: 47
# n Terms: 9 | avg Jaccard sim: 0.912 | min Jaccard sim: 0.811 | n terms: 308
# n Terms: 6 | avg Jaccard sim: 0.934 | min Jaccard sim: 0.884 | n terms: 114
# n Terms: 2 | avg Jaccard sim: 0.936 | min Jaccard sim: 0.936 | n terms: 233
# n Terms: 3 | avg Jaccard sim: 0.917 | min Jaccard sim: 0.902 | n terms: 320
# n Terms: 6 | avg Jaccard sim: 0.924 | min Jaccard sim: 0.857 | n terms: 621
# n Terms: 2 | avg Jaccard sim: 0.916 | min Jaccard sim: 0.916 | n terms: 1233
# n Terms: 6 | avg Jaccard sim: 0.910 | min Jaccard sim: 0.859 | n terms: 331
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 19
# n Terms: 7 | avg Jaccard sim: 0.923 | min Jaccard sim: 0.884 | n terms: 936
# n Terms: 14 | avg Jaccard sim: 0.923 | min Jaccard sim: 0.840 | n terms: 720
# n Terms: 4 | avg Jaccard sim: 0.943 | min Jaccard sim: 0.915 | n terms: 48
# n Terms: 2 | avg Jaccard sim: 0.931 | min Jaccard sim: 0.931 | n terms: 160
# n Terms: 2 | avg Jaccard sim: 0.904 | min Jaccard sim: 0.904 | n terms: 1164
# n Terms: 2 | avg Jaccard sim: 0.919 | min Jaccard sim: 0.919 | n terms: 1202
# n Terms: 3 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.880 | n terms: 1254
# n Terms: 6 | avg Jaccard sim: 0.946 | min Jaccard sim: 0.901 | n terms: 845
# n Terms: 2 | avg Jaccard sim: 0.913 | min Jaccard sim: 0.913 | n terms: 1698
# n Terms: 2 | avg Jaccard sim: 0.928 | min Jaccard sim: 0.928 | n terms: 484
# n Terms: 2 | avg Jaccard sim: 0.908 | min Jaccard sim: 0.908 | n terms: 556
# n Terms: 5 | avg Jaccard sim: 0.946 | min Jaccard sim: 0.921 | n terms: 1443
# n Terms: 2 | avg Jaccard sim: 0.987 | min Jaccard sim: 0.987 | n terms: 79
# n Terms: 8 | avg Jaccard sim: 0.935 | min Jaccard sim: 0.859 | n terms: 183
# n Terms: 2 | avg Jaccard sim: 0.904 | min Jaccard sim: 0.904 | n terms: 428
# n Terms: 5 | avg Jaccard sim: 0.900 | min Jaccard sim: 0.837 | n terms: 533
# n Terms: 9 | avg Jaccard sim: 0.928 | min Jaccard sim: 0.838 | n terms: 908
# n Terms: 8 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.862 | n terms: 1416
# n Terms: 17 | avg Jaccard sim: 0.926 | min Jaccard sim: 0.855 | n terms: 1311
# n Terms: 7 | avg Jaccard sim: 0.911 | min Jaccard sim: 0.809 | n terms: 466
# n Terms: 15 | avg Jaccard sim: 0.915 | min Jaccard sim: 0.847 | n terms: 1047
# n Terms: 8 | avg Jaccard sim: 0.946 | min Jaccard sim: 0.864 | n terms: 164
# n Terms: 11 | avg Jaccard sim: 0.918 | min Jaccard sim: 0.849 | n terms: 764
# n Terms: 10 | avg Jaccard sim: 0.940 | min Jaccard sim: 0.897 | n terms: 1357
# n Terms: 7 | avg Jaccard sim: 0.935 | min Jaccard sim: 0.853 | n terms: 303
# n Terms: 5 | avg Jaccard sim: 0.897 | min Jaccard sim: 0.864 | n terms: 534
# n Terms: 3 | avg Jaccard sim: 0.975 | min Jaccard sim: 0.963 | n terms: 107
# n Terms: 10 | avg Jaccard sim: 0.885 | min Jaccard sim: 0.811 | n terms: 635
# n Terms: 11 | avg Jaccard sim: 0.931 | min Jaccard sim: 0.837 | n terms: 290
# n Terms: 6 | avg Jaccard sim: 0.913 | min Jaccard sim: 0.880 | n terms: 218
# n Terms: 3 | avg Jaccard sim: 0.966 | min Jaccard sim: 0.958 | n terms: 119
# n Terms: 7 | avg Jaccard sim: 0.921 | min Jaccard sim: 0.890 | n terms: 364
# n Terms: 13 | avg Jaccard sim: 0.921 | min Jaccard sim: 0.860 | n terms: 325
# n Terms: 2 | avg Jaccard sim: 0.950 | min Jaccard sim: 0.950 | n terms: 383
# n Terms: 2 | avg Jaccard sim: 0.932 | min Jaccard sim: 0.932 | n terms: 59
# n Terms: 4 | avg Jaccard sim: 0.922 | min Jaccard sim: 0.901 | n terms: 461
# n Terms: 6 | avg Jaccard sim: 0.916 | min Jaccard sim: 0.858 | n terms: 202
# n Terms: 8 | avg Jaccard sim: 0.934 | min Jaccard sim: 0.898 | n terms: 165
# n Terms: 8 | avg Jaccard sim: 0.915 | min Jaccard sim: 0.839 | n terms: 283
# n Terms: 5 | avg Jaccard sim: 0.920 | min Jaccard sim: 0.870 | n terms: 200
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 26
# n Terms: 3 | avg Jaccard sim: 0.928 | min Jaccard sim: 0.894 | n terms: 47
# n Terms: 2 | avg Jaccard sim: 0.909 | min Jaccard sim: 0.909 | n terms: 276
# n Terms: 16 | avg Jaccard sim: 0.896 | min Jaccard sim: 0.842 | n terms: 2824
# n Terms: 10 | avg Jaccard sim: 0.913 | min Jaccard sim: 0.832 | n terms: 1759
# n Terms: 3 | avg Jaccard sim: 0.923 | min Jaccard sim: 0.896 | n terms: 194
# n Terms: 3 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.877 | n terms: 66
# n Terms: 4 | avg Jaccard sim: 0.919 | min Jaccard sim: 0.894 | n terms: 171
# n Terms: 3 | avg Jaccard sim: 0.978 | min Jaccard sim: 0.968 | n terms: 31
# n Terms: 4 | avg Jaccard sim: 0.955 | min Jaccard sim: 0.935 | n terms: 140
# n Terms: 4 | avg Jaccard sim: 0.927 | min Jaccard sim: 0.901 | n terms: 445
# n Terms: 2 | avg Jaccard sim: 0.936 | min Jaccard sim: 0.936 | n terms: 171
# n Terms: 2 | avg Jaccard sim: 0.946 | min Jaccard sim: 0.946 | n terms: 92
# n Terms: 5 | avg Jaccard sim: 0.912 | min Jaccard sim: 0.862 | n terms: 93
# n Terms: 4 | avg Jaccard sim: 0.949 | min Jaccard sim: 0.925 | n terms: 54
# n Terms: 3 | avg Jaccard sim: 0.916 | min Jaccard sim: 0.895 | n terms: 57
# n Terms: 2 | avg Jaccard sim: 0.963 | min Jaccard sim: 0.963 | n terms: 27
# n Terms: 7 | avg Jaccard sim: 0.941 | min Jaccard sim: 0.875 | n terms: 246
# n Terms: 8 | avg Jaccard sim: 0.900 | min Jaccard sim: 0.847 | n terms: 188
# n Terms: 3 | avg Jaccard sim: 0.902 | min Jaccard sim: 0.895 | n terms: 156
# n Terms: 3 | avg Jaccard sim: 0.980 | min Jaccard sim: 0.974 | n terms: 232
# n Terms: 3 | avg Jaccard sim: 0.956 | min Jaccard sim: 0.934 | n terms: 61
# n Terms: 2 | avg Jaccard sim: 0.941 | min Jaccard sim: 0.941 | n terms: 51
# n Terms: 4 | avg Jaccard sim: 0.930 | min Jaccard sim: 0.902 | n terms: 457
# n Terms: 3 | avg Jaccard sim: 0.955 | min Jaccard sim: 0.932 | n terms: 59
# n Terms: 8 | avg Jaccard sim: 0.935 | min Jaccard sim: 0.892 | n terms: 260
# n Terms: 23 | avg Jaccard sim: 0.911 | min Jaccard sim: 0.814 | n terms: 642
# n Terms: 12 | avg Jaccard sim: 0.903 | min Jaccard sim: 0.821 | n terms: 515
# n Terms: 2 | avg Jaccard sim: 0.929 | min Jaccard sim: 0.929 | n terms: 322
# n Terms: 7 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.839 | n terms: 397
# n Terms: 3 | avg Jaccard sim: 0.947 | min Jaccard sim: 0.926 | n terms: 190
# n Terms: 5 | avg Jaccard sim: 0.968 | min Jaccard sim: 0.943 | n terms: 70
# n Terms: 5 | avg Jaccard sim: 0.984 | min Jaccard sim: 0.961 | n terms: 77
# n Terms: 2 | avg Jaccard sim: 0.962 | min Jaccard sim: 0.962 | n terms: 79
# n Terms: 12 | avg Jaccard sim: 0.905 | min Jaccard sim: 0.826 | n terms: 959
# n Terms: 2 | avg Jaccard sim: 0.976 | min Jaccard sim: 0.976 | n terms: 42
# n Terms: 9 | avg Jaccard sim: 0.887 | min Jaccard sim: 0.813 | n terms: 886
# n Terms: 3 | avg Jaccard sim: 0.890 | min Jaccard sim: 0.859 | n terms: 131
# n Terms: 4 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 138
# n Terms: 4 | avg Jaccard sim: 0.947 | min Jaccard sim: 0.928 | n terms: 99
# n Terms: 2 | avg Jaccard sim: 0.974 | min Jaccard sim: 0.974 | n terms: 39
# n Terms: 3 | avg Jaccard sim: 0.915 | min Jaccard sim: 0.875 | n terms: 16
# n Terms: 2 | avg Jaccard sim: 0.932 | min Jaccard sim: 0.932 | n terms: 59
# n Terms: 2 | avg Jaccard sim: 0.976 | min Jaccard sim: 0.976 | n terms: 123
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 11
# n Terms: 3 | avg Jaccard sim: 0.986 | min Jaccard sim: 0.978 | n terms: 46
# n Terms: 6 | avg Jaccard sim: 0.933 | min Jaccard sim: 0.863 | n terms: 81
# n Terms: 2 | avg Jaccard sim: 0.912 | min Jaccard sim: 0.912 | n terms: 57
# n Terms: 4 | avg Jaccard sim: 0.970 | min Jaccard sim: 0.939 | n terms: 33
# n Terms: 8 | avg Jaccard sim: 0.900 | min Jaccard sim: 0.854 | n terms: 213
# n Terms: 2 | avg Jaccard sim: 0.965 | min Jaccard sim: 0.965 | n terms: 86
# n Terms: 9 | avg Jaccard sim: 0.954 | min Jaccard sim: 0.915 | n terms: 541
# n Terms: 13 | avg Jaccard sim: 0.916 | min Jaccard sim: 0.857 | n terms: 1963
# n Terms: 4 | avg Jaccard sim: 0.893 | min Jaccard sim: 0.856 | n terms: 254
# n Terms: 3 | avg Jaccard sim: 0.917 | min Jaccard sim: 0.890 | n terms: 83
# n Terms: 9 | avg Jaccard sim: 0.933 | min Jaccard sim: 0.867 | n terms: 1040
# n Terms: 15 | avg Jaccard sim: 0.885 | min Jaccard sim: 0.797 | n terms: 1096
# n Terms: 2 | avg Jaccard sim: 0.929 | min Jaccard sim: 0.929 | n terms: 155
# n Terms: 2 | avg Jaccard sim: 0.943 | min Jaccard sim: 0.943 | n terms: 35
# n Terms: 3 | avg Jaccard sim: 0.985 | min Jaccard sim: 0.978 | n terms: 92
# n Terms: 4 | avg Jaccard sim: 0.921 | min Jaccard sim: 0.886 | n terms: 1851
# n Terms: 2 | avg Jaccard sim: 0.979 | min Jaccard sim: 0.979 | n terms: 96
# n Terms: 2 | avg Jaccard sim: 0.905 | min Jaccard sim: 0.905 | n terms: 105
# n Terms: 2 | avg Jaccard sim: 0.923 | min Jaccard sim: 0.923 | n terms: 65
# n Terms: 4 | avg Jaccard sim: 0.920 | min Jaccard sim: 0.884 | n terms: 704
# n Terms: 9 | avg Jaccard sim: 0.910 | min Jaccard sim: 0.870 | n terms: 683
# n Terms: 3 | avg Jaccard sim: 0.932 | min Jaccard sim: 0.904 | n terms: 167
# n Terms: 8 | avg Jaccard sim: 0.896 | min Jaccard sim: 0.852 | n terms: 516
# n Terms: 3 | avg Jaccard sim: 0.953 | min Jaccard sim: 0.930 | n terms: 57
# n Terms: 4 | avg Jaccard sim: 0.896 | min Jaccard sim: 0.845 | n terms: 85
# n Terms: 4 | avg Jaccard sim: 0.910 | min Jaccard sim: 0.891 | n terms: 2538
# n Terms: 3 | avg Jaccard sim: 0.906 | min Jaccard sim: 0.903 | n terms: 3259
# n Terms: 2 | avg Jaccard sim: 0.975 | min Jaccard sim: 0.975 | n terms: 1065
# n Terms: 6 | avg Jaccard sim: 0.916 | min Jaccard sim: 0.827 | n terms: 105
# n Terms: 2 | avg Jaccard sim: 0.915 | min Jaccard sim: 0.915 | n terms: 82
# n Terms: 3 | avg Jaccard sim: 0.936 | min Jaccard sim: 0.917 | n terms: 265
# n Terms: 2 | avg Jaccard sim: 0.921 | min Jaccard sim: 0.921 | n terms: 1019
# n Terms: 2 | avg Jaccard sim: 0.951 | min Jaccard sim: 0.951 | n terms: 41
# n Terms: 2 | avg Jaccard sim: 0.958 | min Jaccard sim: 0.958 | n terms: 24
# n Terms: 3 | avg Jaccard sim: 0.938 | min Jaccard sim: 0.929 | n terms: 141
# n Terms: 2 | avg Jaccard sim: 0.919 | min Jaccard sim: 0.919 | n terms: 62
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 27
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 13
# n Terms: 2 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.907 | n terms: 535
# n Terms: 2 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.907 | n terms: 75
# n Terms: 2 | avg Jaccard sim: 0.935 | min Jaccard sim: 0.935 | n terms: 46
# n Terms: 2 | avg Jaccard sim: 0.906 | min Jaccard sim: 0.906 | n terms: 85
# n Terms: 4 | avg Jaccard sim: 0.884 | min Jaccard sim: 0.850 | n terms: 63
# n Terms: 2 | avg Jaccard sim: 0.930 | min Jaccard sim: 0.930 | n terms: 373
# n Terms: 7 | avg Jaccard sim: 0.919 | min Jaccard sim: 0.860 | n terms: 1465
# n Terms: 2 | avg Jaccard sim: 0.966 | min Jaccard sim: 0.966 | n terms: 59
# n Terms: 12 | avg Jaccard sim: 0.920 | min Jaccard sim: 0.868 | n terms: 529
# n Terms: 6 | avg Jaccard sim: 0.943 | min Jaccard sim: 0.905 | n terms: 651
# n Terms: 6 | avg Jaccard sim: 0.887 | min Jaccard sim: 0.811 | n terms: 213
# n Terms: 2 | avg Jaccard sim: 0.942 | min Jaccard sim: 0.942 | n terms: 155
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 22
# n Terms: 7 | avg Jaccard sim: 0.925 | min Jaccard sim: 0.877 | n terms: 148
# n Terms: 2 | avg Jaccard sim: 0.960 | min Jaccard sim: 0.960 | n terms: 124
# n Terms: 3 | avg Jaccard sim: 0.900 | min Jaccard sim: 0.889 | n terms: 2462
# n Terms: 3 | avg Jaccard sim: 0.939 | min Jaccard sim: 0.934 | n terms: 202
# n Terms: 2 | avg Jaccard sim: 0.962 | min Jaccard sim: 0.962 | n terms: 132
# n Terms: 3 | avg Jaccard sim: 0.955 | min Jaccard sim: 0.934 | n terms: 151
# n Terms: 2 | avg Jaccard sim: 0.937 | min Jaccard sim: 0.937 | n terms: 271
# n Terms: 4 | avg Jaccard sim: 0.913 | min Jaccard sim: 0.864 | n terms: 246
# n Terms: 2 | avg Jaccard sim: 0.941 | min Jaccard sim: 0.941 | n terms: 17
# n Terms: 3 | avg Jaccard sim: 0.924 | min Jaccard sim: 0.901 | n terms: 143
# n Terms: 7 | avg Jaccard sim: 0.891 | min Jaccard sim: 0.808 | n terms: 622
# n Terms: 2 | avg Jaccard sim: 0.933 | min Jaccard sim: 0.933 | n terms: 357
# n Terms: 6 | avg Jaccard sim: 0.932 | min Jaccard sim: 0.895 | n terms: 592
# n Terms: 7 | avg Jaccard sim: 0.927 | min Jaccard sim: 0.868 | n terms: 308
# n Terms: 3 | avg Jaccard sim: 0.923 | min Jaccard sim: 0.903 | n terms: 221
# n Terms: 4 | avg Jaccard sim: 0.913 | min Jaccard sim: 0.899 | n terms: 356
# n Terms: 2 | avg Jaccard sim: 0.983 | min Jaccard sim: 0.983 | n terms: 117
# n Terms: 3 | avg Jaccard sim: 0.896 | min Jaccard sim: 0.882 | n terms: 186
# n Terms: 3 | avg Jaccard sim: 0.939 | min Jaccard sim: 0.909 | n terms: 22
# n Terms: 2 | avg Jaccard sim: 0.924 | min Jaccard sim: 0.924 | n terms: 251
# n Terms: 3 | avg Jaccard sim: 0.978 | min Jaccard sim: 0.967 | n terms: 91
# n Terms: 3 | avg Jaccard sim: 0.973 | min Jaccard sim: 0.959 | n terms: 49
# n Terms: 8 | avg Jaccard sim: 0.914 | min Jaccard sim: 0.877 | n terms: 600
# n Terms: 4 | avg Jaccard sim: 0.915 | min Jaccard sim: 0.870 | n terms: 197
# n Terms: 3 | avg Jaccard sim: 0.914 | min Jaccard sim: 0.884 | n terms: 95
# n Terms: 8 | avg Jaccard sim: 0.911 | min Jaccard sim: 0.852 | n terms: 185
# n Terms: 7 | avg Jaccard sim: 0.931 | min Jaccard sim: 0.882 | n terms: 200
# n Terms: 2 | avg Jaccard sim: 0.966 | min Jaccard sim: 0.966 | n terms: 295
# n Terms: 3 | avg Jaccard sim: 0.987 | min Jaccard sim: 0.980 | n terms: 99
# n Terms: 2 | avg Jaccard sim: 0.957 | min Jaccard sim: 0.957 | n terms: 235
# n Terms: 4 | avg Jaccard sim: 0.920 | min Jaccard sim: 0.880 | n terms: 147
# n Terms: 4 | avg Jaccard sim: 0.919 | min Jaccard sim: 0.884 | n terms: 71
# n Terms: 4 | avg Jaccard sim: 0.919 | min Jaccard sim: 0.903 | n terms: 334
# n Terms: 2 | avg Jaccard sim: 0.939 | min Jaccard sim: 0.939 | n terms: 33
# n Terms: 2 | avg Jaccard sim: 0.917 | min Jaccard sim: 0.917 | n terms: 2725
# n Terms: 4 | avg Jaccard sim: 0.927 | min Jaccard sim: 0.899 | n terms: 899
# n Terms: 2 | avg Jaccard sim: 0.914 | min Jaccard sim: 0.914 | n terms: 128
# n Terms: 2 | avg Jaccard sim: 0.981 | min Jaccard sim: 0.981 | n terms: 52
# n Terms: 3 | avg Jaccard sim: 0.922 | min Jaccard sim: 0.910 | n terms: 10099
# n Terms: 5 | avg Jaccard sim: 0.938 | min Jaccard sim: 0.876 | n terms: 105
# n Terms: 3 | avg Jaccard sim: 0.939 | min Jaccard sim: 0.927 | n terms: 123
# n Terms: 3 | avg Jaccard sim: 0.924 | min Jaccard sim: 0.919 | n terms: 988
# n Terms: 3 | avg Jaccard sim: 0.915 | min Jaccard sim: 0.908 | n terms: 235
# n Terms: 3 | avg Jaccard sim: 0.887 | min Jaccard sim: 0.849 | n terms: 140
# n Terms: 3 | avg Jaccard sim: 0.927 | min Jaccard sim: 0.909 | n terms: 56
# n Terms: 2 | avg Jaccard sim: 0.905 | min Jaccard sim: 0.905 | n terms: 262
# n Terms: 4 | avg Jaccard sim: 0.924 | min Jaccard sim: 0.895 | n terms: 2187
# n Terms: 2 | avg Jaccard sim: 0.962 | min Jaccard sim: 0.962 | n terms: 26
# n Terms: 3 | avg Jaccard sim: 0.911 | min Jaccard sim: 0.884 | n terms: 261
# n Terms: 2 | avg Jaccard sim: 0.907 | min Jaccard sim: 0.907 | n terms: 915
# n Terms: 3 | avg Jaccard sim: 0.936 | min Jaccard sim: 0.930 | n terms: 533
# n Terms: 2 | avg Jaccard sim: 0.916 | min Jaccard sim: 0.916 | n terms: 1067
# n Terms: 5 | avg Jaccard sim: 0.932 | min Jaccard sim: 0.894 | n terms: 186
# n Terms: 2 | avg Jaccard sim: 0.911 | min Jaccard sim: 0.911 | n terms: 338
# n Terms: 2 | avg Jaccard sim: 0.941 | min Jaccard sim: 0.941 | n terms: 34
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 27
# n Terms: 3 | avg Jaccard sim: 0.940 | min Jaccard sim: 0.926 | n terms: 710
# n Terms: 2 | avg Jaccard sim: 0.975 | min Jaccard sim: 0.975 | n terms: 40
# n Terms: 3 | avg Jaccard sim: 0.941 | min Jaccard sim: 0.933 | n terms: 46
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 14
# n Terms: 2 | avg Jaccard sim: 0.909 | min Jaccard sim: 0.909 | n terms: 66
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 22
# n Terms: 2 | avg Jaccard sim: 0.958 | min Jaccard sim: 0.958 | n terms: 24
# n Terms: 2 | avg Jaccard sim: 0.926 | min Jaccard sim: 0.926 | n terms: 1318
# n Terms: 2 | avg Jaccard sim: 0.911 | min Jaccard sim: 0.911 | n terms: 146
# n Terms: 3 | avg Jaccard sim: 0.903 | min Jaccard sim: 0.869 | n terms: 162
# n Terms: 3 | avg Jaccard sim: 0.934 | min Jaccard sim: 0.913 | n terms: 103
# n Terms: 2 | avg Jaccard sim: 0.967 | min Jaccard sim: 0.967 | n terms: 60
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 22
# n Terms: 3 | avg Jaccard sim: 0.895 | min Jaccard sim: 0.855 | n terms: 195
# n Terms: 2 | avg Jaccard sim: 1.000 | min Jaccard sim: 1.000 | n terms: 25
# n Terms: 2 | avg Jaccard sim: 0.928 | min Jaccard sim: 0.928 | n terms: 748
# n Terms: 2 | avg Jaccard sim: 0.963 | min Jaccard sim: 0.963 | n terms: 27
# n Terms: 3 | avg Jaccard sim: 0.924 | min Jaccard sim: 0.912 | n terms: 834
# n Terms: 2 | avg Jaccard sim: 0.943 | min Jaccard sim: 0.943 | n terms: 123
# n Terms: 2 | avg Jaccard sim: 0.913 | min Jaccard sim: 0.913 | n terms: 104
# n Terms: 2 | avg Jaccard sim: 0.919 | min Jaccard sim: 0.919 | n terms: 236
# n Terms: 3 | avg Jaccard sim: 0.903 | min Jaccard sim: 0.877 | n terms: 396
# n Terms: 2 | avg Jaccard sim: 0.938 | min Jaccard sim: 0.938 | n terms: 227
# n Terms: 2 | avg Jaccard sim: 0.906 | min Jaccard sim: 0.906 | n terms: 127
# n Terms: 3 | avg Jaccard sim: 0.913 | min Jaccard sim: 0.895 | n terms: 291
# n Terms: 2 | avg Jaccard sim: 0.949 | min Jaccard sim: 0.949 | n terms: 39
# n Terms: 2 | avg Jaccard sim: 0.944 | min Jaccard sim: 0.944 | n terms: 18
# n Terms: 2 | avg Jaccard sim: 0.964 | min Jaccard sim: 0.964 | n terms: 168
# n Terms: 2 | avg Jaccard sim: 0.916 | min Jaccard sim: 0.916 | n terms: 202
# n Terms: 2 | avg Jaccard sim: 0.942 | min Jaccard sim: 0.942 | n terms: 1140
# n Terms: 2 | avg Jaccard sim: 0.950 | min Jaccard sim: 0.950 | n terms: 20
# n Terms: 2 | avg Jaccard sim: 0.960 | min Jaccard sim: 0.960 | n terms: 101
# n Terms: 2 | avg Jaccard sim: 0.944 | min Jaccard sim: 0.944 | n terms: 144
# n Terms: 2 | avg Jaccard sim: 0.902 | min Jaccard sim: 0.902 | n terms: 92
# n New Fields: 8210 | n Old Fields: 9535

# %%
def short_to_long(data_short):
    doculects = data_short.doculect.unique()
    index = 0
    colnames = []
    matrix = np.zeros((len(data_short),0)).astype(int)
    for doc in map(lambda k: 'imputed_' + k, doculects):
        ct = {ei : i for i,ei in enumerate(filter(lambda k : isinstance(k, str), data_short[doc].unique()))}
        matrix = np.hstack([matrix, np.zeros((len(data_short),len(ct)))])
        for ei,i in ct.items():
            colnames.append(doc + '|' + ei)
            matrix[:,index+i] = (np.array(data_short[doc] == ei).astype(int))#[int(e==ei) for e in data_short[doc]]
        index += len(ct)
    data_long = pd.DataFrame(matrix, columns=colnames)
    return data_long

# %%
def get_pc1(fn):
    identifier = os.getpid()
    subprocess.call(['Rscript', 'exppca.R', fn, str(identifier), 'logisticSVD', str(1)])
    model = rdata.conversion.convert(rdata.parser.parse_file('%s.rda' % identifier))['model']
    subprocess.call(['rm', '%s.rda' % identifier])
    return model

# %%
pickle.dump((new_anchors,new_fields), open('%s/fields.p' % pickle_dir, 'wb'))

# %%
def parallel_pca(x, boolean):
    doc, marker = x
    if os.path.isfile('%s/pcaspace_%s_%s.p' % (pcaspace_dir, doc, marker)): 
        return
    df_short = df_sub[boolean]
    df_long = short_to_long(df_short)
    good_columns = df_long.columns[(df_long.sum(0) > 0) & (df_long.sum(0) < len(df_long))]
    if len(good_columns) == 0: return
    fn = '%s/termspace_%s_%s.csv' % (pcaspace_dir, doc, marker)
    df_long[good_columns].to_csv(fn, index=False)
    #
    try: model = get_pc1(fn)
    except: model = None
    #
    subprocess.call(['rm', '%s/termspace_%s_%s.csv' % (pcaspace_dir, doc, marker)])
    if model != None: 
        pickle.dump(model, open('%s/pcaspace_%s_%s.p' % (pcaspace_dir, doc, marker), 'wb'))
        print(doc, marker, model['prop_deviance_expl'][0], datetime.now())

try: os.mkdir(pcaspace_dir)
except: pass
with Pool(8) as p:
    p.starmap(parallel_pca, zip(map(lambda k : k[0], new_anchors), new_fields))
# Out:
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error: TridiagEigen: eigen decomposition failed
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# ngal1292 h-bobon 0.2613770493916292 2024-03-25 14:08:49.257895
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# sout2856 ^atua$ 0.25482718858717945 2024-03-25 15:01:09.997490
# sout2856 ^runomser$ 0.22599746783189212 2024-03-25 15:01:12.008139
# Error in fun(A, k, nu, nv, opts, mattype = "matrix") :
#   nrow(A) and ncol(A) should be at least 3
# Calls: logisticSVD -> <Anonymous> -> <Anonymous> -> svds.matrix -> fun
# Execution halted
# sout2856 ^kemalik$ 0.22054541852143672 2024-03-25 15:01:15.369484
# sout2856 ^nanwei$ 0.3431931217153814 2024-03-25 15:01:16.183598
# sout2856 arik$ 0.3425708731518451 2024-03-25 15:01:17.250083
# sout2856 ^apa$ 0.19894229347553327 2024-03-25 15:01:21.179159
# sout2856 ^rufatlasik$ 0.40817154369577724 2024-03-25 15:01:22.221690
# sout2856 slat 0.18019646981056647 2024-03-25 15:01:40.418394
# sout2856 pa$ 0.1814903867323291 2024-03-25 15:01:44.604132
# sout2856 sat 0.2765659388136694 2024-03-25 15:01:45.347315
# sout2856 sel$ 0.22943832855322088 2024-03-25 15:01:46.412023
# sout2856 pl 0.24517975092438993 2024-03-25 15:01:47.204529
# sout2856 saiki$ 0.18918674476760144 2024-03-25 15:01:48.611128
# sout2856 san$ 0.24019363027235885 2024-03-25 15:01:49.593586
# sout2856 naor$ 0.2557413170051501 2024-03-25 15:01:50.591244
# sout2856 ^nel$ 0.1479931273613747 2024-03-25 15:01:54.848723
# sout2856 auswen$ 0.38039710661965254 2024-03-25 15:01:56.899140
# sout2856 ^nafs 0.5680763799237447 2024-03-25 15:01:57.708542
# sout2856 erek 0.6658432793723953 2024-03-25 15:01:58.558194
# sout2856 ^tangkiu$ 0.28108585944995956 2024-03-25 15:02:00.035728
# sout2856 ^kanrus$ 0.31930015957429325 2024-03-25 15:02:00.848834
# sout2856 ^seserik$ 0.8435615885700349 2024-03-25 15:02:01.579398
# sout2856 ^108-009$ 0.1593480601547912 2024-03-25 15:02:03.542275
# sout2856 ^teesa$ 0.37385346777926043 2024-03-25 15:02:33.404788
# sout2856 ^traus 0.2640791715620455 2024-03-25 15:02:34.568142
# sout2856 nrik 0.28160620385622537 2024-03-25 15:02:38.517138
# sout2856 til 0.23887559680277748 2024-03-25 15:02:39.505336
# sout2856 tra 0.6413616819203323 2024-03-25 15:02:40.327692
# sout2856 ^mal$ 0.2028788568845704 2024-03-25 15:02:42.375465
# sout2856 nrak$ 0.2877263176299356 2024-03-25 15:02:43.522269
# sout2856 ^sol$ 0.35615606976404746 2024-03-25 15:03:25.283180
# sout2856 ^telekor$ 0.25334867892653024 2024-03-25 15:03:26.165723
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_895546/1123051807.py", line 10, in parallel_pca
#     df_long[good_columns].to_csv(fn, index=False)
#   File "/home/barend/.local/lib/python3.10/site-packages/pandas/core/generic.py", line 3902, in to_csv
#     return DataFrameRenderer(formatter).to_csv(
#   File "/home/barend/.local/lib/python3.10/site-packages/pandas/io/formats/format.py", line 1152, in to_csv
#     csv_formatter.save()
#   File "/home/barend/.local/lib/python3.10/site-packages/pandas/io/formats/csvs.py", line 247, in save
#     with get_handle(
#   File "/home/barend/.local/lib/python3.10/site-packages/pandas/io/common.py", line 739, in get_handle
#     check_parent_directory(str(handle))
#   File "/home/barend/.local/lib/python3.10/site-packages/pandas/io/common.py", line 604, in check_parent_directory
#     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
# OSError: Cannot save file into a non-existent directory: 'pickles/pcaspaces/termspace_goro1270_^na'
# """
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 23
#      21 except: pass
#      22 with Pool(8) as p:
# ---> 23     p.starmap(parallel_pca, zip(map(lambda k : k[0], new_anchors), new_fields))
#
# File /usr/lib/python3.10/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File /usr/lib/python3.10/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# OSError: Cannot save file into a non-existent directory: 'pickles/pcaspaces/termspace_goro1270_^na'

# %% [markdown]
# ## analysis

# %%
def get_ig(sorted_terms):
    H = entropy(list(Counter(sorted_terms).values()))
    max_ig = None, 0
    for i in range(1,len(sorted_terms)-1):
        A,B = sorted_terms[:i], sorted_terms[i:]
        Ha, Hb = entropy(list(Counter(A).values())), entropy(list(Counter(B).values()))
        IG = H - ((Ha * (i/len(sorted_terms))) + (Hb * (1-i/len(sorted_terms))))
        if IG > max_ig[1]: max_ig = i, IG
    return max_ig[1]

# %%
concreteness_file = '../metaphor/bert_exploration/13428_2013_403_MOESM1_ESM.xlsx'
conc_data = pd.read_excel(concreteness_file)
conc_dict = {r.Word : r['Conc.M'] for i,r in conc_data.iterrows()}
#
models = { 'knn@3' : KNeighborsClassifier(n_neighbors=3),
           'knn@5' : KNeighborsClassifier(n_neighbors=5),
           'SVC' : SVC(C=1) }

quantile_boundary_values = [0.10, 0.25, 0.5]
predictor_variables = ['std','range','iqr','log_fpm', 'concreteness'] + ['%d_balance' % (100*q) for q in quantile_boundary_values]

# %%
doreco_metadata
# Out:
#                        Language Glottocode iso-639-3  \
# 0                          Anal   anal1239       anm
# 1             Yali (Apahapsili)   apah1238        na
# 2                       Arapaho   arap1274       arp
# 3             Baïnounk Gubëeher   bain1259       bab
# 4                          Beja   beja1238       bej
# 5                          Bora   bora1263       boa
# 6                       Cabécar   cabe1245       cjp
# 7                    Cashinahua   cash1254       cbs
# 8                        Dolgan   dolg1241       dlg
# 9                        Evenki   even1259       evn
# 10                       Goemai   goem1240       ank
# 11                       Gorwaa   goro1270       gow
# 12                       Hoocąk   hoch1243       win
# 13                        Jahai   jeha1242       jhi
# 14                       Jejuan   jeju1234       jje
# 15                       Kakabe   kaka1265       kke
# 16                        Kamas   kama1351       xas
# 17                Tabaq (Karko)   kark1256       kko
# 18                       Komnzo   komn1238       tci
# 19               Light Warlpiri   ligh1234        na
# 20                Lower Sorbian   lowe1385       dsb
# 45  Skopeteas, Stavros and Moisidi, Violeta and Ts...     42.04      43.99
# 46                                    Schnell, Stefan    -13.89     167.43
# 47                                O'Shannessy, Carmel    -20.10     131.05
# 48                                    Michaud, Alexis     27.80     100.90
# 49                                 Skopeteas, Stavros     18.78     -88.96
# 50      Gipper, Sonja and Ballivián Torrico, Jeremías    -16.75     -65.12
#
#           Archive  ... Audio license                    DOI Gloss  \
# 0            ELAR  ...      CC BY-NC  10.34847/nkl.0dbazp8m  none
# 1             TLA  ...   CC BY-NC-SA  10.34847/nkl.9d91nkq2   all
# 2            ELAR  ...         CC BY  10.34847/nkl.36f5r1b6   all
# 3            ELAR  ...         CC BY  10.34847/nkl.a332abw8  some
# 4     CorpoAfroas  ...      CC BY-NC  10.34847/nkl.edd011t1   all
# 5             TLA  ...         CC BY  10.34847/nkl.6eaf5laq   all
# 6             TLA  ...   CC BY-NC-ND  10.34847/nkl.ebc4ra22   all
# 7             TLA  ...         CC BY  10.34847/nkl.a8f9q2f1  some
# 8            HZSK  ...      CC BY-NC  10.34847/nkl.f09eikq3   all
# 9   Siberian Lang  ...         CC BY  10.34847/nkl.5e0d27cu   all
# 10            TLA  ...  audio linked  10.34847/nkl.b93664ml   all
# 11           ELAR  ...         CC BY  10.34847/nkl.a4b4ijj2   all
# 12            TLA  ...  audio linked  10.34847/nkl.b57f5065   all
# 13     RWAAI: TLA  ...   CC BY-NC-ND  10.34847/nkl.6a71xp0p  some
# 14           ELAR  ...         CC BY  10.34847/nkl.06ebrk38   all
# 15           ELAR  ...         CC BY  10.34847/nkl.d5aeu9t6   all
# 16           INEL  ...         CC BY  10.34847/nkl.cdd8177b   all
# 17           ELAR  ...  audio linked  10.34847/nkl.eea8144j  none
# 18         Zenodo  ...         CC BY  10.34847/nkl.c5e6dudv   all
# 19            TLA  ...   CC BY-NC-ND  10.34847/nkl.7452803q  none
# 20            TLA  ...  audio linked  10.34847/nkl.6c6e4e9k  none
# 21            TLA  ...  audio linked  10.34847/nkl.da42xf67   all
# 22            TLA  ...         CC BY  10.34847/nkl.fae299ug  some
# 23       Ortolang  ...   CC BY-NC-ND  10.34847/nkl.2801565f   all
# 24             na  ...         CC BY  10.34847/nkl.f6c37fi0   all
# 25     Multi-CAST  ...         CC BY  10.34847/nkl.ca10ez5t   all
# 26           ELAR  ...   CC BY-NC-ND  10.34847/nkl.efea0b36   all
# 27           ELAR  ...         CC BY  10.34847/nkl.02084446  some
# 28     NTU; RWAAI  ...      CC BY-NC  10.34847/nkl.5ba1062k   all
# 29             na  ...         CC BY  10.34847/nkl.efeav5l9  some
# 30            TLA  ...         CC BY  10.34847/nkl.ffb96lo8  none
# 31             na  ...         CC BY  10.34847/nkl.fde4pp1u   all
# 32           ELAR  ...         CC BY  10.34847/nkl.3db4u59d  none
# 33            TLA  ...         CC BY  10.34847/nkl.81934177  some
# 34            TLA  ...         CC BY  10.34847/nkl.b74d1b33   all
# 35      Paradisec  ...   CC BY-NC-SA  10.34847/nkl.ba4f760l   all
# 36     Multi-CAST  ...         CC BY  10.34847/nkl.9c271u5g   all
# 37             na  ...   CC BY-NC-SA  10.34847/nkl.3520l685   all
# 38      Paradisec  ...         CC BY  10.34847/nkl.5ad4t01p   all
# 39            TLA  ...         CC BY  10.34847/nkl.9ba054c3  none
# 40     Multi-CAST  ...         CC BY  10.34847/nkl.ad7f97xr   all
# 41            TLA  ...         CC BY  10.34847/nkl.9322sdf2   all
# 42             na  ...         CC BY  10.34847/nkl.c50ck58f   all
# 43             na  ...         CC BY  10.34847/nkl.cbc3b4xr  some
# 44           ELAR  ...         CC BY  10.34847/nkl.f77c7m72  none
# 45            TLA  ...   CC BY-NC-ND  10.34847/nkl.ac166n10   all
# 46            TLA  ...         CC BY  10.34847/nkl.3e2cu8c4   all
# 47            TLA  ...   CC BY-NC-ND  10.34847/nkl.042dv614  none
# 48       Pangloss  ...   CC BY-NC-SA  10.34847/nkl.abe65p95  none
# 49            TLA  ...   CC BY-NC-ND  10.34847/nkl.9cbb3619  none
# 50            LAC  ...  audio linked  10.34847/nkl.7ca412wg  none
#
#    Extended speakers Extended word tokens Extended texts  Core speakers  \
# 0                 12                13015             23             12
# 1                 14                10191             11             10
# 2                  8                10407             21              4
# 3                 10                12425             18              9
# 4                  5                15439             58              5
# 5                 39                29578             38              6
# 6                 15                17961            115             10
# 7                  3                10043              3              3
# 8                 20                18966             25              6
# 9                 23                 8315             36             23
# 10                 6                25304             27              5
# 11                11                19688             14              8
# 12                11                 7338             21             11
# 13                 3                 7330              9              3
# 14                 5                 7272              8              5
# 15                18                46656             23              4
# 16                 2                40298            131              1
# 17                 5                 9265             16              5
# 18                26                33909             49             11
# 19                 6                 8672              8              6
# 20                 4                10246             15              4
# 21                 5                10183             12              5
# 22                 4                 3412             10              4
# 23                 8                11872             12              8
# 24                 7                28005             33              6
# 25                 2                 9658              5              2
# 26                 2                 8544              4              2
# 27                14                19131             39             10
# 28                19                20454             21              6
# 29                10                12038             16             10
# 30                 3                 7985             20              3
# 31                 7                 8718              5              7
# 32                 6                12019             13              6
# 33                 5                 5146              9              5
# 34                 7                12075              7              7
# 35                19                29414             63             12
# 36                 4                35441              8              2
# 37                 8                13339              8              8
# 38                26                12838             35             23
# 39                 9                 9895             28              9
# 40                 2                 5059              5              2
# 41                11                12148             11             11
# 42                 1                 8473              4              1
# 43                21                18336             32              6
# 44                12                 8784             40             12
# 45                32                18802            246             30
# 46                10                17794             11              7
# 47                18                 7171             22             18
# 48                 1                 8877              6              1
# 49                 6                10857             10              6
# 50                16                20206             20             16
#
#     core word tokens  Core texts  Years of recordings in core set
# 0              13015          23                        2015-2016
# 1               7474           8                        2013-2017
# 2               4746          11                             2005
# 3              11477          17                        2009-2014
# 4              15439          58                        2003-2011
# 5               8431           9                        2004-2008
# 6              10614          39                             2011
# 7              10043           3                             2006
# 8               8778           9                        1972-2010
# 9               8315          36                        2006-2016
# 10              9340          11                        1999-2000
# 11             10674           9                        2013-2016
# 12              7338          21                        2003-2012
# 13              7330           9                        2000-2012
# 14              7272           8                             2015
# 15              9525           9                        2013-2015
# 16             10052          26                        1964-1970
# 17              9265          16                        2011-2013
# 18              9892          19                        2010-2015
# 19              8672           8                        2005-2015
# 20             10246          15                        2011-2013
# 21             10183          12                        2002-2014
# 22              3412          10                        2010-2012
# 23             11872          12                        2011-2015
# 24             10283          17                        2004-2009
# 25              9658           5                        2000-2004
# 26              8544           4                             2016
# 27             10170          26                        2015-2017
# 28              8520           8                        2011-2012
# 29             12038          16                        2010-2018
# 30              7985          20                        2004-2009
# 31              8718           5                        2012-2019
# 32             12019          13                        2010-2013
# 33              5146           9                        2011-2013
# 34             12075           7                        2003-2008
# 35             10243          30                        1997-2000
# 36              8998           2                        1975-1985
# 37             13339           8                        2014-2015
# 38              9981          28                             2010
# 39              9895          28                             2012
# 40              5059           5                             2010
# 41             12148          11                        2003-2004
# 42              8473           4                             1993
# 43              7792          10                        2005-2018
# 44              8784          40                        2015-2017
# 45             10035         132                             2015
# 46             12380           8                             2007
# 47              7171          22                        2004-2010
# 48              8877           6                        2006-2012
# 49             10857          10                             2015
# 50             20206          20                             2013
#
# [51 rows x 23 columns]

# %%
builder = []
for ai,(A, f) in enumerate(zip(new_anchors, new_fields)):
    df_ai = df_sub[f]
    translations = ['%s (%.1f%%)' % (k,100*v/len(df_ai)) for k,v in Counter(df_ai.term).most_common(3)]    
    #
    print(ai, len(df_ai), A[0], translations)
    #
    if next((False for t in df_ai.term.unique() if t in conc_dict),True):
        print('  *no concreteness scores'); continue
    field_concreteness = np.mean([conc_dict[k] for k,v in Counter(df_ai.term).items() if k in conc_dict for i in range(v)])
    #
    try: model = pickle.load(open(pcaspace_dir + 'pcaspace_' + A[0][0] + '_' + A[0][1] + '.p', 'rb'))
    except: continue
    good_docs = [k for k,v in Counter(df_ai.doculect).most_common() if v >= min_n_tokens] # min 20 tokens
    #
    space = model['A'][:,0]
    space = 2 * ((space - space.min()) / (space.max() - space.min())) - 1 # this places the PC space in [-1,1]
    quantile_boundaries = {i : (np.quantile(space, i), np.quantile(space, 1-i)) for i in quantile_boundary_values}
    #
    per_field_builder = []
    for doc in good_docs:
        observed = (df_ai.doculect == doc) & ~pd.isna(df_ai.marker)
        markers = df_ai[observed].marker
        space_doc = space[observed]
        if len(space_doc) < 1: continue
        if min(space_doc) > quantile_boundaries[0.25][0] or max(space_doc) < quantile_boundaries[0.25][1]: continue
        sorted_terms = list(zip(*sorted(zip(markers, space_doc), key = lambda k : k[1])))[0]
        row = {'doculect' : doc, 'field' : ai, 'concreteness' : field_concreteness }
        # PREDICTED VARIABLES:
        row['ig'] = get_ig(sorted_terms)
        #print('  ', doc, space_doc.reshape(-1,1).shape, markers.shape)
        for model_name, model in models.items():
            if len(set(markers)) == 1: row['colexified_%s' % model_name] = 1
            else:
                model.fit(space_doc.reshape(-1,1), markers)
                row['colexified_%s' % model_name] = int(model.predict([[-1]])[0] == model.predict([[+1]])[0])
        # PREDICTOR VARIABLES:
        row['std'] = np.std(space_doc)
        row['range'] = max(space_doc) - min(space_doc)
        row['iqr'] = np.quantile(space_doc, 0.75) - np.quantile(space_doc,0.25)
        row['log_fpm'] = np.log(1e6*len(markers)/tot_wc[doc])
        for q,(lo,hi) in quantile_boundaries.items():
            neg = sorted_terms[:sum(space_doc < lo)]
            pos = sorted_terms[-sum(space_doc >= hi):]
            row['%d_balance' % (100*q)] = 2*min(len(neg),len(pos))/(len(neg)+len(pos))
        per_field_builder.append(row)
    #

    #
    n_colex = sum(r['colexified_SVC'] for r in per_field_builder)
    n_dislex = len(per_field_builder)-n_colex
    if n_colex >= 0 and n_dislex >= 0: # Makes sure there are at least languages that colexify and ones that dislexify
        print('  sufficient variation (%d colex / %d dislex)' % (n_colex, n_dislex))
        mu_std = { m : (np.mean([r[m] for r in per_field_builder]),np.std([r[m] for r in per_field_builder]))
                  for m in predictor_variables }
        for i in range(len(per_field_builder)):
            for m in predictor_variables:
                per_field_builder[i]['offset_' + m] = ((per_field_builder[i][m]-mu_std[m][0])/(mu_std[m][1])) if mu_std[m][1] > 1e-9 else 0
        builder.extend(per_field_builder)
    else: print('  *insufficient variation (%d colex / %d dislex)' % (n_colex, n_dislex))
df_stats = pd.DataFrame(builder)
# Out:
# 0 6388 ('anal1239', 'do') ['say (99.1%)', 'think (0.6%)', 'mean (0.1%)']
#   sufficient variation (25 colex / 11 dislex)
# 1 1650 ('anal1239', 'da') ['say (97.4%)', 'mean (0.8%)', 'talk (0.7%)']
#   sufficient variation (10 colex / 3 dislex)
# 2 98 ('anal1239', 'the') ['say (96.9%)', 'talk (2.0%)', 'speak (1.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 3 1258 ('anal1239', '^ju') ['go (96.4%)', 'move (1.5%)', 'get (1.3%)']
#   sufficient variation (15 colex / 3 dislex)
# 4 2756 ('anal1239', 'cho') ['go (96.6%)', 'set (1.2%)', 'stay (0.8%)']
#   sufficient variation (24 colex / 14 dislex)
# 5 1500 ('anal1239', 'vang') ['go (98.3%)', 'move (0.6%)', 'walk (0.5%)']
#   sufficient variation (21 colex / 1 dislex)
# 6 2200 ('anal1239', '^ha') ['go (81.5%)', 'get (8.0%)', 'move (4.9%)']
#   sufficient variation (2 colex / 25 dislex)
# 7 269 ('anal1239', '^vaj') ['go (95.2%)', 'get (1.9%)', 'stay (1.5%)']
#   sufficient variation (0 colex / 3 dislex)
# 8 306 ('anal1239', 'ahung$') ['go (96.4%)', 'get (2.9%)', 'pass (0.3%)']
#   sufficient variation (3 colex / 2 dislex)
# 9 861 ('anal1239', '^akho') ['stay (76.4%)', 'go (13.4%)', 'remain (4.6%)']
#   sufficient variation (2 colex / 11 dislex)
# 10 169 ('anal1239', '^itho') ['go (56.8%)', 'dead (31.4%)', 'pass (3.0%)']
#   sufficient variation (0 colex / 1 dislex)
# 11 411 ('anal1239', 'pathi') ['leave (98.8%)', 'go (1.0%)', 'flee (0.2%)']
#   sufficient variation (5 colex / 1 dislex)
# 12 39 ('anal1239', '^hung') ['move (17.9%)', 'pass (12.8%)', 'work (10.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 13 1433 ('anal1239', '^avang') ['come (87.2%)', 'return (6.6%)', 'arrive (4.1%)']
#   sufficient variation (8 colex / 15 dislex)
# 14 1547 ('anal1239', '^ahang') ['come (92.7%)', 'arrive (4.9%)', 'get (0.3%)']
#   sufficient variation (10 colex / 14 dislex)
# 15 361 ('anal1239', '^aju') ['come (87.0%)', 'bring (7.2%)', 'become (1.4%)']
#   sufficient variation (0 colex / 4 dislex)
# 16 1080 ('anal1239', 'thin') ['come (79.4%)', 'arrive (19.3%)', 'bring (0.7%)']
#   sufficient variation (11 colex / 8 dislex)
# 17 710 ('anal1239', 'ahung') ['come (97.6%)', 'bring (1.1%)', 'get (1.0%)']
#   sufficient variation (6 colex / 2 dislex)
# 18 376 ('anal1239', 'vang$') ['come (90.2%)', 'arrive (2.9%)', 'bring (2.7%)']
#   sufficient variation (1 colex / 3 dislex)
# 19 425 ('anal1239', 'ele') ['return (78.1%)', 'come (18.4%)', 'arrive (1.6%)']
#   sufficient variation (2 colex / 1 dislex)
# 20 248 ('anal1239', '^mavati$') ['time (37.1%)', 'long (35.9%)', 'come (15.7%)']
#   sufficient variation (0 colex / 3 dislex)
# 21 931 ('anal1239', '^vanu') ['mother (95.6%)', 'father (1.2%)', 'grandmother (1.1%)']
#   sufficient variation (13 colex / 4 dislex)
# 22 130 ('anal1239', '^kanu') ['mother (99.2%)', 'mom (0.8%)']
#   sufficient variation (1 colex / 0 dislex)
# 23 254 ('anal1239', '^chakaning$') ['think (42.5%)', 'jump (11.4%)', 'want (6.3%)']
#   sufficient variation (0 colex / 1 dislex)
# 24 1804 ('anal1239', 'acha$') ['eat (95.9%)', 'drink (0.7%)', 'serve (0.4%)']
#   sufficient variation (13 colex / 14 dislex)
# 25 117 ('anal1239', '^icha$') ['eat (88.9%)', 'cook (2.6%)', 'serve (1.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 26 15 ('anal1239', 'bal') ['eat (73.3%)', 'chew (6.7%)', 'pick (6.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 27 128 ('anal1239', 'asal') ['eat (71.1%)', 'ask (25.0%)', 'want (2.3%)']
#   sufficient variation (0 colex / 1 dislex)
# 28 1141 ('anal1239', 'ape') ['give (98.1%)', 'bring (1.1%)', 'hand (0.3%)']
#   sufficient variation (10 colex / 6 dislex)
# 29 67 ('anal1239', '^vatho$') ['give (98.5%)', 'bear (1.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 30 211 ('anal1239', '^tho') ['dead (38.4%)', 'give (37.0%)', 'sick (6.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 31 796 ('anal1239', '^alal$') ['man (67.8%)', 'young (25.4%)', 'old (2.0%)']
#   sufficient variation (2 colex / 12 dislex)
# 32 1465 ('anal1239', 'pa$') ['man (99.4%)', 'guy (0.3%)', 'mango (0.2%)']
#   sufficient variation (8 colex / 11 dislex)
# 33 56 ('anal1239', '^amaputhi$') ['man (85.7%)', 'man! (5.4%)', 'manner (3.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 34 65 ('anal1239', '^vangsang$') ['sow (12.3%)', 'ox (6.2%)', 'irrigate (6.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 35 860 ('anal1239', '^tepang$') ['person (36.7%)', 'do (30.6%)', 'human (12.9%)']
#   sufficient variation (0 colex / 12 dislex)
# 36 149 ('anal1239', 'gtho') ['king (75.8%)', 'chief (17.4%)', 'ruler (4.0%)']
#   sufficient variation (2 colex / 0 dislex)
# 37 27 ('anal1239', '^aruwng') ['king (88.9%)', 'chief (11.1%)']
# 38 8 ('anal1239', 'hki') ['king (100.0%)']
# 39 2144 ('anal1239', '^li') ['take (69.2%)', 'marry (14.5%)', 'wedding (4.2%)']
#   sufficient variation (5 colex / 18 dislex)
# 40 530 ('anal1239', 'thu$') ['take (83.8%)', 'bring (11.7%)', 'pick (1.9%)']
#   sufficient variation (2 colex / 7 dislex)
# 41 226 ('anal1239', 'uw$') ['take (95.6%)', 'pick (2.7%)', 'turn (0.9%)']
#   sufficient variation (0 colex / 1 dislex)
# 42 192 ('anal1239', '^asu') ['tell (89.6%)', 'take (3.6%)', 'hold (3.1%)']
#   sufficient variation (1 colex / 0 dislex)
# 43 1594 ('anal1239', 'ning') ['tell (96.9%)', 'warn (0.9%)', 'speak (0.5%)']
#   sufficient variation (8 colex / 12 dislex)
# 44 820 ('komn1238', '?e.mo') ['girl (76.3%)', 'daughter (10.1%)', 'boy (6.1%)']
#   sufficient variation (2 colex / 8 dislex)
# 45 154 ('anal1239', '^matum') ['young (68.8%)', 'girl (17.5%)', 'small (5.8%)']
#   sufficient variation (1 colex / 0 dislex)
# 46 589 ('anal1239', 'too$') ['do (99.7%)', 'donkey (0.3%)']
#   sufficient variation (12 colex / 1 dislex)
# 47 401 ('anal1239', '^chaka') ['do (99.8%)', 'sow (0.2%)']
#   sufficient variation (4 colex / 0 dislex)
# 48 477 ('anal1239', '^apalung$') ['do (31.4%)', 'think (14.3%)', 'work (11.5%)']
#   sufficient variation (0 colex / 8 dislex)
# 49 283 ('anal1239', '^kado') ['do (63.3%)', 'speak (9.2%)', 'play (6.4%)']
#   sufficient variation (0 colex / 1 dislex)
# 50 540 ('anal1239', '^arang') ['time (59.8%)', 'day (10.6%)', 'past (8.7%)']
#   sufficient variation (3 colex / 5 dislex)
# 51 689 ('anal1239', '^asan') ['time (70.1%)', 'day (13.8%)', 'long (8.7%)']
#   sufficient variation (2 colex / 5 dislex)
# 52 147 ('anal1239', 'mpi') ['tiger (83.7%)', 'devil (12.2%)', 'cyclone (2.0%)']
#   sufficient variation (2 colex / 0 dislex)
# 53 67 ('anal1239', '^vacha$') ['harvest (14.9%)', 'farm (13.4%)', 'seed (9.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 54 3083 ('nisv1234', 'ren$') ['people (70.8%)', 'man (8.6%)', 'person (6.9%)']
#   sufficient variation (4 colex / 31 dislex)
# 55 82 ('anal1239', 'atang') ['trap (65.9%)', 'hole (13.4%)', 'hiding (12.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 56 270 ('anal1239', 'changva') ['fish (90.4%)', 'trap (3.3%)', 'shellfish (3.3%)']
#   sufficient variation (0 colex / 4 dislex)
# 57 12 ('anal1239', 'min$') ['trap (50.0%)', 'stick (41.7%)', 'sink (8.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 58 1136 ('anal1239', 'asu') ['look (94.3%)', 'think (1.8%)', 'feel (0.6%)']
#   sufficient variation (10 colex / 12 dislex)
# 59 176 ('anal1239', 'hrung') ['look (43.2%)', 'guard (9.7%)', 'hold (5.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 60 239 ('anal1239', '^peem$') ['different (21.3%)', 'big (20.1%)', 'wear (18.0%)']
#   sufficient variation (0 colex / 1 dislex)
# 61 488 ('anal1239', 'on$') ['call (99.4%)', 'summon (0.4%)', 'ring (0.2%)']
#   sufficient variation (2 colex / 2 dislex)
# 62 106 ('anal1239', '^angnar$') ['call (84.9%)', 'build (6.6%)', 'establish (3.8%)']
#   sufficient variation (1 colex / 0 dislex)
# 63 394 ('anal1239', '^no$') ['call (70.8%)', 'friend (24.4%)', 'hold (1.3%)']
#   sufficient variation (1 colex / 2 dislex)
# 64 292 ('anal1239', 'pachool') ['ask (99.0%)', 'question (0.7%)', 'request (0.3%)']
#   sufficient variation (3 colex / 0 dislex)
# 65 144 ('anal1239', 'pacho') ['ask (52.1%)', 'crab (32.6%)', 'turtle (6.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 66 107 ('anal1239', 'achara$') ['ask (83.2%)', 'son (13.1%)', 'grandson (2.8%)']
#   sufficient variation (0 colex / 1 dislex)
# 67 1167 ('anal1239', '^lap') ['old (66.2%)', 'woman (29.8%)', 'hermit (0.9%)']
#   sufficient variation (2 colex / 12 dislex)
# 68 193 ('anal1239', '^palu$') ['old (73.1%)', 'chop (4.7%)', 'clap (2.1%)']
#   sufficient variation (0 colex / 1 dislex)
# 69 569 ('anal1239', '^vau') ['brother (65.6%)', 'old (16.2%)', 'elder (6.0%)']
#   sufficient variation (1 colex / 8 dislex)
# 70 2253 ('arap1274', "tei'yoo") ['child (75.1%)', 'son (6.9%)', 'young (5.5%)']
#   sufficient variation (5 colex / 25 dislex)
# 71 145 ('anal1239', '^ipu$') ['thing (78.6%)', 'carry (8.3%)', 'hold (3.4%)']
#   sufficient variation (1 colex / 0 dislex)
# 72 712 ('anal1239', 'see') ['make (96.5%)', 'build (2.8%)', 'create (0.4%)']
#   sufficient variation (8 colex / 4 dislex)
# 73 266 ('anal1239', '^pi') ['make (100.0%)']
#   sufficient variation (3 colex / 0 dislex)
# 74 366 ('anal1239', '^patha$') ['send (31.1%)', 'make (30.9%)', 'bring (21.0%)']
#   sufficient variation (0 colex / 5 dislex)
# 75 390 ('anal1239', '^hmi$') ['make (56.7%)', 'burn (27.4%)', 'build (6.2%)']
#   sufficient variation (0 colex / 3 dislex)
# 76 3246 ('anal1239', 'thi') ['know (50.1%)', 'see (36.5%)', 'think (8.5%)']
#   sufficient variation (1 colex / 37 dislex)
# 77 695 ('anal1239', 'ngte$') ['see (99.7%)', 'watch (0.1%)', 'notice (0.1%)']
#   sufficient variation (10 colex / 0 dislex)
# 78 1330 ('anal1239', 'pam$') ['place (58.8%)', 'land (12.0%)', 'carry (6.2%)']
#   sufficient variation (1 colex / 23 dislex)
# 79 926 ('anal1239', 'tho') ['die (66.8%)', 'birth (13.2%)', 'bear (4.4%)']
#   sufficient variation (2 colex / 9 dislex)
# 80 1021 ('vera1241', 'vus$') ['kill (74.2%)', 'slaughter (4.7%)', 'dead (3.0%)']
#   sufficient variation (2 colex / 14 dislex)
# 81 864 ('bain1259', 'dikaa') ['wife (84.1%)', 'birth (3.8%)', 'law (3.1%)']
#   sufficient variation (0 colex / 10 dislex)
# 82 284 ('anal1239', '^vata') ['brother (83.8%)', 'sister (12.3%)', 'son (1.4%)']
#   sufficient variation (1 colex / 2 dislex)
# 83 986 ('anal1239', '^pha') ['get (99.7%)', 'catch (0.1%)', 'start (0.1%)']
#   sufficient variation (4 colex / 10 dislex)
# 84 249 ('anal1239', '^sinpa$') ['boy (99.6%)', 'child (0.4%)']
#   sufficient variation (2 colex / 0 dislex)
# 85 220 ('anal1239', '^ala') ['boy (96.8%)', 'boyile (1.8%)', 'guy (0.9%)']
#   sufficient variation (2 colex / 2 dislex)
# 86 254 ('anal1239', '^ekhal$') ['move (17.7%)', 'big (9.1%)', 'small (7.1%)']
#   sufficient variation (0 colex / 1 dislex)
# 87 1406 ('anal1239', '^du') ['water (54.3%)', 'river (16.1%)', 'fetch (6.3%)']
#   sufficient variation (3 colex / 17 dislex)
# 88 89 ('anal1239', 'nahla$') ['young (47.2%)', 'old (33.7%)', 'small (10.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 89 259 ('anal1239', '^paruwl$') ['snake (83.4%)', 'swallow (10.0%)', 'bug (1.2%)']
#   sufficient variation (2 colex / 0 dislex)
# 90 1188 ('anal1239', 'pal$') ['live (95.8%)', 'grow (1.7%)', 'work (1.3%)']
#   sufficient variation (7 colex / 8 dislex)
# 91 100 ('anal1239', 'hring') ['live (60.0%)', 'death (26.0%)', 'life (6.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 92 548 ('anal1239', '^nahla$') ['woman (99.3%)', 'hermit (0.4%)', 'female (0.2%)']
#   sufficient variation (6 colex / 3 dislex)
# 93 205 ('anal1239', '^sinnu') ['woman (99.0%)', 'man (0.5%)', 'female (0.5%)']
#   sufficient variation (1 colex / 0 dislex)
# 94 970 ('anal1239', '^jol') ['thing (63.8%)', 'woman (32.5%)', 'kind (1.0%)']
#   sufficient variation (0 colex / 9 dislex)
# 95 286 ('anal1239', 'sal') ['cow (94.8%)', 'cattle (2.8%)', 'goat (1.4%)']
#   sufficient variation (3 colex / 0 dislex)
# 96 201 ('anal1239', 'hmi') ['eye (89.6%)', 'ear (4.5%)', 'mouth (1.5%)']
#   sufficient variation (2 colex / 1 dislex)
# 97 403 ('anal1239', 'ul') ['become (95.0%)', 'grow (3.5%)', 'get (0.5%)']
#   sufficient variation (3 colex / 2 dislex)
# 98 213 ('anal1239', '^vapalung$') ['angry (34.3%)', 'get (19.7%)', 'become (17.8%)']
#   sufficient variation (0 colex / 2 dislex)
# 99 425 ('anal1239', 'jung') ['fall (88.7%)', 'drop (1.9%)', 'fell (1.6%)']
#   sufficient variation (1 colex / 4 dislex)
# 100 53 ('anal1239', '^lapanu$') ['lady (66.0%)', 'fall (15.1%)', 'work (3.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 101 467 ('anal1239', '^thing') ['tree (96.6%)', 'trunk (1.7%)', 'branch (0.6%)']
#   sufficient variation (3 colex / 4 dislex)
# 102 149 ('anal1239', '^pavung$') ['grow (69.1%)', 'tree (26.2%)', 'seed (1.3%)']
#   sufficient variation (0 colex / 1 dislex)
# 103 134 ('anal1239', 'chalnu$') ['sister (97.8%)', 'co (2.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 104 68 ('anal1239', 'uhnu$') ['sister (80.9%)', 'brother (11.8%)', 'sibling (4.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 105 665 ('anal1239', 'kam') ['leave (80.6%)', 'celebrate (12.2%)', 'end (1.2%)']
#   sufficient variation (3 colex / 6 dislex)
# 106 541 ('sout2856', 'kori$') ['dog (76.7%)', 'horse (2.6%)', 'human (2.4%)']
#   sufficient variation (2 colex / 5 dislex)
# 107 286 ('anal1239', 'doh$') ['put (64.3%)', 'keep (26.9%)', 'get (2.8%)']
#   sufficient variation (0 colex / 3 dislex)
# 108 861 ('anal1239', '^ito$') ['work (84.0%)', 'know (12.3%)', 'speak (2.4%)']
#   sufficient variation (3 colex / 8 dislex)
# 109 142 ('anal1239', '^changh') ['cat (52.8%)', 'wild (31.0%)', 'polar (5.6%)']
#   sufficient variation (1 colex / 1 dislex)
# 110 42 ('anal1239', '^pangal$') ['wild (16.7%)', 'boar (11.9%)', 'broth (11.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 111 406 ('anal1239', 'du') ['cut (94.3%)', 'blow (1.2%)', 'pierce (1.0%)']
#   sufficient variation (4 colex / 2 dislex)
# 112 86 ('anal1239', '^thum$') ['fruit (57.0%)', 'banana (19.8%)', 'cut (9.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 113 109 ('anal1239', 'aha$') ['ear (50.5%)', 'cut (11.0%)', 'eare (8.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 114 1759 ('anal1239', '^in') ['house (73.1%)', 'home (13.2%)', 'village (4.5%)']
#   sufficient variation (7 colex / 22 dislex)
# 115 513 ('even1259', '^omolgi') ['son (91.8%)', 'daughter (3.5%)', 'father (2.7%)']
#   sufficient variation (4 colex / 2 dislex)
# 116 100 ('anal1239', '^vamah$') ['law (90.0%)', 'son (10.0%)']
#   sufficient variation (1 colex / 1 dislex)
# 117 864 ('anal1239', 'aung') ['sit (66.3%)', 'rest (5.0%)', 'lie (3.1%)']
#   sufficient variation (0 colex / 12 dislex)
# 118 360 ('anal1239', '^iung') ['sit (94.2%)', 'lie (3.1%)', 'wait (0.8%)']
#   sufficient variation (3 colex / 2 dislex)
# 119 120 ('anal1239', '^tah') ['cry (99.2%)', 'sad (0.8%)']
#   sufficient variation (1 colex / 0 dislex)
# 120 150 ('anal1239', 'ta$') ['cry (87.3%)', 'singe (5.3%)', 'shout (2.0%)']
#   sufficient variation (0 colex / 1 dislex)
# 121 289 ('anal1239', '^tacha$') ['bear (5.9%)', 'try (5.9%)', 'next (5.2%)']
#   sufficient variation (0 colex / 1 dislex)
# 122 109 ('anal1239', 'pha') ['reach (76.1%)', 'arrive (6.4%)', 'finish (4.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 123 113 ('anal1239', '^tung') ['reach (99.1%)', 'pass (0.9%)']
#   sufficient variation (1 colex / 1 dislex)
# 124 857 ('anal1239', 'thal') ['put (89.1%)', 'set (3.0%)', 'throw (2.5%)']
#   sufficient variation (4 colex / 5 dislex)
# 125 242 ('anal1239', 'hol') ['carry (64.9%)', 'hold (19.8%)', 'hang (3.7%)']
#   sufficient variation (0 colex / 2 dislex)
# 126 46 ('anal1239', 'apahin') ['parent (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 127 211 ('anal1239', 'apa$') ['parent (38.9%)', 'family (22.7%)', 'relative (15.2%)']
#   sufficient variation (0 colex / 1 dislex)
# 128 528 ('anal1239', '^patung$') ['bring (93.6%)', 'father (1.9%)', 'parent (1.5%)']
#   sufficient variation (2 colex / 3 dislex)
# 129 1644 ('taba1259', '.ji') ['father (65.8%)', 'mother (5.1%)', 'dad (4.4%)']
#   sufficient variation (5 colex / 26 dislex)
# 130 250 ('anal1239', '^ng') ['fish (96.0%)', 'reef (2.0%)', 'whale (1.2%)']
#   sufficient variation (3 colex / 1 dislex)
# 131 425 ('anal1239', '^hlin$') ['catch (14.4%)', 'pick (13.2%)', 'fish (4.5%)']
#   sufficient variation (0 colex / 5 dislex)
# 132 25 ('anal1239', '^ahnam') ['witch (36.0%)', 'lady (20.0%)', 'spirit (12.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 133 88 ('anal1239', '^uns') ['love (86.4%)', 'like (4.5%)', 'care (4.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 134 21 ('anal1239', '^ado') ['love (95.2%)', 'want (4.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 135 31 ('anal1239', '^chaman') ['devil (51.6%)', 'witch (48.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 136 430 ('anal1239', 'lanu$') ['daughter (97.9%)', 'mother (0.5%)', 'young (0.2%)']
#   sufficient variation (5 colex / 1 dislex)
# 137 799 ('anal1239', '^nikhe') ['day (98.7%)', 'today (0.9%)', 'season (0.3%)']
#   sufficient variation (12 colex / 3 dislex)
# 138 60 ('anal1239', '^ding') ['happen (96.7%)', 'do (1.7%)', 'go (1.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 139 72 ('anal1239', '^ing$') ['happen (98.6%)', 'bad (1.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 140 645 ('vera1241', '^kaka') ['story (80.9%)', 'history (3.3%)', 'true (2.5%)']
#   sufficient variation (1 colex / 9 dislex)
# 141 177 ('anal1239', 'nun') ['chase (31.6%)', 'catch (14.7%)', 'follow (10.2%)']
#   sufficient variation (0 colex / 2 dislex)
# 142 419 ('arap1274', "e'eik") ['head (77.3%)', 'tail (4.1%)', 'source (2.9%)']
#   sufficient variation (1 colex / 3 dislex)
# 143 226 ('arap1274', '^hiisiis$') ['sun (76.5%)', 'moon (5.8%)', 'daylight (4.4%)']
#   sufficient variation (2 colex / 1 dislex)
# 144 331 ('anal1239', '^hal') ['pig (33.2%)', 'chicken (19.0%)', 'hen (7.3%)']
#   sufficient variation (1 colex / 2 dislex)
# 145 366 ('anal1239', '^khenu$') ['buy (52.5%)', 'build (7.4%)', 'grow (6.0%)']
#   sufficient variation (0 colex / 1 dislex)
# 146 192 ('anal1239', '^ahmang$') ['forest (74.5%)', 'wood (12.5%)', 'bush (5.7%)']
#   sufficient variation (2 colex / 0 dislex)
# 147 190 ('anal1239', 'athun') ['clothe (48.4%)', 'dress (36.8%)', 'dance (3.2%)']
#   sufficient variation (0 colex / 1 dislex)
# 148 1171 ('anal1239', '^itha') ['good (72.9%)', 'beautiful (17.7%)', 'big (3.2%)']
#   sufficient variation (4 colex / 11 dislex)
# 149 179 ('anal1239', 'hna$') ['leaf (45.3%)', 'leave (27.9%)', 'trunk (7.3%)']
#   sufficient variation (0 colex / 1 dislex)
# 150 646 ('anal1239', '^jowlko$') ['big (60.4%)', 'arrive (18.1%)', 'guest (2.2%)']
#   sufficient variation (2 colex / 8 dislex)
# 151 882 ('sadu1234', '^i55$') ['run (82.5%)', 'jump (3.9%)', 'fly (1.6%)']
#   sufficient variation (3 colex / 8 dislex)
# 152 26 ('anal1239', 'su$') ['release (92.3%)', 'free (3.8%)', 'withdraw (3.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 153 135 ('anal1239', '^kahlo$') ['friend (100.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 154 114 ('anal1239', '^choontang$') ['cover (50.0%)', 'mud (20.2%)', 'lump (13.2%)']
#   sufficient variation (1 colex / 1 dislex)
# 155 39 ('anal1239', '^vahem') ['break (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 156 74 ('anal1239', '^vak') ['break (95.9%)', 'beat (1.4%)', 'hit (1.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 157 40 ('anal1239', '^ahli') ['change (92.5%)', 'difference (5.0%)', 'transform (2.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 158 93 ('anal1239', '^hrin$') ['new (76.3%)', 'change (19.4%)', 'difference (2.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 159 24 ('anal1239', '^pas') ['elephant (95.8%)', 'u (4.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 160 106 ('anal1239', 'bu') ['rice (57.5%)', 'potato (20.8%)', 'grain (5.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 161 263 ('anal1239', '^popem$') ['send (17.9%)', 'fat (16.7%)', 'big (10.6%)']
#   sufficient variation (0 colex / 3 dislex)
# 162 14 ('anal1239', '^tiing$') ['about (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 163 69 ('anal1239', '^hli') ['cultivate (37.7%)', 'grow (30.4%)', 'harvest (11.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 164 155 ('anal1239', 'hlam') ['search (55.5%)', 'look (23.9%)', 'find (10.3%)']
#   sufficient variation (1 colex / 0 dislex)
# 165 224 ('anal1239', 'hli') ['field (67.0%)', 'farm (17.4%)', 'yard (2.7%)']
#   sufficient variation (2 colex / 1 dislex)
# 166 543 ('sout3282', '^hear') ['hear (78.8%)', 'listen (13.4%)', 'sound (3.5%)']
#   sufficient variation (7 colex / 2 dislex)
# 167 322 ('port1286', 'vot$') ['stone (71.1%)', 'rock (17.4%)', 'clay (2.2%)']
#   sufficient variation (2 colex / 3 dislex)
# 168 406 ('anal1239', 'pahang$') ['door (50.5%)', 'open (35.5%)', 'close (10.6%)']
#   sufficient variation (0 colex / 8 dislex)
# 169 195 ('anal1239', 'ari') ['bit (69.2%)', 'little (26.7%)', 'bite (2.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 170 445 ('anal1239', 'aru$') ['bone (24.7%)', 'collect (13.3%)', 'wood (11.2%)']
#   sufficient variation (0 colex / 3 dislex)
# 171 128 ('nort2641', '^feqir') ['poor (90.6%)', 'poverty (6.2%)', 'rotten (0.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 172 612 ('anal1239', '^pavan') ['pour (3.9%)', 'earth (3.3%)', 'devil (3.3%)']
#   sufficient variation (0 colex / 9 dislex)
# 173 112 ('bora1263', 'iibu') ['heart (92.0%)', 'chest (2.7%)', 'mind (2.7%)']
#   sufficient variation (2 colex / 0 dislex)
# 174 213 ('anal1239', '^hlam') ['road (76.5%)', 'way (8.5%)', 'path (5.6%)']
#   sufficient variation (1 colex / 0 dislex)
# 175 401 ('anal1239', 'ong') ['morning (84.5%)', 'tomorrow (5.7%)', 'day (5.0%)']
#   sufficient variation (3 colex / 3 dislex)
# 176 161 ('anal1239', '^atho$') ['wind (47.2%)', 'rain (29.2%)', 'blow (12.4%)']
#   sufficient variation (0 colex / 1 dislex)
# 177 66 ('anal1239', '^tungbing$') ['hang (33.3%)', 'bottle (33.3%)', 'gourd (3.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 178 99 ('anal1239', 'bool$') ['basket (61.6%)', 'bag (10.1%)', 'pole (7.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 179 290 ('port1286', '^pyang$') ['fire (85.5%)', 'candle (4.5%)', 'firewood (4.5%)']
#   sufficient variation (1 colex / 2 dislex)
# 180 209 ('anal1239', 'otang') ['hold (15.8%)', 'festival (11.0%)', 'dance (9.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 181 171 ('anal1239', '^pong') ['pig (60.2%)', 'different (28.1%)', 'horse (3.5%)']
#   sufficient variation (0 colex / 1 dislex)
# 182 728 ('taba1259', "^ip'ru") ['food (73.1%)', 'meal (3.3%)', 'meat (2.9%)']
#   sufficient variation (7 colex / 7 dislex)
# 183 335 ('anal1239', '^kapalungthu$') ['hit (29.6%)', 'want (23.9%)', 'different (8.1%)']
#   sufficient variation (0 colex / 4 dislex)
# 184 1016 ('anal1239', '^mang') ['want (80.0%)', 'much (10.0%)', 'many (3.5%)']
#   sufficient variation (4 colex / 11 dislex)
# 185 32 ('anal1239', 'ram') ['couple (65.6%)', 'marriage (9.4%)', 'multiple (3.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 186 115 ('anal1239', '^kang$') ['knife (52.2%)', 'sword (13.9%)', 'bow (7.8%)']
#   sufficient variation (0 colex / 1 dislex)
# 187 93 ('anal1239', 'vum$') ['black (69.9%)', 'white (18.3%)', 'dark (5.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 188 77 ('anal1239', '^khudok$') ['white (42.9%)', 'magic (29.9%)', 'black (13.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 189 144 ('anal1239', 'asol') ['fight (79.9%)', 'war (14.6%)', 'defeat (3.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 190 31 ('anal1239', 're$') ['fight (54.8%)', 'wartha (9.7%)', 'quarrel (6.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 191 145 ('sanz1248', '^k:urt:') ['fox (97.2%)', 'bat (1.4%)', 'deer (0.7%)']
#   sufficient variation (4 colex / 0 dislex)
# 192 442 ('anal1239', '^hangka') ['climb (49.5%)', 'jump (34.2%)', 'hang (2.3%)']
#   sufficient variation (0 colex / 7 dislex)
# 193 533 ('anal1239', 'hmiing$') ['name (87.2%)', 'call (5.1%)', 'law (2.6%)']
#   sufficient variation (3 colex / 5 dislex)
# 194 87 ('anal1239', 'pajo') ['write (93.1%)', 'letter (6.9%)']
#   sufficient variation (1 colex / 0 dislex)
# 195 30 ('anal1239', '^chethi') ['letter (86.7%)', 'write (13.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 196 14 ('anal1239', '^ra$') ['rain (100.0%)']
# 197 14 ('anal1239', 'kowng') ['tailbone (64.3%)', 'tail (35.7%)']
# 198 93 ('anal1239', '^dumanu$') ['taste (14.0%)', 'riddle (9.7%)', 'sweet (6.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 199 88 ('anal1239', '^sana$') ['gold (76.1%)', 'golden (10.2%)', 'iron (3.4%)']
#   sufficient variation (0 colex / 1 dislex)
# 200 100 ('anal1239', 'sul$') ['gold (22.0%)', 'bladder (4.0%)', 'fat (4.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 201 96 ('anal1239', '^pali') ['eagle (99.0%)', 'owl (1.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 202 240 ('anal1239', 'hlu') ['enter (90.8%)', 'approach (4.2%)', 'arrive (3.3%)']
#   sufficient variation (1 colex / 1 dislex)
# 203 200 ('anal1239', 'hek') ['shoot (81.0%)', 'catch (3.0%)', 'fire (3.0%)']
#   sufficient variation (2 colex / 2 dislex)
# 204 85 ('anal1239', '^pacho$') ['salt (81.2%)', 'saltwater (12.9%)', 'pepper (3.5%)']
#   sufficient variation (1 colex / 0 dislex)
# 205 154 ('anal1239', '^adal$') ['ipoh (15.6%)', 'wake (11.0%)', 'yam (5.2%)']
#   sufficient variation (1 colex / 1 dislex)
# 206 137 ('anal1239', '^sa$') ['animal (87.6%)', 'revenge (3.6%)', 'horse (2.2%)']
#   sufficient variation (2 colex / 1 dislex)
# 207 235 ('anal1239', '^chati$') ['rat (36.6%)', 'burn (11.5%)', 'destroy (4.3%)']
#   sufficient variation (0 colex / 2 dislex)
# 208 43 ('anal1239', '^e$') ['dung (44.2%)', 'yam (11.6%)', 'taiga (7.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 209 101 ('anal1239', '^amin') ['catch (100.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 210 304 ('svan1243', '^cas') ['husband (88.2%)', 'wife (9.2%)', 'brother (0.7%)']
#   sufficient variation (3 colex / 2 dislex)
# 211 182 ('kark1256', '^swiin') ['deer (91.2%)', 'wild (4.9%)', 'animal (2.7%)']
#   sufficient variation (1 colex / 1 dislex)
# 212 42 ('kama1351', '^gol') ['voice (95.2%)', 'ear (2.4%)', 'sound (2.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 213 177 ('anal1239', '^paha') ['bird (96.0%)', 'fly (1.7%)', 'feather (1.1%)']
#   sufficient variation (2 colex / 0 dislex)
# 214 9 ('anal1239', '^amaput') ['wise (88.9%)', 'wisdom (11.1%)']
# 215 84 ('anal1239', '^andol$') ['pour (57.1%)', 'remain (15.5%)', 'pan (8.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 216 326 ('nisv1234', '^navre-n$') ['hand (76.7%)', 'foot (5.5%)', 'arm (5.5%)']
#   sufficient variation (1 colex / 1 dislex)
# 217 207 ('anal1239', '^ahnal$') ['own (80.2%)', 'lick (6.3%)', 'become (3.9%)']
#   sufficient variation (1 colex / 1 dislex)
# 218 80 ('anal1239', 'hmi$') ['tail (98.8%)', 'hind (1.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 219 501 ('anal1239', 'ahlun') ['walk (83.8%)', 'dance (4.0%)', 'move (3.2%)']
#   sufficient variation (4 colex / 2 dislex)
# 220 433 ('komn1238', '^z@.bar$') ['night (81.1%)', 'evening (5.1%)', 'tonight (3.7%)']
#   sufficient variation (2 colex / 5 dislex)
# 221 51 ('anal1239', '^suwn$') ['calf (98.0%)', 'belly (2.0%)']
#   sufficient variation (0 colex / 1 dislex)
# 222 121 ('anal1239', '^hmikhunu$') ['village (33.9%)', 'hut (29.8%)', 'tent (21.5%)']
#   sufficient variation (0 colex / 1 dislex)
# 223 26 ('anal1239', '^lang') ['real (88.5%)', 'true (11.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 224 55 ('anal1239', '^chavan') ['rich (70.9%)', 'wealthy (10.9%)', 'money (10.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 225 113 ('anal1239', '^adu') ['meet (84.1%)', 'catch (6.2%)', 'greet (3.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 226 39 ('anal1239', 'atang$') ['set (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 227 39 ('anal1239', '^vajool$') ['case (48.7%)', 'settle (23.1%)', 'lawsuit (17.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 228 204 ('anal1239', '^kahlu$') ['evening (49.0%)', 'approach (9.8%)', 'afternoon (4.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 229 7 ('anal1239', 'dal$') ['testicle (100.0%)']
# 230 114 ('anal1239', '^ana') ['state (7.0%)', 'taiga (5.3%)', 'anal (4.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 231 239 ('anal1239', 'hra$') ['potato (25.9%)', 'sweet (18.4%)', 'neck (7.9%)']
#   sufficient variation (0 colex / 1 dislex)
# 232 66 ('anal1239', '^khamtung$') ['veranda (15.2%)', 'wear (10.6%)', 'shawl (10.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 233 777 ('anal1239', '^kum') ['year (72.3%)', 'day (18.1%)', 'join (1.3%)']
#   sufficient variation (1 colex / 11 dislex)
# 234 25 ('anal1239', '^nono$') ['normal (24.0%)', 'bare (8.0%)', 'small (8.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 235 598 ('nort2641', '^hesp') ['horse (80.8%)', 'animal (2.2%)', 'breed (1.8%)']
#   sufficient variation (2 colex / 5 dislex)
# 236 149 ('anal1239', '^pathuwn$') ['top (66.4%)', 'crest (8.1%)', 'pile (4.7%)']
#   sufficient variation (0 colex / 1 dislex)
# 237 5 ('anal1239', '^angna') ['angnal (100.0%)']
#   *no concreteness scores
# 238 26 ('anal1239', 'akol$') ['hug (38.5%)', 'hold (26.9%)', 'shake (23.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 239 74 ('anal1239', '^kupal$') ['ring (98.6%)', 'bell (1.4%)']
#   sufficient variation (1 colex / 0 dislex)
# 240 179 ('anal1239', '^hru') ['rope (27.4%)', 'pole (6.1%)', 'cloth (4.5%)']
#   sufficient variation (0 colex / 1 dislex)
# 241 48 ('anal1239', 'akoong') ['tie (39.6%)', 'bind (25.0%)', 'wrap (14.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 242 179 ('anal1239', '^salkhu$') ['taiga (10.1%)', 'plough (6.7%)', 'ravine (3.9%)']
#   sufficient variation (0 colex / 2 dislex)
# 243 114 ('anal1239', '^beel') ['pot (47.4%)', 'break (14.0%)', 'work (6.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 244 167 ('anal1239', '^peereh$') ['play (86.8%)', 'become (3.0%)', 'ascend (1.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 245 21 ('anal1239', '^jote$') ['domestic (38.1%)', 'native (19.0%)', 'mourn (14.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 246 20 ('anal1239', '^pahlung$') ['moth (20.0%)', 'state (5.0%)', 'thing (5.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 247 230 ('anal1239', '^buchung$') ['work (10.0%)', 'wood (4.3%)', 'rule (3.9%)']
#   sufficient variation (0 colex / 1 dislex)
# 248 170 ('anal1239', '^vajung') ['ride (40.6%)', 'scared (22.9%)', 'drive (7.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 249 281 ('anal1239', 'akhu$') ['foot (45.6%)', 'leg (44.1%)', 'arm (3.2%)']
#   sufficient variation (0 colex / 2 dislex)
# 250 189 ('anal1239', 'sal$') ['arrow (55.0%)', 'cattle (32.8%)', 'cow (3.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 251 71 ('anal1239', '^lidar$') ['reindeer (14.1%)', 'tray (11.3%)', 'sheet (5.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 252 93 ('anal1239', '^dupal$') ['ill (12.9%)', 'problem (11.8%)', 'disease (8.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 253 8540 ('port1286', '^van$') ['go (92.7%)', 'leave (3.4%)', 'get (1.5%)']
#   sufficient variation (13 colex / 29 dislex)
# 254 135 ('port1286', 'aa$') ['go (86.7%)', 'leave (10.4%)', 'set (1.5%)']
#   sufficient variation (0 colex / 1 dislex)
# 255 1528 ('port1286', '^tyenem$') ['village (45.1%)', 'leave (11.2%)', 'go (8.2%)']
#   sufficient variation (3 colex / 18 dislex)
# 256 9598 ('port1286', '^kie$') ['say (83.7%)', 'tell (6.3%)', 'think (3.4%)']
#   sufficient variation (6 colex / 35 dislex)
# 257 237 ('port1286', '^ka$') ['say (100.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 258 5862 ('kark1256', '^ta') ['come (85.4%)', 'bring (4.0%)', 'arrive (3.1%)']
#   sufficient variation (7 colex / 33 dislex)
# 259 24 ('port1286', '^sevele$') ['come (83.3%)', 'hurry (4.2%)', 'get (4.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 260 34 ('port1286', 'soaa$') ['come (70.6%)', 'get (26.5%)', 'turn (2.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 261 1797 ('port1286', '^timaleh$') ['child (80.6%)', 'young (11.1%)', 'son (3.6%)']
#   sufficient variation (9 colex / 22 dislex)
# 262 366 ('port1286', '^nare') ['child (65.6%)', 'son (26.0%)', 'daughter (5.5%)']
#   sufficient variation (1 colex / 3 dislex)
# 263 3025 ('port1286', '^idi') ['take (62.8%)', 'bring (26.8%)', 'get (3.5%)']
#   sufficient variation (1 colex / 31 dislex)
# 264 150 ('port1286', 'go$') ['take (98.7%)', 'bring (1.3%)']
#   sufficient variation (1 colex / 1 dislex)
# 265 87 ('port1286', '^vere$') ['take (52.9%)', 'seed (34.5%)', 'bead (3.4%)']
#   sufficient variation (0 colex / 1 dislex)
# 266 670 ('port1286', '^teeteepon$') ['old (27.3%)', 'care (7.9%)', 'take (6.9%)']
#   sufficient variation (0 colex / 6 dislex)
# 267 136 ('port1286', '^saane$') ['leave (49.3%)', 'touch (13.2%)', 'hold (8.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 268 2251 ('lowe1385', 'wiz') ['see (83.8%)', 'look (4.8%)', 'find (4.6%)']
#   sufficient variation (13 colex / 18 dislex)
# 269 734 ('port1286', '^tee') ['look (90.1%)', 'see (5.0%)', 'turn (2.6%)']
#   sufficient variation (7 colex / 7 dislex)
# 270 1680 ('port1286', '^yaapuo$') ['man (92.0%)', 'high (3.8%)', 'person (0.4%)']
#   sufficient variation (12 colex / 11 dislex)
# 271 2827 ('port1286', '^vanten$') ['people (74.0%)', 'man (16.3%)', 'person (6.3%)']
#   sufficient variation (5 colex / 25 dislex)
# 272 196 ('port1286', '^baalip$') ['strong (30.6%)', 'people (25.0%)', 'man (24.0%)']
#   sufficient variation (0 colex / 2 dislex)
# 273 527 ('port1286', 'pwet$') ['stay (57.3%)', 'leave (34.0%)', 'wait (3.6%)']
#   sufficient variation (0 colex / 7 dislex)
# 274 729 ('port1286', 'du$') ['stay (57.5%)', 'leave (30.3%)', 'remain (1.8%)']
#   sufficient variation (0 colex / 8 dislex)
# 275 547 ('port1286', 'lehe$') ['look (97.4%)', 'watch (1.1%)', 'wait (1.1%)']
#   sufficient variation (4 colex / 3 dislex)
# 276 1701 ('savo1255', '^tuvi$') ['house (75.7%)', 'home (7.9%)', 'door (2.8%)']
#   sufficient variation (4 colex / 25 dislex)
# 277 12 ('port1286', '^pinpinin$') ['tell (66.7%)', 'keep (33.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 278 13 ('port1286', 'soro') ['keep (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 279 59 ('port1286', 'isi') ['keep (98.3%)', 'use (1.7%)']
#   sufficient variation (1 colex / 0 dislex)
# 280 130 ('port1286', '^pongor$') ['collect (25.4%)', 'shellfish (8.5%)', 'keep (7.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 281 146 ('port1286', '^teetaa$') ['buttock (8.2%)', 'turn (5.5%)', 'close (4.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 282 67 ('port1286', '^myah$') ['dry (74.6%)', 'keep (14.9%)', 'long (3.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 283 419 ('port1286', '^yen$') ['leg (25.3%)', 'foot (17.4%)', 'bone (3.3%)']
#   sufficient variation (0 colex / 4 dislex)
# 284 1384 ('port1286', '^vanmoro$') ['woman (74.6%)', 'husband (19.4%)', 'law (2.2%)']
#   sufficient variation (3 colex / 15 dislex)
# 285 398 ('port1286', '^vaven$') ['woman (90.2%)', 'lady (8.0%)', 'girl (1.5%)']
#   sufficient variation (3 colex / 1 dislex)
# 286 100 ('port1286', '^maama$') ['mother (80.0%)', 'woman (10.0%)', 'mom (6.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 287 584 ('port1286', '^ot$') ['place (99.0%)', 'area (0.5%)', 'part (0.2%)']
#   sufficient variation (7 colex / 1 dislex)
# 288 95 ('port1286', '^weren$') ['place (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 289 69 ('port1286', '^moso$') ['open (73.9%)', 'clear (10.1%)', 'place (4.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 290 111 ('port1286', '^ok') ['place (97.3%)', 'land (2.7%)']
#   sufficient variation (1 colex / 0 dislex)
# 291 1251 ('yura1255', 'jus') ['want (75.7%)', 'use (4.2%)', 'like (4.0%)']
#   sufficient variation (8 colex / 16 dislex)
# 292 107 ('port1286', '^beleyo$') ['bamboo (49.5%)', 'piece (36.4%)', 'charcoal (4.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 293 179 ('port1286', '^sipa$') ['thank (61.5%)', 'invite (3.4%)', 'need (2.8%)']
#   sufficient variation (1 colex / 1 dislex)
# 294 1232 ('urum1249', '^goi') ['put (77.2%)', 'set (5.2%)', 'finger (2.9%)']
#   sufficient variation (2 colex / 13 dislex)
# 295 2922 ('port1286', '^gone$') ['do (52.9%)', 'make (38.0%)', 'get (4.6%)']
#   sufficient variation (9 colex / 25 dislex)
# 296 182 ('port1286', '^soote$') ['make (90.7%)', 'light (3.8%)', 'build (2.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 297 78 ('port1286', '^step$') ['become (14.1%)', 'difference (11.5%)', 'make (10.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 298 1431 ('port1286', '^ane$') ['eat (97.6%)', 'swallow (0.5%)', 'serve (0.4%)']
#   sufficient variation (15 colex / 5 dislex)
# 299 500 ('port1286', '^en$') ['eat (98.4%)', 'hungry (0.8%)', 'hunt (0.2%)']
#   sufficient variation (3 colex / 1 dislex)
# 300 1068 ('goro1270', '^hho') ['good (81.9%)', 'well (5.3%)', 'bad (2.2%)']
#   sufficient variation (4 colex / 11 dislex)
# 301 218 ('port1286', '^bwengbang$') ['play (97.2%)', 'game (2.3%)', 'player (0.5%)']
#   sufficient variation (4 colex / 1 dislex)
# 302 45 ('port1286', '^ple') ['play (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 303 797 ('port1286', 'nok$') ['finish (60.6%)', 'end (6.4%)', 'leave (4.0%)']
#   sufficient variation (4 colex / 11 dislex)
# 304 1001 ('port1286', 'nap$') ['tell (98.6%)', 'show (0.4%)', 'warn (0.2%)']
#   sufficient variation (10 colex / 5 dislex)
# 305 878 ('port1286', '^mese$') ['tell (82.1%)', 'sick (8.3%)', 'warn (2.1%)']
#   sufficient variation (5 colex / 7 dislex)
# 306 955 ('port1286', '^taat') ['father (94.9%)', 'dad (1.5%)', 'grandfather (1.3%)']
#   sufficient variation (10 colex / 5 dislex)
# 307 170 ('port1286', '^teman$') ['father (95.3%)', 'dad (2.4%)', 'paternal (1.2%)']
#   sufficient variation (1 colex / 0 dislex)
# 308 676 ('port1286', '^meleh$') ['food (76.5%)', 'gold (4.6%)', 'water (4.3%)']
#   sufficient variation (6 colex / 6 dislex)
# 309 16 ('port1286', '^an$') ['food (56.2%)', 'eat (37.5%)', 'cook (6.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 310 255 ('port1286', '^teh$') ['sea (77.6%)', 'water (12.9%)', 'tide (9.0%)']
#   sufficient variation (1 colex / 2 dislex)
# 311 103 ('port1286', '^liioo$') ['coconut (94.2%)', 'palm (1.0%)', 'cotton (1.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 312 618 ('port1286', '^yipyep$') ['human (17.6%)', 'old (9.2%)', 'white (7.8%)']
#   sufficient variation (0 colex / 6 dislex)
# 313 937 ('port1286', '^naana$') ['mother (98.9%)', 'mom (0.4%)', 'sister (0.2%)']
#   sufficient variation (14 colex / 1 dislex)
# 314 31 ('port1286', '^lase') ['mother (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 315 322 ('port1286', '^vehe$') ['carry (78.6%)', 'hold (3.4%)', 'fall (1.9%)']
#   sufficient variation (2 colex / 2 dislex)
# 316 795 ('port1286', 'kuo$') ['run (90.7%)', 'eat (1.4%)', 'flee (0.9%)']
#   sufficient variation (5 colex / 5 dislex)
# 317 419 ('port1286', '^masolo$') ['fish (97.9%)', 'source (1.7%)', 'bead (0.2%)']
#   sufficient variation (5 colex / 1 dislex)
# 318 122 ('port1286', '^pado$') ['fish (74.6%)', 'fishing (18.9%)', 'swim (4.9%)']
#   sufficient variation (0 colex / 1 dislex)
# 319 711 ('port1286', '^leng$') ['time (67.9%)', 'day (25.9%)', 'while (2.0%)']
#   sufficient variation (0 colex / 11 dislex)
# 320 363 ('port1286', '^taem$') ['time (99.2%)', 'season (0.6%)', 'year (0.3%)']
#   sufficient variation (2 colex / 0 dislex)
# 321 1029 ('port1286', '^wobuong$') ['day (79.6%)', 'year (12.4%)', 'time (4.9%)']
#   sufficient variation (2 colex / 17 dislex)
# 322 75 ('port1286', '^temat$') ['demon (50.7%)', 'evil (9.3%)', 'fairy (8.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 323 419 ('port1286', '^lii') ['tree (93.1%)', 'grass (0.7%)', 'branch (0.5%)']
#   sufficient variation (2 colex / 5 dislex)
# 324 204 ('port1286', '^vih$') ['banana (53.4%)', 'tree (31.4%)', 'potato (3.9%)']
#   sufficient variation (0 colex / 1 dislex)
# 325 121 ('port1286', '^ta$') ['cut (80.2%)', 'pick (10.7%)', 'dig (5.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 326 290 ('port1286', '^te$') ['cut (91.0%)', 'break (1.7%)', 'tear (1.4%)']
#   sufficient variation (2 colex / 1 dislex)
# 327 145 ('port1286', '^tabini$') ['kill (60.0%)', 'cut (29.7%)', 'dead (3.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 328 325 ('port1286', '^mom') ['way (98.8%)', 'manner (1.2%)']
#   sufficient variation (4 colex / 2 dislex)
# 329 99 ('port1286', '^saa') ['way (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 330 409 ('port1286', '^ya') ['become (90.2%)', 'get (8.1%)', 'grow (1.2%)']
#   sufficient variation (3 colex / 2 dislex)
# 331 340 ('port1286', '^lop$') ['day (26.8%)', 'become (5.9%)', 'old (4.1%)']
#   sufficient variation (0 colex / 5 dislex)
# 332 501 ('port1286', 'loko$') ['walk (91.8%)', 'move (1.0%)', 'eat (1.0%)']
#   sufficient variation (7 colex / 1 dislex)
# 333 706 ('port1286', 'kye$') ['call (99.3%)', 'name (0.3%)', 'summon (0.3%)']
#   sufficient variation (4 colex / 6 dislex)
# 334 1102 ('port1286', 'muru$') ['live (32.1%)', 'little (26.8%)', 'small (23.5%)']
#   sufficient variation (1 colex / 12 dislex)
# 335 280 ('port1286', '^keke') ['small (56.4%)', 'little (37.1%)', 'young (2.5%)']
#   sufficient variation (1 colex / 2 dislex)
# 336 114 ('port1286', '^lamwiye$') ['top (100.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 337 392 ('port1286', '^polo') ['climb (55.4%)', 'get (35.5%)', 'top (2.6%)']
#   sufficient variation (0 colex / 4 dislex)
# 338 40 ('port1286', '^mangki$') ['monkey (92.5%)', 'rat (7.5%)']
#   sufficient variation (1 colex / 0 dislex)
# 339 672 ('port1286', '^longane$') ['hear (64.4%)', 'feel (14.0%)', 'noise (2.4%)']
#   sufficient variation (6 colex / 6 dislex)
# 340 993 ('port1286', 'soro$') ['talk (39.8%)', 'speak (39.0%)', 'get (6.4%)']
#   sufficient variation (4 colex / 6 dislex)
# 341 1248 ('kama1351', '^amn') ['sit (73.0%)', 'lie (8.4%)', 'live (4.1%)']
#   sufficient variation (3 colex / 13 dislex)
# 342 1060 ('port1286', '^duut$') ['live (78.0%)', 'bush (5.8%)', 'tree (3.5%)']
#   sufficient variation (2 colex / 10 dislex)
# 343 205 ('port1286', '^waawaa$') ['birth (48.3%)', 'give (19.5%)', 'bear (10.7%)']
#   sufficient variation (0 colex / 2 dislex)
# 344 307 ('port1286', '^biibilen$') ['friend (80.1%)', 'relative (13.7%)', 'people (2.9%)']
#   sufficient variation (2 colex / 0 dislex)
# 345 20 ('port1286', '^map$') ['chestnut (65.0%)', 'feel (20.0%)', 'saddlebag (5.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 346 298 ('port1286', '^kiikyee$') ['snake (72.8%)', 'pig (5.7%)', 'bird (1.7%)']
#   sufficient variation (1 colex / 4 dislex)
# 347 2136 ('dolg1241', '^bil') ['know (81.4%)', 'see (1.6%)', 'think (1.5%)']
#   sufficient variation (3 colex / 30 dislex)
# 348 299 ('kama1351', "^d'u") ['ground (79.9%)', 'earth (6.7%)', 'descend (4.7%)']
#   sufficient variation (2 colex / 2 dislex)
# 349 327 ('port1286', '^doma$') ['today (89.0%)', 'tomorrow (6.4%)', 'tonight (3.7%)']
#   sufficient variation (2 colex / 2 dislex)
# 350 200 ('port1286', '^lonla') ['today (97.5%)', 'tomorrow (2.5%)']
#   sufficient variation (2 colex / 1 dislex)
# 351 303 ('port1286', '^mal$') ['chief (48.5%)', 'king (47.2%)', 'ruler (2.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 352 38 ('port1286', 'mwee$') ['palm (71.1%)', 'chief (18.4%)', 'chieftancy (10.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 353 201 ('port1286', '^tangale$') ['reach (88.1%)', 'arrive (3.5%)', 'get (3.0%)']
#   sufficient variation (2 colex / 1 dislex)
# 354 647 ('port1286', 'obo$') ['big (89.2%)', 'long (8.7%)', 'old (1.4%)']
#   sufficient variation (3 colex / 8 dislex)
# 355 253 ('port1286', '^laasi$') ['giant (58.1%)', 'float (10.7%)', 'old (7.9%)']
#   sufficient variation (0 colex / 2 dislex)
# 356 582 ('port1286', '^man$') ['boy (78.2%)', 'son (14.6%)', 'girl (5.0%)']
#   sufficient variation (4 colex / 5 dislex)
# 357 609 ('port1286', '^ih$') ['name (74.2%)', 'call (23.6%)', 'last (1.1%)']
#   sufficient variation (2 colex / 4 dislex)
# 358 17 ('port1286', '^naim$') ['fifth (41.2%)', 'rank (41.2%)', 'seventh (11.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 359 20 ('port1286', '^urut$') ['first (70.0%)', 'rank (25.0%)', 'third (5.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 360 40 ('port1286', '^lokwaru$') ['third (90.0%)', 'rank (7.5%)', 'fourth (2.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 361 28 ('port1286', '^gulgul$') ['second (92.9%)', 'rank (3.6%)', 'secondborn (3.6%)']
# 362 818 ('orko1234', '^taal') ['brother (75.8%)', 'sister (7.0%)', 'relative (3.5%)']
#   sufficient variation (2 colex / 11 dislex)
# 363 359 ('port1286', '^seene$') ['throw (69.9%)', 'hook (4.5%)', 'set (3.9%)']
#   sufficient variation (0 colex / 3 dislex)
# 364 460 ('port1286', '^pwili') ['bake (10.7%)', 'order (7.2%)', 'cook (4.8%)']
#   sufficient variation (1 colex / 4 dislex)
# 365 1418 ('yong1270', 'ki-') ['give (89.6%)', 'leave (1.4%)', 'pay (1.2%)']
#   sufficient variation (7 colex / 13 dislex)
# 366 1017 ('port1286', '^syivye$') ['kill (57.9%)', 'turn (5.3%)', 'em (3.9%)']
#   sufficient variation (0 colex / 19 dislex)
# 367 142 ('port1286', '^top') ['kill (54.9%)', 'slaughter (12.7%)', 'string (5.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 368 463 ('port1286', '^malop$') ['vill (5.6%)', 'mountain (3.5%)', 'volcano (3.5%)']
#   sufficient variation (2 colex / 3 dislex)
# 369 16 ('port1286', '^bye$') ['shark (100.0%)']
# 370 88 ('port1286', '^buluu') ['hole (97.7%)', 'opening (1.1%)', 'throat (1.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 371 102 ('port1286', '^bolo') ['hole (86.3%)', 'opening (3.9%)', 'belly (3.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 372 282 ('port1286', '^popat$') ['pig (73.0%)', 'cow (6.4%)', 'cattle (3.2%)']
#   sufficient variation (0 colex / 2 dislex)
# 373 564 ('teop1238', '^hivi') ['ask (86.2%)', 'try (1.8%)', 'request (1.8%)']
#   sufficient variation (1 colex / 2 dislex)
# 374 550 ('port1286', 'kuoli') ['return (87.6%)', 'arrive (6.4%)', 'leave (2.7%)']
#   sufficient variation (3 colex / 1 dislex)
# 375 340 ('port1286', '^myen$') ['throw (21.2%)', 'fruit (13.5%)', 'fall (12.1%)']
#   sufficient variation (0 colex / 2 dislex)
# 376 76 ('port1286', '^tevane$') ['bury (59.2%)', 'dig (38.2%)', 'hide (2.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 377 17 ('port1286', '^tivin$') ['bury (94.1%)', 'hiding (5.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 378 147 ('port1286', '^dumuo$') ['first (97.3%)', 'third (1.4%)', 'second (0.7%)']
#   sufficient variation (2 colex / 0 dislex)
# 379 192 ('bora1263', '^ura') ['follow (77.1%)', 'chase (4.2%)', 'take (3.1%)']
#   sufficient variation (0 colex / 1 dislex)
# 380 32 ('port1286', '^kyep$') ['shit (68.8%)', 'shamanize (9.4%)', 'sling (6.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 381 877 ('port1286', 'malek$') ['sleep (55.3%)', 'night (38.7%)', 'dream (0.8%)']
#   sufficient variation (0 colex / 11 dislex)
# 382 73 ('port1286', 'pili$') ['red (72.6%)', 'white (15.1%)', 'black (4.1%)']
#   sufficient variation (0 colex / 1 dislex)
# 383 51 ('port1286', '^vovyoh$') ['heart (90.2%)', 'gut (5.9%)', 'throat (3.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 384 222 ('port1286', '^notnoten$') ['heart (26.1%)', 'thought (13.1%)', 'plan (11.3%)']
#   sufficient variation (0 colex / 1 dislex)
# 385 38 ('port1286', '^pin') ['roast (47.4%)', 'rooster (23.7%)', 'rivulet (18.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 386 22 ('port1286', '^pane$') ['rivulet (54.5%)', 'roast (27.3%)', 'rusum (9.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 387 170 ('nisv1234', 'a=mac') ['dead (79.4%)', 'alive (8.8%)', 'deceased (6.5%)']
#   sufficient variation (0 colex / 2 dislex)
# 388 692 ('sout2856', 'mro') ['think (76.2%)', 'feel (5.1%)', 'thought (4.9%)']
#   sufficient variation (1 colex / 9 dislex)
# 389 1259 ('resi1247', 'odohp') ['work (78.2%)', 'try (3.2%)', 'job (1.9%)']
#   sufficient variation (1 colex / 17 dislex)
# 390 721 ('port1286', '^tiri$') ['thing (99.0%)', 'people (0.4%)', 'whatchamacallit (0.3%)']
#   sufficient variation (5 colex / 5 dislex)
# 391 349 ('port1286', '^yaa$') ['sun (49.3%)', 'burn (36.7%)', 'smoke (4.0%)']
#   sufficient variation (0 colex / 3 dislex)
# 392 833 ('svan1243', 'bin') ['start (65.4%)', 'begin (23.5%)', 'end (1.3%)']
#   sufficient variation (3 colex / 7 dislex)
# 393 124 ('port1286', '^gum') ['hold (95.2%)', 'close (2.4%)', 'squeeze (1.6%)']
#   sufficient variation (1 colex / 0 dislex)
# 394 236 ('nisv1234', 'bagim$') ['door (91.1%)', 'open (1.7%)', 'knock (1.3%)']
#   sufficient variation (1 colex / 1 dislex)
# 395 424 ('port1286', '^too$') ['garden (39.2%)', 'field (5.4%)', 'stick (3.8%)']
#   sufficient variation (0 colex / 5 dislex)
# 396 255 ('port1286', '^tuutu$') ['grandmother (82.7%)', 'grandfather (4.7%)', 'grandparent (3.5%)']
#   sufficient variation (2 colex / 1 dislex)
# 397 74 ('port1286', '^doko') ['pull (90.5%)', 'drag (5.4%)', 'turn (1.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 398 298 ('port1286', '^yepgare$') ['fly (41.3%)', 'pull (16.1%)', 'fall (11.1%)']
#   sufficient variation (0 colex / 3 dislex)
# ...
#   sufficient variation (2 colex / 6 dislex)
# 8078 690 ('nngg1234', "^!'oa") ['young (40.4%)', 'girl (32.0%)', 'boy (10.3%)']
#   sufficient variation (0 colex / 9 dislex)
# 8079 79 ('nngg1234', 'g!ae') ['law (13.9%)', 'spring (10.1%)', 'dress (8.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 8080 22 ('nngg1234', '^oom$') ['oom (100.0%)']
#   *no concreteness scores
# 8081 27 ('nngg1234', '^boetie$') ['brother (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8082 693 ('nngg1234', "^!'ai") ['call (95.4%)', 'name (3.6%)', 'know (0.4%)']
#   sufficient variation (6 colex / 7 dislex)
# 8083 189 ('nngg1234', '^dinges$') ['call (93.7%)', 'name (5.3%)', 'last (1.1%)']
#   sufficient variation (1 colex / 2 dislex)
# 8084 34 ('nngg1234', '^||abe$') ['leopard (100.0%)']
# 8085 130 ('nngg1234', "^|'arusi$") ['human (53.8%)', 'leopard (17.7%)', 'meal (6.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 8086 36 ('nngg1234', '^tier$') ['human (11.1%)', 'yamcake (11.1%)', 'leopard (8.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 8087 1099 ('nngg1234', '^xainki$') ['mother (88.4%)', 'parent (4.1%)', 'birth (2.0%)']
#   sufficient variation (7 colex / 13 dislex)
# 8088 91 ('nngg1234', '^ma$') ['mother (83.5%)', 'father (13.2%)', 'mommy (2.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 8089 138 ('nngg1234', '^|hee') ['grass (90.6%)', 'leave (8.0%)', 'mud (0.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8090 1058 ('nngg1234', "^||'uin$") ['day (73.0%)', 'sun (16.4%)', 'year (2.4%)']
#   sufficient variation (4 colex / 14 dislex)
# 8091 46 ('nngg1234', '^|=xao$') ['smear (37.0%)', 'defecate (8.7%)', 'shellfish (8.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8092 7 ('nngg1234', '^tcurike$') ['smear (100.0%)']
# 8093 45 ('nngg1234', '^!qain') ['full (95.6%)', 'whole (2.2%)', 'empty (2.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 8094 40 ('nngg1234', "^kx'uin$") ['news (45.0%)', 'full (25.0%)', 'long (10.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8095 164 ('nngg1234', '^katyum') ['listen (100.0%)']
#   sufficient variation (2 colex / 0 dislex)
# 8096 33 ('nngg1234', '^!aa') ['listen (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8097 165 ('nngg1234', '^tyuu$') ['door (80.6%)', 'listen (15.8%)', 'noise (1.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 8098 342 ('nngg1234', "^|'ii$") ['fire (72.8%)', 'hut (9.9%)', 'tent (6.4%)']
#   sufficient variation (2 colex / 2 dislex)
# 8099 120 ('nngg1234', '^!xao$') ['light (68.3%)', 'candle (22.5%)', 'burn (5.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 8100 149 ('nngg1234', '^!qoeke$') ['eye (6.0%)', 'clap (5.4%)', 'candle (5.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 8101 114 ('nngg1234', '^dyoo$') ['skin (67.5%)', 'hide (7.9%)', 'tail (6.1%)']
#   sufficient variation (0 colex / 1 dislex)
# 8102 93 ('nngg1234', 'velle') ['hide (84.9%)', 'hiding (4.3%)', 'leave (4.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 8103 162 ('nngg1234', '^more$') ['morning (50.6%)', 'tomorrow (23.5%)', 'today (10.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 8104 751 ('nngg1234', '^!xaeka$') ['morning (34.2%)', 'day (26.6%)', 'next (12.4%)']
#   sufficient variation (1 colex / 11 dislex)
# 8105 438 ('nngg1234', "^|='ain$") ['think (54.1%)', 'small (33.3%)', 'little (3.4%)']
#   sufficient variation (0 colex / 5 dislex)
# 8106 518 ('nngg1234', '^@oa') ['small (51.5%)', 'little (39.4%)', 'own (6.2%)']
#   sufficient variation (2 colex / 4 dislex)
# 8107 220 ('nngg1234', 'ietjie$') ['little (78.6%)', 'kind (19.1%)', 'nice (0.9%)']
#   sufficient variation (0 colex / 1 dislex)
# 8108 12 ('nngg1234', '^koro$') ['jackal (100.0%)']
# 8109 490 ('nngg1234', '^!xama$') ['cook (57.3%)', 'fish (4.5%)', 'prepare (3.7%)']
#   sufficient variation (0 colex / 6 dislex)
# 8110 93 ('nngg1234', "^kha'u$") ['turn (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8111 83 ('nngg1234', '^berge$') ['mountain (74.7%)', 'tree (7.2%)', 'land (6.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8112 83 ('nngg1234', '^ka||ur') ['mountain (97.6%)', 'tree (2.4%)']
#   sufficient variation (1 colex / 0 dislex)
# 8113 93 ('nngg1234', '^!ao$') ['mountain (97.8%)', 'plateau (1.1%)', 'hill (1.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 8114 312 ('nngg1234', "^!'hoe") ['ask (96.8%)', 'request (2.6%)', 'answer (0.3%)']
#   sufficient variation (3 colex / 0 dislex)
# 8115 181 ('nngg1234', "tyuu'") ['ask (99.4%)', 'request (0.6%)']
#   sufficient variation (2 colex / 0 dislex)
# 8116 31 ('nngg1234', '^oupa$') ['grandpa (67.7%)', 'grand (22.6%)', 'grandma (6.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 8117 38 ('nngg1234', '^hoo') ['meet (81.6%)', 'meeting (7.9%)', 'encounter (7.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 8118 711 ('nngg1234', 'xoe$') ['place (99.9%)', 'manner (0.1%)']
#   sufficient variation (10 colex / 3 dislex)
# 8119 207 ('nngg1234', "^!'hau$") ['place (31.4%)', 'roast (11.6%)', 'sow (11.1%)']
#   sufficient variation (0 colex / 2 dislex)
# 8120 38 ('nngg1234', '^tyoe$') ['ostrich (52.6%)', 'ox (18.4%)', 'ipoh (13.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 8121 468 ('nngg1234', '^ta') ['language (98.5%)', 'tongue (0.9%)', 'grammar (0.2%)']
#   sufficient variation (5 colex / 1 dislex)
# 8122 225 ('nngg1234', '^|=xoaki$') ['law (25.8%)', 'language (16.9%)', 'word (4.9%)']
#   sufficient variation (0 colex / 1 dislex)
# 8123 70 ('nngg1234', '^!abi$') ['ride (84.3%)', 'saddlebag (4.3%)', 'chase (2.9%)']
#   sufficient variation (1 colex / 0 dislex)
# 8124 59 ('nngg1234', '^n!ari$') ['drive (81.4%)', 'ride (16.9%)', 'fly (1.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8125 106 ('nngg1234', '^|=anu$') ['cover (67.9%)', 'blanket (5.7%)', 'cloth (5.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8126 286 ('nngg1234', '^||haan$') ['sack (12.9%)', 'exchange (8.0%)', 'belly (6.6%)']
#   sufficient variation (0 colex / 2 dislex)
# 8127 349 ('nngg1234', '^jong$') ['boy (98.9%)', 'boyile (1.1%)']
#   sufficient variation (6 colex / 0 dislex)
# 8128 258 ('nngg1234', '^|=aqbe') ['throw (98.4%)', 'push (0.4%)', 'take (0.4%)']
#   sufficient variation (1 colex / 1 dislex)
# 8129 59 ('nngg1234', '^!oqe$') ['tortoise (79.7%)', 'totem (13.6%)', 'taro (3.4%)']
#   sufficient variation (1 colex / 0 dislex)
# 8130 66 ('nngg1234', '^g||ain$') ['hyena (54.5%)', 'antelope (22.7%)', 'mulbadaw (7.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 8131 81 ('nngg1234', '^deur') ['door (100.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8132 96 ('nngg1234', "^|='aa") ['slaughter (64.6%)', 'milk (12.5%)', 'rear (4.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 8133 20 ('nngg1234', '^||qolo$') ['chop (40.0%)', 'chew (15.0%)', 'chili (10.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8134 41 ('nngg1234', "^||kx'oo$") ['chop (90.2%)', 'chew (4.9%)', 'whoop (2.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 8135 315 ('nngg1234', '^!ao') ['stone (72.1%)', 'rock (14.3%)', 'wood (5.4%)']
#   sufficient variation (2 colex / 3 dislex)
# 8136 35 ('nngg1234', '^|xoransi$') ['leaf (48.6%)', 'scrape (22.9%)', 'scraper (8.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 8137 462 ('nngg1234', 'ore$') ['good (99.4%)', 'kind (0.2%)', 'very (0.2%)']
#   sufficient variation (5 colex / 3 dislex)
# 8138 1214 ('nngg1234', '^siinsnn$') ['work (80.6%)', 'live (3.8%)', 'try (1.9%)']
#   sufficient variation (6 colex / 10 dislex)
# 8139 46 ('nngg1234', '!aqa$') ['shake (78.3%)', 'lift (8.7%)', 'push (4.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 8140 148 ('nngg1234', '^|=xain$') ['angry (12.8%)', 'tired (8.1%)', 'relaxed (6.8%)']
#   sufficient variation (0 colex / 1 dislex)
# 8141 703 ('nngg1234', "^|'aa") ['die (86.8%)', 'dead (11.4%)', 'death (0.9%)']
#   sufficient variation (4 colex / 5 dislex)
# 8142 17 ('nngg1234', '^tyxann') ['dung (100.0%)']
# 8143 74 ('nngg1234', '^|=haun') ['pour (100.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 8144 27 ('nngg1234', '^||uuke$') ['steekgra (40.7%)', 'shamanize (11.1%)', 'stump (11.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 8145 344 ('nngg1234', '^kunisi$') ['pull (32.8%)', 'cart (12.2%)', 'drive (9.9%)']
#   sufficient variation (0 colex / 2 dislex)
# 8146 170 ('nngg1234', '^!ona') ['fox (83.5%)', 'bat (5.3%)', 'eare (4.1%)']
#   sufficient variation (2 colex / 1 dislex)
# 8147 30 ('nngg1234', "^||'aake$") ['bat (13.3%)', 'bird (13.3%)', 'ear (10.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8148 103 ('nngg1234', '^blom') ['flower (44.7%)', 'leave (22.3%)', 'leaf (8.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8149 1067 ('nngg1234', '^tyd') ['time (84.6%)', 'day (10.3%)', 'year (3.6%)']
#   sufficient variation (7 colex / 11 dislex)
# 8150 23 ('nngg1234', "!'huun") ['worm (82.6%)', 'nuts (13.0%)', 'crab (4.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 8151 1062 ('nngg1234', '^saboru$') ['big (55.0%)', 'bag (6.2%)', 'long (5.2%)']
#   sufficient variation (0 colex / 17 dislex)
# 8152 266 ('nngg1234', "^!'hara$") ['enter (79.3%)', 'kraal (3.8%)', 'kwrman (2.3%)']
#   sufficient variation (0 colex / 2 dislex)
# 8153 39 ('nngg1234', '^|=xanisi$') ['letter (87.2%)', 'write (7.7%)', 'message (5.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 8154 19 ('nngg1234', '^klaas$') ['klaas (52.6%)', 'kyk!"{team (15.8%)', 'spit (5.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 8155 7 ('nngg1234', "'oq") ['stretch (100.0%)']
# 8156 80 ('nngg1234', '^n|=ona$') ['knife (75.0%)', 'sword (11.2%)', 'arrow (8.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 8157 344 ('nngg1234', '^gum$') ['cow (79.7%)', 'cattle (18.6%)', 'animal (0.9%)']
#   sufficient variation (1 colex / 3 dislex)
# 8158 28 ('nngg1234', '^stupu') ['vill (46.4%)', 'veranda (42.9%)', 'vegetal (10.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8159 38 ('nngg1234', '^koffie$') ['coffee (73.7%)', 'tea (23.7%)', 'teapot (2.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 8160 21 ('nngg1234', "^||kx'oqe$") ['spit (66.7%)', 'spat (9.5%)', 'shit (9.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 8161 20 ('nngg1234', '^dokter') ['doctor (90.0%)', 'drink (5.0%)', 'medicine (5.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8162 11 ('nngg1234', "x'ao$") ['flay (72.7%)', 'broth (9.1%)', 'flail (9.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 8163 69 ('nngg1234', '^is$') ['mean (100.0%)']
#   sufficient variation (1 colex / 0 dislex)
# 8164 25 ('nngg1234', '^|uutyuu$') ['buttock (48.0%)', 'ass (44.0%)', 'butt (8.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8165 136 ('nngg1234', '^||hai') ['milk (70.6%)', 'oil (2.9%)', 'wine (2.2%)']
#   sufficient variation (0 colex / 2 dislex)
# 8166 54 ('nngg1234', "x'oak") ['rotten (46.3%)', 'poor (18.5%)', 'good (9.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 8167 101 ('nngg1234', '^||qann$') ['sew (54.5%)', 'dead (20.8%)', 'stab (14.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 8168 31 ('nngg1234', '^n||uintyuu$') ['chest (61.3%)', 'breast (12.9%)', 'heart (6.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 8169 295 ('nngg1234', '^|aqasi$') ['snake (72.2%)', 'devil (7.5%)', 'crab (4.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8170 38 ('nngg1234', '^!qhaike$') ['shit (36.8%)', 'diarrhea (23.7%)', 'dike (5.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 8171 177 ('nngg1234', "^|='hubi$") ['burn (71.2%)', 'smoke (6.2%)', 'bury (5.6%)']
#   sufficient variation (0 colex / 2 dislex)
# 8172 149 ('nngg1234', '^broek') ['hold (48.3%)', 'reach (43.6%)', 'touch (7.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 8173 104 ('nngg1234', '^piri') ['goat (99.0%)', 'pig (1.0%)']
#   sufficient variation (1 colex / 1 dislex)
# 8174 261 ('nngg1234', 'inka$') ['think (99.2%)', 'believe (0.4%)', 'agree (0.4%)']
#   sufficient variation (2 colex / 0 dislex)
# 8175 50 ('nngg1234', "^!'oo$") ['axe (98.0%)', 'axis (2.0%)']
# 8176 289 ('nngg1234', '^bietjie$') ['bit (43.9%)', 'different (43.3%)', 'difference (4.2%)']
#   sufficient variation (0 colex / 2 dislex)
# 8177 104 ('nngg1234', "^ts'ii") ['bite (72.1%)', 'bit (10.6%)', 'lick (3.8%)']
#   sufficient variation (0 colex / 0 dislex)
# 8178 74 ('nngg1234', '^|=ae$') ['smoke (83.8%)', 'irrigate (4.1%)', 'sniff (2.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8179 61 ('nngg1234', '^!qam$') ['plough (16.4%)', 'peel (13.1%)', 'porridge (11.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 8180 233 ('nngg1234', '^mielie') ['bamboo (8.6%)', 'banana (6.9%)', 'orange (5.2%)']
#   sufficient variation (0 colex / 2 dislex)
# 8181 15 ('nngg1234', '^kan|=oqno$') ['shadow (80.0%)', 'shade (13.3%)', 'darkness (6.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8182 295 ('nngg1234', '^ouma$') ['grandmother (70.8%)', 'grandfather (5.8%)', 'grandma (5.4%)']
#   sufficient variation (1 colex / 2 dislex)
# 8183 116 ('nngg1234', '^!aqa$') ['rain (81.0%)', 'dry (5.2%)', 'mud (4.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 8184 112 ('nngg1234', '^paleke$') ['pole (39.3%)', 'stick (8.0%)', 'tent (7.1%)']
#   sufficient variation (0 colex / 1 dislex)
# 8185 853 ('nngg1234', "^|kx'ain$") ['village (80.0%)', 'town (3.2%)', 'festival (2.2%)']
#   sufficient variation (4 colex / 9 dislex)
# 8186 45 ('nngg1234', '^plan') ['plan (55.6%)', 'reason (8.9%)', 'idea (6.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8187 168 ('nngg1234', '^g!aixa$') ['past (10.7%)', 'elder (10.1%)', 'religion (7.1%)']
#   sufficient variation (0 colex / 1 dislex)
# 8188 28 ('nngg1234', 'dokter$') ['law (17.9%)', 'traditional (17.9%)', 'healer (10.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8189 36 ('nngg1234', '^|=xai') ['drag (66.7%)', 'creep (8.3%)', 'carry (5.6%)']
#   sufficient variation (0 colex / 0 dislex)
# 8190 1008 ('nngg1234', '^!uu$') ['tree (48.1%)', 'land (14.7%)', 'way (2.5%)']
#   sufficient variation (0 colex / 16 dislex)
# 8191 68 ('nngg1234', '|=qoa$') ['pot (86.8%)', 'pan (7.4%)', 'oven (2.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 8192 22 ('nngg1234', '^||qunn||khaa$') ['baboon (27.3%)', 'tendur (13.6%)', 'banyan (9.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 8193 63 ('nngg1234', "kx'ain'") ['laugh (82.5%)', 'cry (9.5%)', 'angry (6.3%)']
#   sufficient variation (1 colex / 0 dislex)
# 8194 14 ('nngg1234', '^|khuun$') ['fart (100.0%)']
# 8195 18 ('nngg1234', '^g||oosi$') ['bean (33.3%)', 'eland (22.2%)', 'aluver (16.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8196 84 ('nngg1234', '^|=an') ['close (83.3%)', 'open (11.9%)', 'end (2.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 8197 20 ('nngg1234', "^||'ngke$") ['tighten (25.0%)', 'bang (10.0%)', 'mine (10.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8198 23 ('nngg1234', '^|hoqo$') ['devil (47.8%)', 'ghost (21.7%)', 'spirit (17.4%)']
#   sufficient variation (0 colex / 0 dislex)
# 8199 106 ('nngg1234', '^dankie$') ['thank (92.5%)', 'sorry (2.8%)', 'lucky (2.8%)']
#   sufficient variation (1 colex / 0 dislex)
# 8200 87 ('nngg1234', '^|quu$') ['tobacco (71.3%)', 'smoke (23.0%)', 'charcoal (3.4%)']
#   sufficient variation (0 colex / 1 dislex)
# 8201 14 ('nngg1234', '^!xoosi$') ['pipe (64.3%)', 'organ (14.3%)', 'packet (14.3%)']
#   sufficient variation (0 colex / 0 dislex)
# 8202 65 ('nngg1234', '^uin') ['alive (47.7%)', 'dead (33.8%)', 'live (16.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 8203 90 ('nngg1234', '^dyebe$') ['salt (68.9%)', 'gold (14.4%)', 'saltwater (12.2%)']
#   sufficient variation (0 colex / 0 dislex)
# 8204 40 ('nngg1234', '^|hoqa$') ['poison (40.0%)', 'inside (12.5%)', 'devil (12.5%)']
#   sufficient variation (0 colex / 0 dislex)
# 8205 102 ('nngg1234', '^khinn$') ['feel (89.2%)', 'thirsty (6.9%)', 'smell (2.9%)']
#   sufficient variation (0 colex / 0 dislex)
# 8206 42 ('nngg1234', '^g||unn$') ['remove (61.9%)', 'skin (14.3%)', 'flesh (7.1%)']
#   sufficient variation (0 colex / 0 dislex)
# 8207 167 ('nngg1234', '^|=khoe$') ['wind (52.7%)', 'blow (23.4%)', 'cyclone (3.0%)']
#   sufficient variation (0 colex / 0 dislex)
# 8208 26 ('nngg1234', "^!'ann$") ['betel (46.2%)', 'untjie (11.5%)', 'poep (7.7%)']
#   sufficient variation (0 colex / 0 dislex)
# 8209 938 ('nngg1234', '^||xaa||xaa$') ['good (21.1%)', 'learn (14.1%)', 'teach (14.0%)']
#   sufficient variation (0 colex / 10 dislex)

# %%
print(len(df_stats.field.unique()), len(df_stats))
# Out:
# 4679 33843

# %%
df_stats_old = df_stats.copy() # backup bc now you're zscoring

# %%
for i in predictor_variables + list(map(lambda k : 'offset_' + k, predictor_variables)):
    df_stats[i] = zscore(df_stats[i]) if len(set(df_stats[i])) > 1 else df_stats[i]

# %%
from scipy.stats import pearsonr, zscore, ttest_ind
#df_stats = df_stats_old.copy()
cont_dep = ['ig']
for i in predictor_variables + list(map(lambda k : 'offset_' + k, predictor_variables)):
    if len(set(df_stats[i])) == 1: 
        print(i,'insufficient variation');continue
    for d in cont_dep:
        p,r = pearsonr(zscore(df_stats[i]), df_stats[d])
        print(i,d,'%.2f (%.3f)' % (p,r), '<<<' if r < 0.05 else '')
        #sns.regplot(x=df_stats[i], y=df_stats[d])
        #plt.show()
# Out:
# std ig 0.67 (0.000) <<<
# range ig 0.50 (0.000) <<<
# iqr ig 0.53 (0.000) <<<
# log_fpm ig -0.07 (0.000) <<<
# concreteness ig 0.09 (0.000) <<<
# 10_balance ig 0.10 (0.000) <<<
# 25_balance ig 0.11 (0.000) <<<
# 50_balance ig 0.07 (0.000) <<<
# offset_std ig 0.29 (0.000) <<<
# offset_range ig 0.14 (0.000) <<<
# offset_iqr ig 0.23 (0.000) <<<
# offset_log_fpm ig -0.09 (0.000) <<<
# offset_concreteness insufficient variation
# offset_10_balance ig 0.09 (0.000) <<<
# offset_25_balance ig 0.09 (0.000) <<<
# offset_50_balance ig 0.08 (0.000) <<<

# %%
dfi = df_stats
lm = ols('ig ~ iqr + log_fpm', dfi).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     ig   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     6932.
# Date:                Mon, 25 Mar 2024   Prob (F-statistic):               0.00
# Time:                        22:39:08   Log-Likelihood:                 6591.8
# No. Observations:               33843   AIC:                        -1.318e+04
# Df Residuals:                   33840   BIC:                        -1.315e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3443      0.001    318.047      0.000       0.342       0.346
# iqr            0.1263      0.001    116.633      0.000       0.124       0.128
# log_fpm       -0.0169      0.001    -15.652      0.000      -0.019      -0.015
# ==============================================================================
# Omnibus:                      782.057   Durbin-Watson:                   1.447
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              693.251
# Skew:                          -0.296   Prob(JB):                    2.90e-151
# Kurtosis:                       2.623   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.formula.api as smf
log_reg = smf.logit("colexified_SVC ~ iqr + log_fpm", data=df_stats).fit()
log_reg.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.621212
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         colexified_SVC   No. Observations:                33843
# Model:                          Logit   Df Residuals:                    33840
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 25 Mar 2024   Pseudo R-squ.:                 0.07303
# Time:                        23:39:01   Log-Likelihood:                -21024.
# converged:                       True   LL-Null:                       -22680.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5066      0.012    -42.092      0.000      -0.530      -0.483
# iqr           -0.7202      0.014    -51.771      0.000      -0.747      -0.693
# log_fpm       -0.0799      0.012     -6.899      0.000      -0.103      -0.057
# ==============================================================================
# """

# %%
bin_dep = ['colexified_knn@3', 'colexified_knn@5', 'colexified_SVC']
for i in predictor_variables + list(map(lambda k : 'offset_' + k, predictor_variables)):
    if len(set(df_stats[i])) == 1: 
        print(i,'insufficient variation\n');continue
    for d in bin_dep:
        zed = zscore(df_stats[i])
        a,b = zed[df_stats[d] == 0], zed[df_stats[d] == 1]
        t,r = ttest_ind(a,b)
        print(i,d,'%.2f (%.3f)' % (t,r), '<<<' if r < 0.05 else '')
        #sns.regplot(x=df_stats[i], y=df_stats[d])
        #plt.show()
    print()
# Out:
# std colexified_knn@3 47.09 (0.000) <<<
# std colexified_knn@5 51.74 (0.000) <<<
# std colexified_SVC 77.95 (0.000) <<<
#
# range colexified_knn@3 54.80 (0.000) <<<
# range colexified_knn@5 51.19 (0.000) <<<
# range colexified_SVC 104.04 (0.000) <<<
#
# iqr colexified_knn@3 22.84 (0.000) <<<
# iqr colexified_knn@5 29.07 (0.000) <<<
# iqr colexified_SVC 35.44 (0.000) <<<
#
# log_fpm colexified_knn@3 7.48 (0.000) <<<
# log_fpm colexified_knn@5 9.96 (0.000) <<<
# log_fpm colexified_SVC 5.75 (0.000) <<<
#
# concreteness colexified_knn@3 5.34 (0.000) <<<
# concreteness colexified_knn@5 5.56 (0.000) <<<
# concreteness colexified_SVC 11.87 (0.000) <<<
#
# 10_balance colexified_knn@3 17.80 (0.000) <<<
# 10_balance colexified_knn@5 16.58 (0.000) <<<
# 10_balance colexified_SVC 28.84 (0.000) <<<
#
# 25_balance colexified_knn@3 11.79 (0.000) <<<
# 25_balance colexified_knn@5 12.31 (0.000) <<<
# 25_balance colexified_SVC 12.49 (0.000) <<<
#
# 50_balance colexified_knn@3 6.44 (0.000) <<<
# 50_balance colexified_knn@5 7.00 (0.000) <<<
# 50_balance colexified_SVC 4.47 (0.000) <<<
#
# offset_std colexified_knn@3 27.72 (0.000) <<<
# offset_std colexified_knn@5 30.52 (0.000) <<<
# offset_std colexified_SVC 51.37 (0.000) <<<
#
# offset_range colexified_knn@3 31.80 (0.000) <<<
# offset_range colexified_knn@5 28.83 (0.000) <<<
# offset_range colexified_SVC 67.36 (0.000) <<<
#
# offset_iqr colexified_knn@3 10.53 (0.000) <<<
# offset_iqr colexified_knn@5 14.73 (0.000) <<<
# offset_iqr colexified_SVC 20.18 (0.000) <<<
#
# offset_log_fpm colexified_knn@3 -2.35 (0.019) <<<
# offset_log_fpm colexified_knn@5 -0.87 (0.383)
# offset_log_fpm colexified_SVC -1.59 (0.111)
#
# offset_concreteness insufficient variation
#
# offset_10_balance colexified_knn@3 17.45 (0.000) <<<
# offset_10_balance colexified_knn@5 16.37 (0.000) <<<
# offset_10_balance colexified_SVC 29.15 (0.000) <<<
#
# offset_25_balance colexified_knn@3 10.31 (0.000) <<<
# offset_25_balance colexified_knn@5 10.79 (0.000) <<<
# offset_25_balance colexified_SVC 11.51 (0.000) <<<
#
# offset_50_balance colexified_knn@3 5.57 (0.000) <<<
# offset_50_balance colexified_knn@5 6.37 (0.000) <<<
# offset_50_balance colexified_SVC 4.70 (0.000) <<<
