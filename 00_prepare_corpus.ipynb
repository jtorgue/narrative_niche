# %% [markdown]
# # Data Prep DoReCo
#
# This script creates a pickle file containing a prepared version of the DoReCo corpus, removing some irregularities and characteristics that would make subsequent processing more difficult.

# %%
import csv
import os
from collections import defaultdict, Counter
import dill as pickle
import numpy as np
import time

from langdetect import detect
import re
from googletrans import Translator
translator = Translator()#
import spacy
nlp = spacy.load('en_core_web_lg')
#
REP = dict([l.strip('\n').split(',') for l in open('manual_corrections.csv')])
dn = '/home/barend/Google Drive/data/doreco/' # path to corpus files

# %% [markdown]
# ## 1. get raw corpus and preprocess
#
# extracts for all csv-s with an 8-character language code an initial unprocessed corpus, consisting of the free translation (ft), the text (tx) and the glosses, where each gloss consists of the word w, the word index wi, the morpheme array M, the gloss array G, the part-of-speech array P, the start time and the end time.

# %%
punct = '.,?\"§«»…*()[]–. \t —/’`'
exclusion_markers = {'<p:>', '', '[xxx]', '****', 'xxx', '***', 'X', '.', "'.'"}
parenthetical_content = '(=|i.e.|\*|\?|…|[Ll]it.|alt:|\d+|sic|[A-Z]{2,}|noise|laughter|inaudible|unclear|or|---)'

def clean_wr(wr,lg):
    wrx = re.sub('<<.*?>(.*)>', r'\1', wr).strip(punct + '-').rstrip('!').lower()
    wrx = wrx.strip("'") if lg[:4] not in {'arap', 'goem', 'vera', 'trip'} else wrx
    return wrx
    
def clean_tx(tx,lg):
    tx = re.sub('\(\?\)', '', tx)
    tx = re.sub('#', '', tx)
    return ' '.join(filter(lambda w : w not in exclusion_markers and w[0] not in '<',
                           map(lambda w : clean_wr(w,lg), tx.split())))

def clean_gl(gl):
    gl = re.sub(r'\bsaid\b', 'say', gl)
    gl = re.sub(r'\bmen\b', 'man', gl)
    return gl.strip('".-=?')

# %%
corpus = defaultdict(lambda : defaultdict(lambda : defaultdict(lambda : {})))
for d in filter(lambda d: d[8:12] == '.csv', sorted(os.listdir(dn))):
    matches = []
    for l in list(csv.DictReader(open(dn + d))):
        lg,fi,li,wi = l['lang'], l['file'], l['ref'], l['wd_ID']
        tx = clean_tx(l['tx'],lg)
        ft = l['ft']
        wr = clean_wr(l['wd'],lg)
        #
        if ft in exclusion_markers or re.match('.*[a-zЁёА-я]', ft) == None: continue
        if tx in exclusion_markers or tx[0] == '*?.#': continue
        if wr in exclusion_markers or wr[0] == '<': continue
        # weeds out bad FT, TX and WR
        #  
        M = list(filter(lambda m : m not in exclusion_markers, l['mb'].lower().split())) if re.match('\*+', l['mb']) == None else []
        G = (list(map(lambda m : clean_gl(m),
                     filter(lambda m : m not in exclusion_markers, l['gl'].split()))) 
             if re.match('\*+', l['gl']) == None else [])
        if len(M) != len(G) and len(M) == 0 or len(G) == 0:
            M,G = [], []
        corpus[d][fi][li]['gloss'] = (corpus[d][fi][li].get('gloss', []) + [{'w':wr,'wid':wi,'M':M,'G':G}])
        corpus[d][fi][li]['ft'] = ft
        corpus[d][fi][li]['tx'] = tx
    nlines = len([l for f in corpus[d] for l in corpus[d][f]])
    glosses = Counter((gi for f in corpus[d] for l,elt in corpus[d][f].items() for g in elt['gloss'] for gi in g['G']))
    print(d, nlines, len(glosses))
# Out:
# anal1239.csv 2848 0
# apah1238.csv 4411 641
# arap1274.csv 3158 2135
# bain1259.csv 2926 1029
# beja1238.csv 6308 2036
# bora1263.csv 3820 1681
# cabe1245.csv 2052 1949
# cash1254.csv 1764 1129
# dolg1241.csv 2428 1982
# even1259.csv 2311 1667
# goem1240.csv 2533 856
# goro1270.csv 4339 1465
# hoch1243.csv 971 1094
# jeha1242.csv 1358 469
# jeju1234.csv 1958 1173
# kaka1265.csv 4606 1179
# kama1351.csv 9284 1473
# kark1256.csv 2187 0
# komn1238.csv 7524 4348
# ligh1234.csv 1437 0
# lowe1385.csv 1149 0
# movi1243.csv 2178 1130
# ngal1292.csv 1677 564
# nisv1234.csv 1675 1054
# nngg1234.csv 6224 1147
# nort2641.csv 834 1655
# nort2875.csv 2693 878
# orko1234.csv 2911 647
# pnar1238.csv 930 1175
# port1286.csv 1301 719
# resi1247.csv 1248 0
# ruul1235.csv 2924 1833
# sadu1234.csv 1456 0
# sanz1248.csv 699 758
# savo1255.csv 779 751
# sout2856.csv 1548 1173
# sout3282.csv 2271 0
# stan1290.csv 0 0
# sumi1235.csv 2472 565
# svan1243.csv 1299 0
# taba1259.csv 632 1108
# teop1238.csv 1970 1034
# texi1237.csv 2818 726
# trin1278.csv 1843 1334
# tsim1256.csv 1591 0
# urum1249.csv 2297 1797
# vera1241.csv 1932 972
# warl1254.csv 2009 0
# yong1270.csv 866 0
# yuca1254.csv 994 0
# yura1255.csv 14115 0

# %% [markdown]
# ### 2. gloss-morph alignment
#
# Simple segmentation of glosses and morphemes leaves several languages with imperfect gloss-morph alignments (per word). This code probabilistically resolves this.

# %%
import networkx as nx
from itertools import product

def get_dtw(A, B, P):
    dtw = np.ones((len(A),len(B)))
    path = [[[] for j in range(len(B))] for i in range(len(A))]
    #
    for i in range(len(A)):
        for j in range(len(B)):
            p = P[A[i],B[j]]
            if i > 0 and j > 0 and dtw[i-1,j-1] >= dtw[i,j-1] and dtw[i-1,j-1] >= dtw[i-1,j]:
                path[i][j] = path[i-1][j-1] + [(i,j)]
                dtw[i,j] = dtw[i-1,j-1] * p
            elif i > 0 and (j == 0 or dtw[i-1,j] >= dtw[i,j-1]):
                path[i][j] = path[i-1][j] + [(i,j)]
                dtw[i,j] = dtw[i-1,j] * p
            else:
                path[i][j] = path[i][j-1] + [(i,j)]
                dtw[i,j] = dtw[i,j-1] * p
            #print(i,j,dtw[i,j],path[i][j])
    G = nx.Graph()
    for i,j in path[-1][-1]:
        G.add_edge((0,i),(1,j))
    clusters = [(tuple(map(lambda x : A[x[1]], sorted(filter(lambda x : x[0] == 0, c), key = lambda x : x[1]))),
                 tuple(map(lambda x : B[x[1]], sorted(filter(lambda x : x[0] == 1, c), key = lambda x : x[1]))))
                for c in sorted(nx.connected_components(G))]
    return clusters

def get_pjoint_MG(corpus, doc):
    MG,GM = defaultdict(lambda : Counter()),defaultdict(lambda : Counter())
    for f in corpus[doc]:
        for l in corpus[doc][f]:
            for g in corpus[doc][f][l]['gloss']:
                M = g['M']
                G = [gs for g in g['G'] for gs in split_g(g)]
                for m,g in product(M,G):
                    MG[m][g] += 1
                    GM[g][m] += 1
    pMiG = { g : Counter({ m : v/sum(GM[g].values()) for m,v in GM[g].items()}) for g in GM}
    pGiM = { m : Counter({ g : v/sum(MG[m].values()) for g,v in MG[m].items()}) for m in MG}
    pjoint = { (m,g) : pMiG[g][m] * pGiM[m][g] for g in GM for m in GM[g]}
    return pjoint

def split_g(g):
    gn = re.sub('([A-Z])/(\w)', r'\1.\2', g.strip('-='))
    gn = re.sub('(\w)/([A-Z])', r'\1.\2', gn)
    gni = re.split('[/=\-._:,()\\\\\[\]~\<\>+\sː]', gn)
    return [gsub.strip('?!/;,.\\*%"\'`') for gsub in gni if gsub.strip('?!/;,.\\*%"\'`') != '']

# %%
def morph_gloss_alignment(corpus, verbose=1):
    for f in corpus:
        if verbose > 0: 
            print('='*9,f.upper())
        P = get_pjoint_MG(corpus, f)
        i = 0
        for fi in corpus[f]:
            for li in corpus[f][fi]:
                for gi, g in enumerate(corpus[f][fi][li]['gloss']):
                    M = list(filter(lambda g : g not in {'<p:>','****', '***'}, g['M']))
                    G = list([gs for g in (g['Gt'] if 'Gt' in g else g['G']) for gs in split_g(g)])
                    #
                    if len(M) == len(G): 
                        MGa = [((a,),(b,)) for a,b in zip(M,G)]
                    elif len(G) > 0 and len(M) > 0: 
                        MGa = get_dtw(M,G,P)
                        i += 1
                        if verbose > 1 and i < 10: print(f[:4], '\t', M, '\n\t', G, '\n\t', ['.'.join(m) for m,g in MGa], ['.'.join(g) for m,g in MGa])
                    else: MGa = []
                    corpus[f][fi][li]['gloss'][gi]['M'] = ['.'.join(m) for m,g in MGa]
                    corpus[f][fi][li]['gloss'][gi]['G'] = ['.'.join(g) for m,g in MGa]
    return corpus

corpus = morph_gloss_alignment(corpus, verbose = 0)

# %% [markdown]
# ### 3. add English translations for non-English free translations and glosses
#
# Free Translations in languages other than English are detected and translated, with Google Translate, into English.

# %%
def detect_ft_language(corpus, f, fi, verbose=False):    
    ft_lg = Counter()
    for li in corpus[f][fi]:
        ft = corpus[f][fi][li]['ft']
        try: ft_lg[detect(ft)] += 1
        except: pass 
    if verbose: print(ft_lg.most_common(3))
    if len(ft_lg) == 0: return None, 0
    top_lg, certainty = next(((f,c) for f,c in ft_lg.most_common() if f != None),(None,sum(ft_lg.values())))
    return top_lg, certainty/sum(ft_lg.values())

def add_ft_translation(corpus, verbose = 1):
    for doc in corpus:
        print(doc)
        for f in corpus[doc]:
            ft_buffer, ft_keys = '', []
            top_lg, certainty = detect_ft_language(corpus, doc, f, False)
            if top_lg == 'en': continue
            for l in corpus[doc][f]:
                ft = corpus[doc][f][l]['ft']
                if len(ft_buffer) + len(ft) + 1 > 5000:
                    print('  translating', doc, f, top_lg, '\n', len(ft_buffer), ft_buffer[:80].replace('\n', ' | '))
                    tr = translator.translate(ft_buffer, 'en', top_lg).text
                    for tri, lx in zip(tr.split('\n'), ft_keys):
                        corpus[doc][f][lx]['ft'] = tri
                    ft_buffer, ft_keys = '', []
                    time.sleep(0.5)
                ft_buffer += ft + '\n'
                ft_keys.append(l)
                #
            if ft_buffer != '':
                print('  translating', doc, f, top_lg, '\n', len(ft_buffer), ft_buffer[:80].replace('\n', ' | '))
                tr = translator.translate(ft_buffer, 'en', top_lg).text
                for tri, lx in zip(tr.split('\n'), ft_keys):
                    corpus[doc][f][lx]['ft'] = tri
    return corpus 

corpus = add_ft_translation(corpus, verbose = 1)
# Out:
# anal1239.csv
# apah1238.csv
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4965 saya sedang bertanya kepada Kristian | apakah saya harus mengulang dari apa yang s
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4989 karena ada salah satu mereka yang mengganggu dia | kami turun ke Kulet | mereka dapa
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4995 ya, mereka sedang bawa itu | mereka masak makanan sambil menanti mereka turun | bapa
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4976 mereka di sana juga | karena kami dengar dari radio | bapak Rot yang memberitahukann
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4968 karena Awanon sudah duluan ke sana | di sana mereka sudah mendengarnya | karena mere
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4994 mereka berjaga di bawah, dari mana mereka akan turun ke sini bersama-sama | tempat
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4985 saya katakan bahwa mereka tinggal seperti itu | kemudian | mereka, babi | orang, untuk
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4985 orang lain tidak mau membuka diri | hanya sedikit orang saja | bapak Handimu | anaknya
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4965 dari bapak Zollner | karena cara berpikir kedua istrimu perbeda | karena kamu bekerj
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  5000 orang dari Kulet ini tidak bisa membunuhmu, kalau itu terjadi, aduh | mereka ke sa
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4996 kami bisa bertanya, katanya | dia meminta untuk bertanya di sana, dia e | ah, di sin
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4977 kami tinggal di arah mana? | itu di mana? | apakah di hilir kali Yahuli? | bagaimana d
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4984 saya juga belum tahu dengan jelas tentang hal itu | hanya sedikit saja | karena itu
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  4956 ketika Lewi masuk ke rumah dan sedang makan | dari orang lain | guru | kenapa, orang | y
#   translating apah1238.csv doreco_apah1238_interview_IP_Ware id
#  583 oh ya, jadi dia membawa tomat itu kepada istri bapak Bentz? | ya, itu Tuhan | Tuhan
#   translating apah1238.csv doreco_apah1238_TGB_Firaon_Yoas_2-15 id
#  4976 kami yang bicara duluan | saya tidak punya itu | saya | saya tidak punya itu | tidak sam
#   translating apah1238.csv doreco_apah1238_TGB_Firaon_Yoas_2-15 id
#  172 and next to it there are also three | and its shape is like that, then | on the east
# arap1274.csv
# bain1259.csv
#   translating bain1259.csv doreco_bain1259_DJI101210AC2 fr
#  4871 les rituels traditinels | d'acord rituel | le jour ou son mari descede | aprés les fun
#   translating bain1259.csv doreco_bain1259_DJI240211AC fr
#  4956 du passé | le travail | Si tu as été adopté | Peut-être si ton père est mort | les tiens
#   translating bain1259.csv doreco_bain1259_DJI240211AC fr
#  4962 je ne te dis pas que tout le monde est gentil | S'il n'est pas gentil il cache | Si
#   translating bain1259.csv doreco_bain1259_DJI240211AC fr
#  2867 Et auparavant, comment l'enfant avait peur d'un vieux. | Et auparavant est-ce que
#  1123 Жил один человек, эвенк. | Ой-ой-ой, шутник. | Он был большой обманщик. | А тогда были
#   translating even1259.csv doreco_even1259_2014_Yukta_UdygirVP_LO ru
#  2075 В молодости я охотился со своим дядей. | Ну, на диких оленей. | Здесь была звероферм
#   translating even1259.csv doreco_even1259_2016_Yerbogachyon_MongoPI_LR7 ru
#  1466 Мой дедушка рассказывал. | «Когда я был маленький, мы с младшим братом, — он говор
#   translating even1259.csv doreco_even1259_2016_Yerbogachyon_TsurkanII_LB1 ru
#  2627 Ну, по-эвенкийски | Дедушка, бабушка у меня были. | Ну, хорошо мы жили. | Тогда дедушк
#   translating even1259.csv doreco_even1259_2016_Yerbogachyon_TsurkanII_LF_1 ru
#  1625 Ну, расскажу. | Моя бабушка рассказывала, старая, сказку, как одна женщина была, ш
#   translating even1259.csv doreco_even1259_2016_Yerbogachyon_TsurkanII_LR2 ru
#  1428 Мы ходили по ягоду два года [назад]. | Два года уже прошло. | Сюда, наверное, киломе
# goem1240.csv
# goro1270.csv
#   translating goro1270.csv doreco_goro1270_20131108b_20150725j sw
#  4964 nataka kuongea kuhusu asali | asali ni tamu | asali hutengenezwa na nyuki | asali hute
#   translating goro1270.csv doreco_goro1270_20131108b_20150725j sw
#  1079 mume wake huyo pia akakubali ni mjinga kabisa | wote ni wajinga | mume akakubali | bas
# hoch1243.csv
# jeha1242.csv
# jeju1234.csv
# kaka1265.csv
# kama1351.csv
#   translating kama1351.csv doreco_kama1351_PKZ_196X_GirlsWent_flk af
#  82 Girls went to dig potatoes. | To cut all the grass and to cover potato with ground
# kark1256.csv
# komn1238.csv
# ligh1234.csv
# lowe1385.csv
#   translating lowe1385.csv doreco_lowe1385_MEW-008-20111119 de
#  4632 Ja. | Ja. | Ja, das sagt man doch immer so, | aber wie das, ich weiß jetzt nicht auf S
#   translating lowe1385.csv doreco_lowe1385_MEW-062-20121023 de
#  4951 Ja. | Ja, wenn du in einem Dorf lebst, | wenn man mit den Leuten zusammenkommt, | das
#   translating lowe1385.csv doreco_lowe1385_MEW-062-20121023 de
#  1664 Und dann ziehen die Burschen, äh die, die Männer mit Musik in den Sportlerheim e
#   translating lowe1385.csv doreco_lowe1385_MEW-063-20121023 de
#  4999 Wenn die Fastnacht vorüber ist, dann kommt Ostern. | Ostern ist ein kirchliches Fe
#   translating lowe1385.csv doreco_lowe1385_MEW-064-20121023 de
#  4971 Ich kann ... | Ich könnte Ihnen jetzt viel davon erzählen, welche Späße wir getrie
#   translating lowe1385.csv doreco_lowe1385_MEW-064-20121023 de
#  4632 Der ist kein guter, sondern ein fauler Bauer, | der versteht es nicht zu arbeiten.
#   translating lowe1385.csv doreco_lowe1385_MEW-066-20121023 de
#  671 Ich will nochmal sagen, | wir können dem Herren nicht genug danken, | diesem König, |
#   translating lowe1385.csv doreco_lowe1385_MEW-087-20121102 de
#  4887 Hmm, hmm. | Hmm. | Na ja, das war eben so, als wir junge Burschen waren, da haben wi
#   translating lowe1385.csv doreco_lowe1385_MEW-087-20121102 de
#   translating nisv1234.csv doreco_nisv1234_T30_31-08-2015_Bwenahai_Limeten_1092 fr
#  3717 Il continue, il brûle une noix de coco, elle est chaude, Vierarar la boit puis v
#   translating nisv1234.csv doreco_nisv1234_T31_31-08-2015_Bwenahai_Limeten_Namangi-Livenbumbrao_1093 fr
#  4934 Où est le chemin ? | -- L'herber pousse, Bat et ses frères sont là. | Bat, | Keskisvas
#   translating nisv1234.csv doreco_nisv1234_T31_31-08-2015_Bwenahai_Limeten_Namangi-Livenbumbrao_1093 fr
#  1043 vous ouvrez, euh... et il vit encore, je l'ai seulement enrobé dans la feuille l
#   translating nisv1234.csv doreco_nisv1234_T34_30-08-2015_Farun_Rosie_1088 fr
#  4980 L'histoire se passe là, | à Liror. | Une femme enfante un enfant... une fille. | une p
#   translating nisv1234.csv doreco_nisv1234_T34_30-08-2015_Farun_Rosie_1088 fr
#  1643 Ensuite, ils vont et restent dessus. | Eux... la femme se dépêche, les esprits, un
#   translating nisv1234.csv doreco_nisv1234_T41_01-09-2015_Bwenhai_Kalbatik_Tunglarer_1097 fr
#  4970 Où est le chemin | L'herbe pousse | une femme est là | quelques hommes sont là | ils son
#   translating nisv1234.csv doreco_nisv1234_T41_01-09-2015_Bwenhai_Kalbatik_Tunglarer_1097 fr
#  4411 Il les a tranchées jusqu'à ce que deux seulement restent. | «Eh!» dit-il à ses deu
#   translating nisv1234.csv doreco_nisv1234_T5_15-12-2013_Levetbao_Aven_Nhasu-Nivu_1091 fr
#  4945 Je veux dire une stori... une histoire aux enfants. | L'histoire d'un rat et d'un
#   translating nisv1234.csv doreco_nisv1234_T5_15-12-2013_Levetbao_Aven_Nhasu-Nivu_1091 fr
#  178 la tortue rampe jusqu'à la mer et s'en va, le rat reste sur la forêt. | Ensuite, c
# nngg1234.csv
# nort2641.csv
# nort2875.csv
# orko1234.csv
# pnar1238.csv
# port1286.csv
#   translating port1286.csv doreco_port1286_08-22-11_IlsonMagekon no
#  3427 nem blong mi Ilson ... Ilson Magekon | mi mi wantem talem wan stori abaot ol pijin
# resi1247.csv
#   translating resi1247.csv doreco_resi1247_candi_res es
#  1544 ahora voy a decir de lo que nos están haciendo los mestizos | hay un mestizo él vi
#   translating resi1247.csv doreco_resi1247_cuentoresbruj es
#  3585 dizque había un brujo | y dice ya le abandonó | el brujo dizque todos su cosa su bru
#   translating resi1247.csv doreco_resi1247_cuentores_11 es
#  1045 ya ahora acá lechuza de el voy avisar | como lo que era lechuza dice que su mujer
#   translating resi1247.csv doreco_resi1247_cuentores_3 es
#  4981 cuando yo era niño su mamá finada de mi mamá lo que me contó voy a contar de miv
#   translating resi1247.csv doreco_resi1247_cuentores_3 es
#  3622 Este es tu huella no mas dijo el zorro | No amigo, dónde voy a vivir. | Entonces vam
#   translating resi1247.csv doreco_resi1247_cuentores_7 es
#  1778 Vamos a contar del gusano malaguero | Dizque una mujer | Una mujer dizque estaba mar
#   translating resi1247.csv doreco_resi1247_cuentores_8 es
#  4991 madre ¿qué era? ¿montete? | lo que su madre | su madre montete lo que era el "huevo
#   translating resi1247.csv doreco_resi1247_cuentores_8 es
#  342 mordiendo el hueso dizque (xxxxx) | "no lo vas a morder dizque le dijo el “huevo d
#   translating resi1247.csv doreco_resi1247_cuentores_9 es
#  1244 Origen del aguaje | El origen | Origen del aguaje | Un árbol de aguaje dizque, solo un
#   translating resi1247.csv doreco_resi1247_dyushi es
#  3012 Dyushi dice que comió a su mamaá, de esto le voy a contar ahora. | Cállate, el nos
#   translating resi1247.csv doreco_resi1247_experabuPA es
#  1878 ahora voy a contar lo que me contó mi abuela finada | allá en su tierra cuando era
#   translating resi1247.csv doreco_resi1247_experi_res_1 es
#  3166 ahora voy avisar cuando era joven monte lo que fuimos | con mis dos cuñados tambié
#   translating resi1247.csv doreco_resi1247_experi_res_2 es
#  2754 otra vez voy a contar lo que yo andaba en el monte de ese otra vez voy a contar |
#   translating resi1247.csv doreco_resi1247_experi_res_RA es
#  1863 ahora hijo te empezaré a contar | como es que nos fuimos al  monte | que nos vamos a
#   translating resi1247.csv doreco_resi1247_fiesta_rec_RA es
#  1204 mis padres finados cuando estaban con nosotros en la cas grande, hijo, ahora te
#   translating resi1247.csv doreco_resi1247_hechohoyRA es
#  2206 por la mañanita me levante y fui a la chacra | yendo ya saqué yuca despues de saca
#   translating resi1247.csv doreco_resi1247_lifestoryres_1 es
#  3093 venimos de alla, del río vehnítsohni | allá he nacido, allá | la hermana finada de m
#   translating resi1247.csv doreco_resi1247_res_tramp_1 es
#  914 (como) se hace trampa | ¿Con que soga se hace trampa? | ¿Soga de pretina (esp. de ár
#   translating resi1247.csv doreco_resi1247_res_tramp_7 es
#  326 júgabu (nombre de una trampa) | nombre de trampa tu haces bastante de una vez algu
#   translating resi1247.csv doreco_resi1247_sacha_res es
#  4865 ahora el cuento de sachavaca de ese voy a decir | las hijas de tabaco eran dos | y d
#   translating resi1247.csv doreco_resi1247_storyalicia es
#  1211 ¿De cuando tiempo vas a volver? | rápido | ¿Vas a llevar a mi nieta? | Llévala y dale
#   translating resi1247.csv doreco_resi1247_vida_PA es
#  2712 ahora como yo crecí de eso voy a contar | cuando era muchacho como yo crecí | yenton
# ruul1235.csv
# sadu1234.csv
# sanz1248.csv
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4862 18 лет. свадибу сыграли, после свадибы в Цаалдарки дояркой работала | хоть и была
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4793 провожали этого человека, разговаривали. ночью танцевали, этому человеку уважени
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4842 пошел пасти, сбился с пути и стадо незаметно для него ушло к этим местам, в эту
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4746 встретились там. какие новости? как дела? спрашивает Хан. новостей нет, отвечает
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4848 к нам приходили люди с Украины на костылях. это в голодное время? да. у моей мам
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4895 поели, садака раздали. вот так эти оба моста сделали. два раза разрушались. река
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4916 только кукуруза была. вязанку дров носила продавать, приносила банку или две бан
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4840 и весь дом с сараем, с местом для дров и сена остался нам. в этом трехэтажном до
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4875 наш народ простой. правда и у нас уже обычаи изменились. наши тоже теперь золото
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  4947 на следующий день с твоим дедушкой  мой сын Гаджи пошел. вчера, говорит твой дед
#   translating sanz1248.csv doreco_sanz1248_Sanzhi_09_08_2012_RMDF_001 ru
#  1640 эту историю расскажу, больше не буду, сейчас плохо себя чувствую. так вот пошли
# savo1255.csv
# sout2856.csv
# sout3282.csv
# stan1290.csv
# sumi1235.csv
# svan1243.csv
# taba1259.csv
# teop1238.csv
# texi1237.csv
#   translating texi1237.csv doreco_texi1237_JuanFlojo es
#  4996 Entonces, dicen que un hombre tiene dinero, | está rico. | Tiene dos hijos. | Trabajan
#   translating texi1237.csv doreco_texi1237_JuanFlojo es
#  4977 tú vas a ir. | ¿Quién diablos me va a comer? dice. | El que te va a comer dice es el
#   translating texi1237.csv doreco_texi1237_JuanFlojo es
#  4981 Ya lo había matado a golpes. | No se dice [a sí mismo], | ahora, ¿cómo le vamos a ha
#   translating texi1237.csv doreco_texi1237_JuanFlojo es
#  4997 Estoy lastimado dice. | Me pegaron en mi pecho. | Ahí vete dice. | Ahí está el catre. |
#   translating texi1237.csv doreco_texi1237_JuanFlojo es
#  4990 te debo. | No dice, no me debes. | Yo vengo lejos. | Vengo lejos | a buscar otro hombre |
#   translating texi1237.csv doreco_texi1237_JuanFlojo es
#  4991 Te necesito. | No sé cuánto me vas a cobrar dice. | ¿Porqué? dice. HER | Quiero que me
#   translating texi1237.csv doreco_texi1237_JuanFlojo es
#  4985 ¿Pues qué cosa como yo? | Gente dice como. | Ahh dice, yo también eso como. | Ahh buen
#   translating texi1237.csv doreco_texi1237_JuanFlojo es
#  4949 Ahorita vamos a tirar. | No te molestes dice. | Nos vamos a tirar. | Ahora sí | me toca
#   translating texi1237.csv doreco_texi1237_JuanFlojo es
#  4442 Ahora sí ya van las dos botella [ya tomó dos], ¡pa su gallo! | Juan Flojo, ¡pa su
#   translating texi1237.csv doreco_texi1237_LaChichimeca es
#  4999 Este era un hombre | [que] tenía su esposa. | Una vez se murió su esposa. | Murió su m
#   translating texi1237.csv doreco_texi1237_LaChichimeca es
#  4986 ¡Juta!, sí ustedes son mis hijos dice. | Ustedes [son] mis hijos dice. | No, | no me r
#   translating texi1237.csv doreco_texi1237_LaChichimeca es
#  4436 ¡Ahora no la volteen. | Ahí déjala, | que esté tapada! | Hasta los siete días cuando v
#   translating texi1237.csv doreco_texi1237_LaMujerFloja es
#  4986 Este era un hombre. | Un muchacho, pues. | Lo casaron. | Su papá lo casó con una mujer
#   translating texi1237.csv doreco_texi1237_LaMujerFloja es
#  4985 El que me grite, también lo voy a balacear. | El que no trabaje, también lo voy a
#   translating texi1237.csv doreco_texi1237_LaMujerFloja es
#  1552 Dice: Sí dice, yo lo maté dice. | Pues ahora vas a pagar. | Si no, no vas a salir de
#   translating texi1237.csv doreco_texi1237_Pepito es
#  1550 Entonces [en] una escuela | [está] la profesora. | Llegaron ahí ellos, | los niños. | Ho
# trin1278.csv
# tsim1256.csv
#   translating tsim1256.csv doreco_tsim1256_IGS0229_2015-12-21_GG_1 sw
#  4221 Mimi nemzaliwa mwa elfu moja mia tisa sitini na mbili | Sasa nina miaka 54 | Mimi za
# urum1249.csv
#   translating urum1249.csv doreco_urum1249_UUM-TXT-CL-00000-B11 pt
#  93 Sea, sea narrow | Darkness is inside | If you don’t believe count and see | It’s sixte
# vera1241.csv
# warl1254.csv
# yong1270.csv
#   translating yong1270.csv doreco_yong1270_crdo-NRU_F4_10_AGRICULTURAL_ACTIVITIES fr
#  4956 (à) Yongning, eh bien, c’est comme ça qu’on travaille, n’est-ce pas: | alors, cett
#   translating yong1270.csv doreco_yong1270_crdo-NRU_F4
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-AN-00000-02 es
#  245 todos los días, ñprque cada persona | vive de diferente manera, aunque viven en un
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-AN-00000-04 es
#  4970 lo que he escuchado que cuenten mis abuelos, por lo s hombres que conocen un poc
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-AN-00000-04 es
#  1673 ttodos, si pudieras verlos , todos tienen facciones  españoles | hasta sus joyas s
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-BO-00000-22 es
#  4980 un día, | cuando, mi padre me contó, | él me dijo que el nombre del cuento es Juan s
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-BO-00000-22 es
#  933 y fueron y sacaron al rey, lo sacaron | y le diejron al brujo que lo  transfora a
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-BO-00000-23 es
#  4528 el moustro que dicen? | ese moustro?, si es el moustro si lo conozco, | se un poco | p
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-CD-00000-12 es
#  4273 en estos días todo a cambiado | hablemos sobre los valores o | a dar gracias, a resp
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-CH-00000-04 es
#  4448 Del ch'a'aj cháak solo conozco un poco | un día me integré en un lugar en donde es
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-CO-00000-04 es
#  44 poner esas grandes tortillas , | jaanal pixan |
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-CO-00000-12 es
#  4996 ésta es un poco dificil de explicar, asi como su relato. | no sé mucho, | este... pa
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-CO-00000-12 es
#  190 porque como el de caldo no lo pueden llevar, porque a se les derrama en el camin
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-CO-00000-25 es
#  4986 El píibil waaj tal como lo acostumbra realizar mi  madre y mi padre es un | un tra
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-CO-00000-25 es
#  822 el píib también ya se ha quemado toda la leña, | y se comienza a rompera las piedr
#   translating yuca1254.csv doreco_yuca1254_YUC-TXT-PA-00000-04 es
#  4013 Para ir hasta | estando aqui en carrillo para ir hasta Hu May y llegar XHazil, | par
# yura1255.csv
#   translating yura1255.csv doreco_yura1255_MS-LM_AscGer_1 es
#  4999 Y ya pueden empezar. | Ya, haber voy a hacer esto. | Para después este. | Y ya. | En idi
#   translating yura1255.csv doreco_yura1255_MS-LM_AscGer_1 es
#  4980 Esta bien. | Ustedes, haaa. | Ahora me van a decir. | Ustedes. | Ha.. | Cual nuestro idiom
#   translating yura1255.csv doreco_yura1255_MS-LM_AscGer_1 es
#  4995 A veces me voy abajo. | Solo. | A veces solo por hablar. | Cuando se va... | Se va. | Ya. |
#   translating yura1255.csv doreco_yura1255_MS-LM_AscGer_1 es
#  4982 Por eso no muy bien. | No muy bien. | Como en nuestro idioma. | Hablamos en nuestro id
#   translating yura1255.csv doreco_yura1255_MS-LM_AscGer_1 es
#  4990 Son cuatro las mujeres. | Ese mis hijo el primero se llama. | Después. | Su hermana se
#   translating yura1255.csv doreco_yura1255_MS-LM_AscGer_1 es
#  4997 Los escucho también. | Nuestros parientes. | Pero igual. | Igual nustro idioma. | Hablan
#   translating yura1255.csv doreco_yura1255_MS-LM_AscGer_1 es
#  1832 Salio y lo miro. | Mi esposa. | No avia dice. | Bien era su voz. | Después cuando llegue
#   translating yura1255.csv doreco_yura1255_SocCog-YUZ103-1 es
#  4991 A este. | Otra ya. | Bueno. | Ahora vamos a empezar. | Por fin. | Bueno, yo pensaba que...
#   translating yura1255.csv doreco_yura1255_SocCog-YUZ103-1 es
#  4984 'Mi esposa.' | 'Así le llegó dice.' | 'Contento la voy aver, tal vez no.' | Tal vez as
#   translating yura1255.csv doreco_yura1255_SocCog-YUZ103-1 es
#  1759 Porque no está borracho ya está pensando. | Así tal vez. | 'Así voy a hacer tal vez.
#   translating yura1255.csv doreco_yura1255_SocCog-YUZ103-2 es
#  4991 Entonses ahoraya. | Así lo voy a leer. | Ahora tienen que  ponerlo con cuidado. | Dibu
#   translating yura1255.csv doreco_yura1255_SocCog-YUZ103-2 es
#  4993 Así lo hizo. | Sin ropase quedo entoces el hombre. | Aquí. | Bastante triste se quedo.
#   translating yura1255.csv doreco_yura1255_SocCog-YUZ103-2 es
#  369 De verdad siempre. | Después. | No quiero. | De verdad no. | Ya. | Jm. | Mjm... | están felize
#   translating yura1255.csv doreco_yura1255_SocCog-YUZ103-3 es
#  4996 Esta bien. | Am. | Así hemoshecho Jeremias este. | Lo hemos mirado. | Primero hemos mira
#   translating yura1255.csv doreco_yura1255_SocCog-YUZ103-3 es
#  4979 Hacer. | Mi huerto. | O mi trabajo. | Así andar con felizidad. | Con mi marido. | Mi hijo.
#   translating yura1255.csv doreco_yura1255_SocCog-YUZ103-3 es
# ...
#     FT: las raíces de cetico maramara, the roots of cetico maramara,
#     FT: A ellos pues para que no nos m So they don't look at us, it j
#     FT: A nosotros no nos miren Don't look at us
#     FT: Este lado no mas estamos pidie This side we are asking for no
#     FT: Ese lado también hay su pequeñ There is also its small obstac
#     FT: Ellos, si nosotros no decimos  They, if we don't say about th
#     FT: Ellos dice cuando están con no They say when they are with us
#     FT: Ese clasecita espero que nos e That little class I hope he li
#     FT: Y luego si olvidamos algunas p And then if we forget some par
#     FT: A nosotros nos muestre como di He shows us, as I say, his pre
#     FT: Cuanto tiempo porque quizás no How long because perhaps we di
#     FT: Por esa razón pedimos a ál a t For that reason we ask him thr
#     FT: A él pedimos en este momento. We ask him at this time.
#     FT: En eso vamos a estar mañana That's what we'll be doing tom
#     FT: En ese pensamiento, como digo, In that thought, as I say, we
#     FT: Dentro de nuestro cuerpo, pidi Inside our body, asking like t
#     FT: Así eran esas cositas That's how those things were
#     FT: Esto no es nueva cosita, que e This is not a new thing, what
#     FT: Conforme que es, así pues espe As it is, so I hope we will mi
# [('es', 113), ('it', 3), ('ca', 2)]
#    doreco_bora1263_warEhko_mEE bora1263.csv
#     FT: Escuchen ustedes los que traba Listen, you who work
#     FT: De esta manera se tuesta la co In this way the coca of the pa
#     FT: Y la estrategia de la rapidez  And the strategy of the speed
#     FT: El Creador dice cuando nos cre The Creator says when he creat
#     FT: Y él solo tostaba su coca, apu And he just toasted his coke,
#     FT: Y supo el chinchilejo del alim And the chinchilejo knew about
#     FT: “¿qué cosa tan buena coquea el “what good thing does the Crea
#     FT: Viniendo él le dijo “hijo, ¿ha Coming he said "son, have you
#     FT: “sí, sí, abuelo, he venido a v "Yes, yes, grandfather, I have
#     FT: “muy bien, hijo”, le dice, “bi “Very good, son”, he says, “fi
#     FT: Ya coqueó del alimento He already coked from the food
#     FT: “ese era un poco de mi coca, h "That was a bit of my coke, so
#     FT: “ya abuelo”, le dice, “muy bie "and grandfather," he says, "v
#     FT: Sí le contesta, ya tuesta la c Yes, he answers, he already to
#     FT: Y dice que la coca se quemaba  And he says that the coca burn
#     FT: Tostando, empezó a machacar, l Toasting, he began to crush, t
#     FT: “abuelo”, le dijo, “te doy de  "Grandpa", he told him, "I'll
#     FT: “ya”, le dijo, coqueó el Cread "Yeah," he said, the Creator c
#     FT: “no”, dice “no, le ha quemado, “no”, he says “no, it has burn
#     FT: Y él le dice “abuelo, dame tu  And he says "grandfather, give
#     FT: “hijo”, le dice, “con lo poco  "Son," she tells him, "with wh
#     FT: “ya has coqueado, tostado, mac "You've already cooked, toaste
#     FT: Y a él dice se lo esconde cuan And he says he hides it when h
#     FT: Tiene dos nombres: “planta de  It has two names: "food plant"
#     FT: Y a él dice se lo esconde al c And he says he hides it from t
#     FT: Ya uno no sabía después vino e You didn't know anymore, then
#     FT: “abuelo”, le dice, “¿cómo está "Grandpa," he says, "how are y
#     FT: “aquí bien” “here good”
#     FT: “por eso he venido, abuelo”, l "That's why I came, grandfathe
#     FT: Y a todo que venia, le decía “ And to everyone who came, he s
#     FT: Y él había tostado bien And he had toasted well
#     FT: Lo tostó bien lo machucó, le c He toasted it well, he crushed
#     FT: Por eso dicen que el pájaro de That is why they say that the
#     FT: Entonces dijo el Creador: “la  Then the Creator said: "the co
#     FT: Coquearon normal así como noso They flirted normal just like
#     FT: “y como es eso, ááh” dice, “co "And how is that, ááh" he says
#     FT: “por eso le resultó poco”, dic "That's why it didn't work for
#     FT: “así será los que vienen despu "This is how it will be for th
#     FT: Y a él se esconde al pájaro de And he hides the bird from the
#     FT: Después de eso, el vino la ara After that, the food spider ca
#     FT: “hijo”, le dice, cuando machuc “son”, he tells him, when he w
#     FT: “hijo”, le dice, “¿a mi (has v "Son," he says, "have you come
#     FT: “sí, ¿cómo, abuelo, vas a mach "Yes, how, grandfather, are yo
#     FT: “muy bien, hijo” "very good son"
#     FT: La araña del alimento machucab The food spider crushed, crush
#     FT: Robando le colaba en sus dedos Stealing slipped through his f
#     FT: Y llevaba robando en sus dedos And he had stealing on his fin
#     FT: Y él también sacó poquita coca And he also took a little coke
#     FT: Y por último, cómo es la cosa, And finally, how is the thing,
#     FT: “ya, nieto”, le dice, “gracias "Yeah, grandson," he says, "th
#     FT: “pero mi coca era mucha y como "But my coke was a lot and sin
#     FT: Y todo lo que llevaba en sus d And everything that he carried
#     FT: Vaciaban y ya tenía su coca, c They emptied and he already ha
#     FT: Y a él también se lo esconde a And he also hides it from the
#     FT: Luego vino murciélago del alim Then the bat came from the foo
#     FT: “¿me has venido a visitar?” "Have you come to visit me?"
#     FT: “sí, que pena abuelo que tú só "Yes, what a pity, grandfather
#     FT: “muy bien nieto”, le dice, col "Very well, grandson," he tell
#     FT: También le resultó poquito su  His coke was also little
#     FT: Dice que él cuando él colaba s He says that when he strained
#     FT: Y a él también se lo esconde c And he also hides it when he d
#     FT: Estos fueron los que hicieron  These were the ones that made
#     FT: Y a todos ellos se los esconde And all of them are hidden
#     FT: Cuando todos estos están en me When all these are in our mids
#     FT: Por eso se debe tener la estra That is why those of us who wo
#     FT: “áh, dice, “de esta forma será “ah, he says, “this is how it
#     FT: el dijo dentro de su corazón,  he said inside his heart, it s
#     FT: A todos ellos se los esconde They are all hidden
#     FT: Después vino el hijo de la lag Then came the son of the sky s
#     FT: “abuelo”, le dice "Grandpa", he says
#     FT: “hijo, ¿me estás visitando?” “son, are you visiting me?”
#     FT: “sí, ¿es este tu coca abuelo?” "Yes, is this your coca grandp
#     FT: “si, nieto”, le dice, “no toda "Yes, grandson," he says, "I h
#     FT: “yo voy a tostar para ti abuel "I'm going to toast for you, g
#     FT: “muy bien, nieto,” le dice, “t “very good, grandson,” he says
#     FT: Ya atizaba la candela, el hijo He was already fanning the can
#     FT: Prendiendo, el escondió la can Burning, he hid the candle of
#     FT: Y encendió su candela de alime And he lit his candle of sweet
#     FT: Mediante esta estrategia se tu By means of this strategy the
#     FT: "Este quemará enseguida mi coc "This one will burn my coke ri
#     FT: Es que este hijo de lagartija  It is that this son of a lizar
#     FT: No era poco fuego, bajó el tos It was not a little fire, he l
#     FT: “abuelo”, le dice, “ven a coqu "Grandpa", he says, "come and
#     FT: Y él pensaba que la coca estab And he thought that the coke w
#     FT: “ááh”, dice, “este mi nieto sí “ahh”, he says, “this my grand
#     FT: Entonces así será que los que  So it will be that those who h
#     FT: Y dicen que también encendemos And they say that we also ligh
#     FT: Y cuando machucaba, él pensaba And when he crushed, he though
#     FT: Si no escondía la cabeza, y la If he didn't hide his head, an
#     FT: Hay dos ideas sobre ese asunto There are two ideas on that ma
#     FT: Es por eso que a veces aunque  That is why sometimes, even th
#     FT: Con esa estrategia, tostó rápi With this strategy, he roasted
#     FT: “abuelo”, le dice, “¡trae tu e “Grandpa”, she tells him, “bri
#     FT: bueno, dijo well he said
#     FT: Le llenó bien, bien tanqueado Filled him up well, well tanke
#     FT: “¿no tienes otro envase abuelo "Don't you have another contai
#     FT: “no tengo”, le dice "I don't have", he says
#     FT: “pero todavía hay acá” “but there are still here”
#     FT: “saca en el mismo envase que h "Take out in the same containe
#     FT: Botó el afrecho y también tanq He threw the bran and also tan
#     FT: “abuelo”, le dice, “¿no hay ot “Grandpa”, she says, “isn't th
#     FT: “ah”, dice, “muy bien hijo, gr “ah”, he says, “very good son,
#     FT: Bien, bien, bien, le creyó a é Well, well, well, he believed
#     FT: Y así fue y esta estrategia di And so it was and this strateg
#     FT: Y él es el que sabe todo And he is the one who knows ev
#     FT: Y fue él, el único que ayudaba And it was he, the only one wh
#     FT: Y le dio el Creador nuestro sa And the Creator gave him our w
#     FT: Y con la estrategia de él se t And with his strategy the coke
#     FT: Y todo eso cuando la coca aume And all this when the coke inc
#     FT: Por eso el hijo de lagartija d That's why the son of the liza
#     FT: Por eso está en los cercos de  That's why it's on the fences
#     FT: También se le menciona en cant It is also mentioned in songs
#     FT: esta lagartija viene a quemar  this lizard comes to burn the
#     FT: Esta lagartija viene a quemar  This lizard comes to burn wasp
#     FT: Canción de madrugada, en un in Early morning song, in an inte
#     FT: Así es como se trabaja coca de This is how party coke is work
#     FT: Y ya saben ustedes ya le he co And you know, I have already t
#     FT: Así es la historia de la estra This is the story of the strat
#     FT: Así era eso lo poco se escondí That's how it was, the little
#     FT: Y así otro en el mismo camino, And so another on the same pat
#     FT: Entonces nuestros antecesores  So our ancestors, your grandpa
#     FT: Eso ahí termina eso, la estrat That ends that there, the stra
# cabe1245.csv
# [('en', 5)]
# [('en', 10)]
# [('en', 48), ('sk', 1)]
# [('en', 10)]
# [('en', 15)]
# [('en', 36), ('ca', 2), ('pt', 1)]
# [('en', 27)]
# [('en', 21)]
# [('en', 3)]
# [('en', 17), ('pt', 1)]
# [('en', 5)]
# [('en', 24)]
#     FT: Eu já estava aprendendo como f I was already learning how to
#     FT: O jurití veio. estava rodeando The court came. he was circlin
#     FT: "Bom", foi lá animado, pegou,  "Good", he went there excitedl
#     FT: Meu tio falou: "Irmã, meu sobr My uncle said: "Sister, my nep
#     FT: "Ah". O assado deram para meu  "Ah". The roast they gave to m
#     FT: Quando nós matamos pela primei When we kill for the first tim
#     FT: Nós costumamos fazer assim. We used to do it like this.
#     FT: Ele me fez ficar assim, eu que He made me look like this, I w
#     FT: Não deixava mais a touca, não  I didn't leave my cap on anymo
#     FT: Fiz tocaias, fiz tocaias de vá I made ambushes, I made ambush
#     FT: Fiz tocaia na árvore matamata, I ambushed the matamata tree,
#     FT: vários tipos, Many types,

# %%
def add_gl_translation(corpus):
    gloss_lg = {'EVEN1259':'ru', 'NISV1234':'fr', 'TEXI1237':'es'}
    for f in corpus:
        if f[:8].upper() not in gloss_lg: continue
        glossct = Counter([gi for fi in corpus[f] for li in corpus[f][fi]
                           for g in corpus[f][fi][li]['gloss'] for gi in g['G']])
        print(f, len(glossct), glossct.most_common(10))
        cr = [w for w,c in glossct.most_common()]
        cr2 = cr.copy()
        tr = []
        while cr != []:
            crstr = ''
            while cr != [] and len(crstr) + len(cr[0]) + 1 < 5000:
                crstr += cr.pop(0) + '\n'
            crstr.strip('\n')
            print(len(cr))
            tr += translator.translate(crstr, 'en', gloss_lg[f[:8].upper()]).text.split('\n')
        dic = {w:t for w,t in zip(cr2,tr)}
        for fi in corpus[f]:
            for li in corpus[f][fi]:
                for gi,g in enumerate(corpus[f][fi][li]['gloss']):
                    corpus[f][fi][li]['gloss'][gi]['G'] = [dic[gx] for gx in g['G']]
    return corpus
        
corpus = add_gl_translation(corpus)
# Out:
# even1259.csv 1727 [('PL', 1062), ('3SG', 830), ('NFUT', 734), ('IPFV', 685), ('1SG', 651), ('ACC', 591), ('PST', 424), ('быть', 390), ('PANT', 390), ('FOC', 372)]
# 1063
# 527
# 13
# 0
# nisv1234.csv 1107 [('3SG', 1499), ('3PL', 566), ('INTR', 467), ('aller', 436), ('COO.VB', 398), ('DET', 361), ('1SG', 263), ('dire', 254), ('NOM', 243), ('ASP.A', 243)]
# 471
# 0
# texi1237.csv 742 [('3.A', 1649), ('decir', 1276), ('PFV', 829), ('3.3', 498), ('FUT', 426), ('1.3', 334), ('no', 317), ('3.PL', 294), ('APL', 278), ('ya', 245)]
# 0

# %% [markdown]
# ## clean FT
#
# needs to happen after translation

# %%
def clean_ft(ft, doc):
    punct = '.,;:\'\"!\?'
    brackets = '\[\]\(\)\<\>'
    #
    ft = ' '.join([(w.strip('-…') if w not in REP else REP[w]) for w in ft.split(' ')])
    #ft = re.sub('([^-])[-]*(\w+)[-]*([^-])', r'\1\2\3', ft) 
    # remove trailing dashes
    ft = re.sub('(\w)[-_](\w)', r'\1 \2', ft) 
    # splits hyphenated and underscore-linked words
    ft = re.sub('(\'\'|``|’’|“|”)', '"', ft)
    # normalize quote chars
    ft = re.sub('[`‘’´]', "'", ft)
    # normalize apostrophes
    ft = re.sub('ː', ':', ft)
    # normalize colons
    ft = re.sub('\(' + parenthetical_content + '.*?\)', '', ft)
    ft = re.sub('\[' + parenthetical_content + '.*?\]', '', ft)
    ft = re.sub('\<' + parenthetical_content + '.*?\>', '', ft)
    #
    ft = re.sub('([\[\(\<])\s*', r' \1', ft)
    ft = re.sub('\s*([\]\)\>])', r'\1 ', ft)
    
    # remove comments and other parentheticals [that aren't textual completions]
    # ft = re.sub('[()]','', ft)
    ft = re.sub('â', '', ft)
    ft = re.sub('\s+([%s])' % punct, r'\1', ft)
    ft = re.sub('(\w)([%s])(\w)' % (punct+brackets), r'\1 \2 \3', ft)
    ft = re.sub('(\w)([%s])([%s])(\w)' % (punct+brackets,punct+brackets), r'\1 \2 \3 \4', ft)
    ft = re.sub('(\w)([%s])([%s])([%s])(\w)' % (punct+brackets,punct+brackets,punct+brackets), r'\1 \2 \3 \4 \5', ft)
    ft = re.sub('[<>]\??', '', ft) 
    ft = re.sub('\s+', ' ', ft)
    ft = re.sub('#', '', ft)
    ft = ft.strip(' _/')
    ft = re.sub(" ' (ve|t|m|s|d|ll|re|clock)", r"'\1", ft)
    if doc[:4] == 'bain': ft = re.sub('.*?\|', '', ft)
    # remove duplicate spaces
    return ft

# %%
for doc in corpus:
    for file in corpus[doc]:
        for line,elt in corpus[doc][file].items():
            corpus[doc][file][line]['ft'] = clean_ft(elt['ft'], doc)

# %% [markdown]
# ## finding further errors

# %% [markdown]
# ### 4. add spacy data

# %%
def get_features(w):
    return {'text' : w.text, 'i' : w.i, 'idx' : w.idx, 'lemma' : w.lemma_, 'pos' : w.pos_,
            'tag' : w.tag_, 'head.i' : w.head.i, 'dep' : w.dep_}

for doc in corpus:
    print(doc)
    for f in corpus[doc]:
        for l in corpus[doc][f]:
            e = corpus[doc][f][l]
            e['spc'] = [get_features(w) for w in nlp(e['ft'])]
# Out:
# anal1239.csv
# apah1238.csv
# arap1274.csv
# bain1259.csv
# beja1238.csv
# bora1263.csv
# cabe1245.csv
# cash1254.csv
# dolg1241.csv
# even1259.csv
# goem1240.csv
# goro1270.csv
# hoch1243.csv
# jeha1242.csv
# jeju1234.csv
# kaka1265.csv
# kama1351.csv
# kark1256.csv
# komn1238.csv
# ligh1234.csv
# lowe1385.csv
# movi1243.csv
# ngal1292.csv
# nisv1234.csv
# nngg1234.csv
# nort2641.csv
# nort2875.csv
# orko1234.csv
# pnar1238.csv
# port1286.csv
# resi1247.csv
# ruul1235.csv
# sadu1234.csv
# sanz1248.csv
# savo1255.csv
# sout2856.csv
# sout3282.csv
# stan1290.csv
# sumi1235.csv
# svan1243.csv
# taba1259.csv
# teop1238.csv
# texi1237.csv
# trin1278.csv
# tsim1256.csv
# urum1249.csv
# vera1241.csv
# warl1254.csv
# yong1270.csv
# yuca1254.csv
# yura1255.csv

# %%
pickle.dump(corpus, open('corpus_doreco.p', 'wb'))
